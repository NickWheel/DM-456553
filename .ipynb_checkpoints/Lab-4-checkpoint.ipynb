# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-64a8289b2d8e> in <module>
#       1 # створимо інстанс для операції `SELECT`
# ----> 2 students_cur = cur.execute("SELECT * FROM jornal")
#       3
#       4 # будуємо список записів за допомогою метода `fetchall()`
#       5 students_list = students_cur.fetchall()
#
# OperationalError: no such table: jornal

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('jornal_test',)]

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test.\"Оцінка/100\" FROM  \
            jornal LEFT JOIN test ON jornal.Surname = test.\"Ім\'я\" "

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-6ca9d9ffa997> in <module>
#       4
#       5 # для перевірки виконаємо і виведемо результати запиту
# ----> 6 cur.execute(sql_stmt).fetchall()
#
# OperationalError: no such table: jornal

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# %%
result_dict

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %%
Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.

__Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.). 
Необхідно:
1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються) 
3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

YOUR_FILE = 'aprt_total_price.txt'
with open(YOUR_FILE) as f1, \
     open('street_name.csv') as f2, \
     open('street_flat_property.csv', 'w') as f3:
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# price,street
#
# 115 000,Омеляновича-Павленка
#
# 75 000,
#
# 140 000,Ованеса Туманяна
#
# 140 000,Петропавлівська
#
# 160 000,Дніпровська
#
# 870 000,Саксаганського
#
# 14 883 863,Івана Мазепи
#
# 220 000,Дніпровська
#
# 133 000,Ділова
#
# 69 000,Новодарницька
#
# 169 999,Ревуцького
#
# 212 000,Липківського
#
# 83 500,Бендукідзе
#
# 75 000,Введенська
#
# 65 000,Виноградний
#
# 82 000,Кайсарова
#
# 207 000,Ахматової
#
# 51 990,Радченка
#
# 57 999,Дніпровська
#
# 57 000,Ділова
#
# 95 000,Бориспільська
#
# 50 000,Болсуновська
#
# 95 000,Українки
#
# 46 860,Антонова
#
# 38 500,Омеляновича-Павленка
#
# 110 000,
#
# 269 000,Ованеса Туманяна
#
# 1 983 000,Петропавлівська
#
# 119 000,Дніпровська
#
# 210 000,Саксаганського
#
# 310 000,Івана Мазепи
#
# 93 000,Дніпровська
#
# 98 000,Ділова
#
# 78 000,Новодарницька
#
# 68 000,Ревуцького
#
# 77 000,Липківського
#
# 176 000,Бендукідзе
#
# 5 572 000,Введенська
#
# 129 000,Виноградний
#
# 136 000,Кайсарова
#
# 71 000,Ахматової
#
# 108 000,Радченка
#
# 175 000,Дніпровська
#
# 45 006,Ділова
#
# 78 000,Бориспільська
#
# 65 000,Болсуновська
#
# 3 396 000,Українки
#
# 68 899,Антонова
#
# 205 000,Науки
#
# 211 000,Метрологічна
#
# 36 500,Дружби Народів
#
# 3 176 715,*** not found
#
# 155 000,Драгомирова
#
# 109 000,Данченка
#
# 120 000,Кримська
#
# 55 000,Новопольова
#
# 48 000,Туполєва
#
# 235 000,*** not found
#
# 41 000,Дніпровська
#
# 143 000,Перемоги
#
# 65 000,Івана Федорова
#
# 500 000,Братиславська
#
# 94 000,*** not found
#
# 280 000,Червоноткацька
#
# 67 500,Златоустівська
#
# 72 000,Бойченка
#
# 54 000,Трускавецька
#
# 74 000,Каховська
#
# 130 000,Лобановського
#
# 110 000,*** not found
#
# 180 000,Курчатова
#
# 69 000,Голосіївська
#
# 205 000,Тираспольська
#
# 211 000,Лаврська
#
# 36 500,Правди
#
# 3 176 715,Миколайчука
#
# 155 000,Порика
#
# 109 000,Червоноткацька
#
# 120 000,Маккейна
#
# 55 000,Йорданська
#
# 48 000,Тютюнника
#
# 235 000,Регенераторна
#
# 41 000,Зарічна
#
# 143 000,Заболотного
#
# 65 000,Курнатовського
#
# 500 000,Інститутська
#
# 94 000,Маланюка
#
# 280 000,Гречка
#
# 67 500,Липківського
#
# 72 000,Маккейна
#
# 54 000,Григоренка
#
# 74 000,Коновальця
#
# 130 000,Закревського
#
# 110 000,*** not found
#
# 180 000,Старонаводницька
#
# 69 000,Маланюка
#
# 120 000,Заньковецької
#
# 150 000,Кудрявська
#
# 750 000,
#
# 75 000,Українки
#
# 53 000,
#
# 42 500,Милославська
#
# 103 000,Донця
#
# 650 000,Верховинця
#
# 56 000,Героїв Дніпра
#
# 90 000,Каховська
#
# 77 000,Каховська
#
# 115 000,Вишняківська
#
# 120 000,Липська
#
# 130 000,Сверстюка
#
# 85 000,Драгомирова
#
# 140 000,Причальна
#
# 45 500,Болсуновська
#
# 63 232,Повітрофлотський
#
# 95 000,Драгоманова
#
# 55 000,Григоренка
#
# 186 900,Дніпровська
#
# 34 200,Жабаєва
#
# 234 899,Філатова
#
# 55 000,Правди
#
# 136 000,Малопідвальна
#
# 139 000,Бойчука
#
# 210 000,Зарічна
#
# 195 000,Предславинська
#
# 119 000,Івана Мазепи
#
# 410 000,Радченка
#
# 93 000,Лабораторний
#
# 137 634,Конєва
#
# 115 000,Шаповала
#
# 85 000,Дніпровська
#
# 130 000,Клеманська
#
# 113 000,Григоренка
#
# 39 500,Туполєва
#
# 68 000,Хмельницького
#
# 155 000,Саперне Поле
#
# 110 000,Героїв Сталінграда
#
# 75 000,Дніпровська
#
# 142 000,Тарасівська
#
# 80 000,Краківська
#
# 43 000,Юнацька
#
# 248 000,Клеманська
#
# 280 000,Героїв Сталінграда
#
# 209 000,Драгомирова
#
# 58 990,*** not found
#
# 111 000,Драгоманова
#
# 97 000,Українки
#
# 68 000,Тимошенка
#
# 184 900,Маяковського
#
# 61 500,Дмитрівська
#
# 111 000,Курбаса
#
# 190 700,Комарова
#
# 53 000,Драгоманова
#
# 69 000,Драгомирова
#
# 169 000,Моторний
#
# 95 000,Милославська
#
# 110 000,Бойчука
#
# 5 880 000,Закревського
#
# 99 999,Івана Федорова
#
# 327 000,Філатова
#
# 85 000,Перемоги
#
# 790 000,Миропільська
#
# 95 000,Григоренка
#
# 70 000,Юнацька
#
# 2 352 122,Вишгородська
#
# 807 000,Жолудєва
#
# 77 000,Павлівська
#
# 75 000,Голосіївський
#
# 480 000,Осокорська
#
# 70 000,Вишгородська
#
# 205 000,Драгомирова
#
# 499 990,Тютюнника
#
# 52 000,Маккейна
#
# 93 000,Івана Мазепи
#
# 117 000,Героїв Сталінграда
#
# 53 900,Липківського
#
# 58 000,*** not found
#
# 159 000,Коновальця
#
# 116 000,Максимовича
#
# 42 000,Зарічна
#
# 55 500,Голосіївська
#
# 370 000,Ясинуватський
#
# 650 000,*** not found
#
# 355 000,Колоса
#
# 145 000,Правди
#
# 117 000,Велика Васильківська
#
# 300 000,Голосіївський
#
# 55 000,*** not found
#
# 41 000,Бойчука
#
# 128 000,Центральна
#
# 175 000,Ясинуватський
#
# 783 000,Райдужна
#
# 90 000,Ломоносова
#
# 98 000,
#
# 137 000,*** not found
#
# 45 000,Гусовського
#
# 2 015 228,Окіпної
#
# 200 000,Багговутівська
#
# 147 000,Дружби Народів
#
# 78 000,Маккейна
#
# 82 000,Маланюка
#
# 75 000,Михайла Котельникова
#
# 89 000,Героїв Севастополя
#
# 710 000,Маланюка
#
# 620 000,Саперне Поле
#
# 69 500,Балтійський
#
# 85 000,Кудрявська
#
# 43 000,Перемоги
#
# 330 000,Німанська
#
# 59 000,Каховська
#
# 40 000,Малопідвальна
#
# 1 200 000,Невська
#
# 405 000,Златоустівська
#
# 100 110,
#
# 400 000,Берковецька
#
# 97 500,Бажана
#
# 83 000,Антоновича
#
# 44 000,*** not found
#
# 66 000,Гречка
#
# 350 000,Микільсько-Слобідська
#
# 77 000,Правди
#
# 122 250,Тимошенка
#
# 65 000,Павла Тичини
#
# 170 000,Олевська
#
# 95 000,Освіти
#
# 85 000,Іллєнка
#
# 69 500,Дніпровська
#
# 152 000,Івана Мазепи
#
# 92 000,Українки
#
# 375 000,Данченка
#
# 449 000,Драгомирова
#
# 75 500,Тбіліський
#
# 140 000,Каховська
#
# 45 000,Ушинського
#
# 135 000,Урлівська
#
# 125 000,Світлицького
#
# 140 000,Дніпровська
#
# 120 000,Липківського
#
# 42 000,Микільсько-Слобідська
#
# 125 000,Лобановського
#
# 48 000,Героїв Сталінграда
#
# 300 000,Дніпровська
#
# 120 000,Драгоманова
#
# 649 000,Ахматової
#
# 64 980,Саперне Поле
#
# 77 000,Данченка
#
# 48 000,Голосіївський
#
# 102 000,*** not found
#
# 185 000,Глибочицька
#
# 42 000,Багговутівська
#
# 115 000,Саксаганського
#
# 175 000,Моторний
#
# 54 000,Йорданська
#
# 10 116 000,Саперне Поле
#
# 137 000,Вернадського
#
# 95 000,Курбаса
#
# 360 000,Багговутівська
#
# 135 000,Набережно-Рибальська
#
# 105 000,Саксаганського
#
# 58 000,Малиновського
#
# 180 000,Протасів Яр
#
# 153 000,Німанська
#
# 159 000,Підвисоцького
#
# 98 000,Зодчих
#
# 1 200 000,Рокосовського
#
# 42 900,Шовковична
#
# 86 000,Крушельницької
#
# 155 000,Новопольова
#
# 450 000,Визволителів
#
# 148 000,Сонячна
#
# 50 000,Сікорського
#
# 81 000,Радченка
#
# 161 003,Бульварно-Кудрявська
#
# 61 500,Кайсарова
#
# 78 000,Дніпровська
#
# 259 266,Перова
#
# 34 500,Глушкова
#
# 122 000,Рокосовського
#
# 147 420,Саперно-Слобідська
#
# 73 000,Миколи Кибальчича
#
# 44 000,Миколи Ушакова
#
# 128 000,Антоновича
#
# 111 000,Богданівська
#
# 73 000,
#
# 89 000,Сверстюка
#
# 64 000,Ревуцького
#
# 375 000,Ованеса Туманяна
#
# 98 000,Саперне Поле
#
# 32 000,Григоренка
#
# 125 000,Гречка
#
# 61 500,Богатирська
#
# 105 000,Білоруська
#
# 2 425 640,Регенераторна
#
# 89 000,Вишняківська
#
# 27 500,Гонгадзе
#
# 47 000,Правди
#
# 329 000,Кольцова
#
# 71 000,Воскресенська
#
# 1 885 431,Руставелі
#
# 980 000,Голосіївський
#
# 68 000,Комбінатна
#
# 71 000,Салютна
#
# 190 000,Маланюка
#
# 3 641 884,Ромоданова
#
# 115 000,Саперне Поле
#
# 45 000,Сім’ї Кульженків
#
# 57 000,Лабораторна
#
# 45 500,Драгоманова
#
# 260 000,
#
# 80 000,Кудрявська
#
# 2 110 252,Краківська
#
# 138 000,Кольцова
#
# 105 000,Антоновича
#
# 2 363 130,Лариси Руденко
#
# 89 000,Івана Пулюя
#
# 400 000,Українки
#
# 100 000,Тютюнника
#
# 61 500,Юрія Смолича
#
# 48 000,Оболонський
#
# 180 000,Курбаса
#
# 108 000€,Верховинця
#
# 43 500,Зарічна
#
# 100 999,Дніпровська
#
# 52 000,Коломийський
#
# 146 000,Правди
#
# 110 000,Каховська
#
# 148 800,Бойчука
#
# 77 000,Правди
#
# 38 500,Маккейна
#
# 100 000,Перемоги
#
# 78 000,Грушевського
#
# 75 000,Срібнокільська
#
# 45 000,Перемоги
#
# 900 000,Урлівська
#
# 85 000,Заболотного
#
# 65 600,Максимовича
#
# 395 000,Бажана
#
# 155 000,Сікорського
#
# 84 000,Курбаса
#
# 73 000,Дніпровська
#
# 83 000,Драгомирова
#
# 250 000,
#
# 299 000,Антонова
#
# 56 000,Бучми
#
# 4 335 178,Кубанської України
#
# 270 000,Дніпровська
#
# 58 000,Панельна
#
# 62 000,Коновальця
#
# 80 000,Богатирська
#
# 195 000,Оболонський
#
# 3 180 495,Українки
#
# 122 000,Бориса Гмирі
#
# 3 793 500,Правди
#
# 65 000,Центральна
#
# 40 500,Преображенська
#
# 1 181 731,Коновальця
#
# 69 000,Українки
#
# 75 000,*** not found
#
# 155 000,Велика Васильківська
#
# 220 000,Липківського
#
# 51 500,Бойчука
#
# 73 900,Васильківська
#
# 2 458 347,Данькевича
#
# 1 400 000,Богатирська
#
# 93 950,Українки
#
# 395 000,Гречка
#
# 179 000,Редутна
#
# 260 000,Бориса Гмирі
#
# 52 000,Драгомирова
#
# 395 000,Туполєва
#
# 198 450,Кондратюка
#
# 750 000,Мінський
#
# 650 000,Княжий Затон
#
# 75 000,Герцена
#
# 150 000,Балтійський
#
# 93 900,Ернста
#
# 120 500,Шаповала
#
# 129 000,Городецького
#
# 62 000,Сім'ї Сосніних
#
# 150 000,Івана Мазепи
#
# 55 000,Червоноткацька
#
# 138 000,*** not found
#
# 172 000,Голосіївська
#
# 79 900,*** not found
#
# 49 999,Миколи Гулака
#
# 115 000,Івана Федорова
#
# 87 000,Саперне Поле
#
# 107 000,Миколи Хвильового
#
# 87 700,Паторжинського
#
# 65 000,Наумовича
#
# 1 250 000,Калнишевського
#
# 34 700,Дніпровська
#
# 67 000,Електриків
#
# 88 000,Солом'янська
#
# 285 000,Шевченка
#
# 93 000,Озерна
#
# 85 000,Григоренка
#
# 230 000,Антонова
#
# 155 000,Голосіївський
#
# 180 000,Комарова
#
# 95 000,Борщагівська
#
# 54 934,Шевченка
#
# 260 000,Максимовича
#
# 145 000,Ковальський
#
# 135 000,Малевича
#
# 50 000,Мічуріна
#
# 399 000,*** not found
#
# 55 000,Балтійський
#
# 270 000,Азербайджанська
#
# 337 000,Зарічна
#
# 170 000,Чавдар
#
# 85 000,Правди
#
# 279 000,Урлівська
#
# 44 000,Бориспільська
#
# 170 000,Поправки
#
# 88 000,Бориспільська
#
# 41 500,Ентузіастів
#
# 70 000,Малоземельна
#
# 119 900,Саксаганського
#
# 86 000,Героїв Сталінграда
#
# 138 000,Зодчих
#
# 240 000,Калнишевського
#
# 149 500,Філатова
#
# 1 999 600,Старонаводницька
#
# 67 999,Заболотного
#
# 41 500,Правди
#
# 99 000,*** not found
#
# 580 000,Антоновича
#
# 75 000,Шаповала
#
# 299 000,Івана Федорова
#
# 44 000,Деревлянська
#
# 139 000,Вільямса
#
# 150 000,Васильченка
#
# 45 690,Предславинська
#
# 115 000,Крайня
#
# 63 500,Милославська
#
# 42 000,Воскресенська
#
# 56 500,Маланюка
#
# 66 000,Дніпровська
#
# 103 000,Пушкінська
#
# 63 000,Набережно-Корчуватська
#
# 228 000,Зарічна
#
# 90 000,Тургенєвська
#
# 87 000,Радченка
#
# 62 000,Зарічна
#
# 77 000,Метрологічна
#
# 179 900,Йорданська
#
# 49 000,Кольцова
#
# 105 900,Максимовича
#
# 500 000,Науки
#
# 38 000,Саперно-Слобідська
#
# 130 000,Шовковична
#
# 230 000,Трускавецька
#
# 66 800,Гавела
#
# 125 000,Повітрофлотський
#
# 113 000,Запорожця
#
# 93 000,Маккейна
#
# 422 000,Перемоги
#
# 80 500,Щербаківського
#
# 123 000,Зарічна
#
# 200 000,Будищанська
#
# 52 000,Жилянська
#
# 360 000,Комбінатна
#
# 102 000,Ревуцького
#
# 77 000,Бородіна
#
# 125 000,Руставелі
#
# 84 000,Драгоманова
#
# 185 000,Преображенська
#
# 888 189,Депутатська
#
# 45 142,Багговутівська
#
# 980 000,*** not found
#
# 180 000,Сікорського
#
# 40 000,Драгомирова
#
# 110 000,Коперніка
#
# 3 600 804,Васильківська
#
# 165 000,Глибочицька
#
# 92 550,Чавдар
#
# 80 000,Шовковична
#
# 115 000,Дніпровська
#
# 4 335 178,Антоновича
#
# 155 000,
#
# 220 000,Славгородська
#
# 95 000,Драгомирова
#
# 115 000,Срібнокільська
#
# 1 750 000,Харченка
#
# 240 000,Окіпної
#
# 1 158 740,Саперне Поле
#
# 170 000,Олени Теліги
#
# 93 000,Кондратюка
#
# 145 000,Мечнікова
#
# 47 211,Героїв Сталінграда
#
# 81 000,Рибальська
#
# 750 000,Березова
#
# 84 950,Саперне Поле
#
# 190 000,Антоновича
#
# 85 000,Маккейна
#
# 211 000,Лейпцизька
#
# 136 279,Драгоманова
#
# 71 000,Коновальця
#
# 95 000,Василя Стуса
#
# 120 000,Тютюнника
#
# 335 000,Січових Стрільців
#
# 38 500,Райдужна
#
# 47 000,Закревського
#
# 105 000,Тургенєвська
#
# 163 000,Васильківська
#
# 1 500 000,Зої Космодем'янської
#
# 49 000,Радченка
#
# 100 000,Сверстюка
#
# 130 000,Милославська
#
# 2 688 000,Метрологічна
#
# 52 600,Деміївська
#
# 39 000,Перемоги
#
# 110 000,Вишгородська
#
# 135 000,Маккейна
#
# 139 860,
#
# 70 000,Перемоги
#
# 95 000,Балтійський
#
# 155 000,Звіринецька
#
# 56 850,Ревуцького
#
# 140 000,Правди
#
# 110 000,Милославська
#
# 145 000,Вербицького
#
# 280 000,Новгородська
#
# 270 000,Бажана
#
# 50 500,Канівська
#
# 39 000,Максимовича
#
# 490 000,Донця
#
# 34 988,Драгомирова
#
# 311 000,Тираспольська
#
# 65 000,Саксаганського
#
# 169 000,Тираспольська
#
# 70 000,Зарічна
#
# 103 000,Гонгадзе
#
# 140 000,Українки
#
# 116 500,Світлицького
#
# 107 000,Воробйова
#
# 77 000,Каховська
#
# 165 000,Глибочицька
#
# 450 000,Білокур
#
# 195 000,Балтійський
#
# 480 000,Антоновича
#
# 120 000,Кондратюка
#
# 58 000,Гончара
#
# 1 500 000,Ревуцького
#
# 345 700,*** not found
#
# 126 000,Драгоманова
#
# 158 000,Сім’ї Кульженків
#
# 206 315,Панельна
#
# 33 000,Вільямса
#
# 250 000,Голосіївська
#
# 63 500,Оболонський
#
# 2 100 000,Миколи Голего
#
# 1 180 000,Дніпровська
#
# 42 000,Малиновського
#
# 146 000,Назарівська
#
# 299 000,Гоголівська
#
# 141 000,Дорогожицька
#
# 41 000,Петропавлівська
#
# 115 000,Грушевського
#
# 81 000,Іллєнка
#
# 103 950,Липківського
#
# 1 468 067,Ушинського
#
# 68 000,Польова
#
# 80 000,Саперне Поле
#
# 112 000,Панельна
#
# 319 000,Коновальця
#
# 98 000,Хмельницького
#
# 50 000,Маккейна
#
# 49 990,Антоновича
#
# 89 500,Толстого
#
# 350 000,Дружби Народів
#
# 210 000,Оболонський
#
# 345 000,Багговутівська
#
# 90 000,Антонова
#
# 170 000,Володимирська
#
# 110 000,Українки
#
# 59 000,Сім’ї Кульженків
#
# 145 000,Коновальця
#
# 79 000,Мирного
#
# 375 000,Московська
#
# 122 000,Жмеринська
#
# 255 000,Бойчука
#
# 85 000,Липківського
#
# 240 800,Лабораторний
#
# 455 000,Інститутська
#
# 165 000,Українки
#
# 100 000,Хрещатик
#
# 195 000,Дніпровська
#
# 41 000,Осокорська
#
# 70 000,Саперне Поле
#
# 71 400,Комарова
#
# 3 711 865,Драгомирова
#
# 60 000,Срібнокільська
#
# 240 000,Чоколівський
#
# 260 000,Звіринецька
#
# 127 000,Вишгородська
#
# 40 000,Драгомирова
#
# 1 796 439,Героїв Сталінграда
#
# 3 400 000,Будівельників
#
# 44 500,Іллєнка
#
# 125 000,Урлівська
#
# 51 000,Сормовська
#
# 1 707 790,Правди
#
# 65 000,Верховинна
#
# 55 000,Вербицького
#
# 94 500,*** not found
#
# 115 000,Велика Васильківська
#
# 45 000,Бойчука
#
# 85 000,Лобановського
#
# 5 204 750,Миколи Шепелєва
#
# 84 500,Кропивницького
#
# 350 000,Трускавецька
#
# 182 000,Голосіївська
#
# 188 999,Маланюка
#
# 147 000,Драгомирова
#
# 89 900,Юнацька
#
# 66 900,Максимовича
#
# 75 000,Комарова
#
# 58 000,Багговутівська
#
# 140 000,
#
# 82 000,Костанайська
#
# 215 000,Срібнокільська
#
# 33 400,Курчатова
#
# 100 000,Гусовського
#
# 240 000,Українки
#
# 62 000,Драгоманова
#
# 115 000,Дніпровська
#
# 143 560,Заболотного
#
# 130 000,Заболотного
#
# 152 000,Перемоги
#
# 33 800,Сверстюка
#
# 55 000,Липківського
#
# 110 000,Маккейна
#
# 200 000,Дніпровська
#
# 70 000,Волгоградська
#
# 160 888,Новопольова
#
# 189 000,Драгоманова
#
# 135 000,Лебедєва
#
# 215 000,*** not found
#
# 102 000,Драгомирова
#
# 193 750,Лейпцизька
#
# 54 000,Глибочицька
#
# 70 000,Салютна
#
# 3 180 495,Метрологічна
#
# 50 500,Північно-Сирецька
#
# 57 000,Правди
#
# 130 000,Вернадського
#
# 262 000,Пчілки
#
# 66 000,Лейпцизька
#
# 3 249 056,Басейна
#
# 2 000 000,Шаповала
#
# 78 000,Бережанська
#
# 90 500,Бойчука
#
# 80 000,Перемоги
#
# 906 080,Івана Федорова
#
# 4 500 000,Антоновича
#
# 32 000,Вільямса
#
# 190 000,Бойчука
#
# 220 000,Перемоги
#
# 110 000,Ковпака
#
# 43 000,Русанівський
#
# 983 253,Українки
#
# 65 000,Празька
#
# 110 000,Гончара
#
# 150 000,Маккейна
#
# 125 500,Балтійський
#
# 200 000,Білоруська
#
# 480 000,Драгоманова
#
# 235 000,Липківського
#
# 82 000,Новогоспітальна
#
# 121 975,Радченка
#
# 200 000,Богомольця
#
# 250 000,Донця
#
# 205 000,Оболонський
#
# 76 466,Щекавицька
#
# 240 000,Пожарського
#
# 150 000,Полкова
#
# 69 000,Донця
#
# 74 900,Палладіна
#
# 1 350 000,Бойчука
#
# 386 000,Липківського
#
# 31 500,Павлівська
#
# 58 000,Івашкевича
#
# 115 000,Іскрівська
#
# 64 999,Максимовича
#
# 69 900,*** not found
#
# 220 000,Драгомирова
#
# 2 873 080,Теремківська
#
# 186 000,Осокорська
#
# 43 000,Дмитрівська
#
# 55 000,Кондратюка
#
# 193 750,Регенераторна
#
# 100 999,
#
# 11 017 941,Глибочицька
#
# 149 000,Героїв Сталінграда
#
# 3 600 804,Борщагівська
#
# 45 000,Ревуцького
#
# 92 000,Юнацька
#
# 295 000,Заболотного
#
# 39 900,Автозаводська
#
# 215 000,Заболотного
#
# 2 458 347,Саксаганського
#
# 138 000,Зарічна
#
# 50 000,*** not found
#
# 92 284,Невська
#
# 140 000,Героїв Сталінграда
#
# 3 707 378,Вишняківська
#
# 94 000,Драгомирова
#
# 45 000,Драгомирова
#
# 56 000,Гавела
#
# 140 000,Здолбунівська
#
# 90 000,Драгомирова
#
# 159 000,Мечнікова
#
# 1 848 450,*** not found
#
# 106 000,Максимовича
#
# 170 000,Багговутівська
#
# 91 000,Шолуденка
#
# 110 000,Щекавицька
#
# 65 000,Коласа
#
# 260 000,*** not found
#
# 125 000,*** not found
#
# 65 000,Перемоги
#
# 158 000,*** not found
#
# 80 000,Наумова
#
# 68 900,Перемоги
#
# 168 000,Велика Васильківська
#
# 41 000,Червоноткацька
#
# 134 900,Вишгородська

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur  = conn.cursor()

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'
rows = cur.execute("SELECT * FROM street_district LIMIT 10")

rows_list = rows.fetchall()

_ = [print(x) for x in rows_list]
# Out:
# ('9-го Травня', 'вулиця', 'Святошинський')
# ('Абрикосова', 'вулиця', 'Оболонський')
# ('Абрикосова', 'вулиця', 'Дарницький')
# ('Абрикосова', 'вулиця', 'Подільський')
# ('Августина Волошина', 'вулиця', 'Солом’янський')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський')
# ('Автозаводська', 'вулиця', 'Оболонський')
# ('Автозаводський ', 'провулок', 'Оболонський')
# ('Автопаркова', 'вулиця', 'Дарницький')
# ('Авторемонтна', 'вулиця', "Солом'янський")

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property INT);"

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('property',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = "SELECT * FROM street_flat_property LEFT JOIN street_district ON street_flat_property.street = street_district.street;"

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()
# Out:
# [('115\xa0000', 'Омеляновича-Павленка', None, None, None),
#  ('75\xa0000', None, None, None, None),
#  ('140\xa0000', 'Ованеса Туманяна', None, None, None),
#  ('140\xa0000', 'Петропавлівська', 'Петропавлівська', 'вулиця', 'Подільський'),
#  ('140\xa0000', 'Петропавлівська', 'Петропавлівська', 'площа', 'Оболонський'),
#  ('160\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('870\xa0000',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('14\xa0883\xa0863', 'Івана Мазепи', None, None, None),
#  ('220\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('133\xa0000', 'Ділова', 'Ділова', 'вулиця', 'Голосіївський, Печерський'),
#  ('69\xa0000', 'Новодарницька', None, None, None),
#  ('169\xa0999', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('212\xa0000', 'Липківського', None, None, None),
#  ('83\xa0500', 'Бендукідзе', None, None, None),
#  ('75\xa0000', 'Введенська', 'Введенська', 'вулиця', 'Подільський'),
#  ('65\xa0000', 'Виноградний', 'Виноградний', 'провулок', 'Печерський'),
#  ('82\xa0000',
#   'Кайсарова',
#   'Кайсарова',
#   'вулиця',
#   "Голосіївський,Солом'янський"),
#  ('207\xa0000', 'Ахматової', None, None, None),
#  ('51\xa0990', 'Радченка', None, None, None),
#  ('57\xa0999', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('57\xa0000', 'Ділова', 'Ділова', 'вулиця', 'Голосіївський, Печерський'),
#  ('95\xa0000', 'Бориспільська', 'Бориспільська', 'вулиця', 'Дарницький'),
#  ('50\xa0000', 'Болсуновська', 'Болсуновська', 'вулиця', 'Печерський'),
#  ('95\xa0000', 'Українки', None, None, None),
#  ('46\xa0860', 'Антонова', None, None, None),
#  ('38\xa0500', 'Омеляновича-Павленка', None, None, None),
#  ('110\xa0000', None, None, None, None),
#  ('269\xa0000', 'Ованеса Туманяна', None, None, None),
#  ('1\xa0983\xa0000',
#   'Петропавлівська',
#   'Петропавлівська',
#   'вулиця',
#   'Подільський'),
#  ('1\xa0983\xa0000',
#   'Петропавлівська',
#   'Петропавлівська',
#   'площа',
#   'Оболонський'),
#  ('119\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('210\xa0000',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('310\xa0000', 'Івана Мазепи', None, None, None),
#  ('93\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('98\xa0000', 'Ділова', 'Ділова', 'вулиця', 'Голосіївський, Печерський'),
#  ('78\xa0000', 'Новодарницька', None, None, None),
#  ('68\xa0000', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('77\xa0000', 'Липківського', None, None, None),
#  ('176\xa0000', 'Бендукідзе', None, None, None),
#  ('5\xa0572\xa0000', 'Введенська', 'Введенська', 'вулиця', 'Подільський'),
#  ('129\xa0000', 'Виноградний', 'Виноградний', 'провулок', 'Печерський'),
#  ('136\xa0000',
#   'Кайсарова',
#   'Кайсарова',
#   'вулиця',
#   "Голосіївський,Солом'янський"),
#  ('71\xa0000', 'Ахматової', None, None, None),
#  ('108\xa0000', 'Радченка', None, None, None),
#  ('175\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('45\xa0006', 'Ділова', 'Ділова', 'вулиця', 'Голосіївський, Печерський'),
#  ('78\xa0000', 'Бориспільська', 'Бориспільська', 'вулиця', 'Дарницький'),
#  ('65\xa0000', 'Болсуновська', 'Болсуновська', 'вулиця', 'Печерський'),
#  ('3\xa0396\xa0000', 'Українки', None, None, None),
#  ('68\xa0899', 'Антонова', None, None, None),
#  ('205\xa0000', 'Науки', 'Науки', 'проспект', 'Голосіївський'),
#  ('211\xa0000', 'Метрологічна', 'Метрологічна', 'вулиця', 'Голосіївський'),
#  ('36\xa0500', 'Дружби Народів', 'Дружби Народів', 'бульвар', 'Печерський'),
#  ('3\xa0176\xa0715', '*** not found', None, None, None),
#  ('155\xa0000', 'Драгомирова', None, None, None),
#  ('109\xa0000', 'Данченка', None, None, None),
#  ('120\xa0000', 'Кримська', 'Кримська', 'вулиця', 'Голосіївський'),
#  ('55\xa0000', 'Новопольова', 'Новопольова', 'вулиця', "Солом'янський"),
#  ('48\xa0000', 'Туполєва', None, None, None),
#  ('235\xa0000', '*** not found', None, None, None),
#  ('41\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('143\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('143\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('143\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('65\xa0000', 'Івана Федорова', None, None, None),
#  ('500\xa0000',
#   'Братиславська',
#   'Братиславська',
#   'вулиця',
#   'Деснянський, Дніпровський'),
#  ('94\xa0000', '*** not found', None, None, None),
#  ('280\xa0000', 'Червоноткацька', None, None, None),
#  ('67\xa0500', 'Златоустівська', None, None, None),
#  ('72\xa0000', 'Бойченка', None, None, None),
#  ('54\xa0000', 'Трускавецька', 'Трускавецька', 'вулиця', 'Дарницький'),
#  ('74\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('130\xa0000', 'Лобановського', None, None, None),
#  ('110\xa0000', '*** not found', None, None, None),
#  ('180\xa0000', 'Курчатова', None, None, None),
#  ('69\xa0000', 'Голосіївська', 'Голосіївська', 'вулиця', 'Голосіївський'),
#  ('69\xa0000', 'Голосіївська', 'Голосіївська', 'площа', 'Голосіївський'),
#  ('205\xa0000', 'Тираспольська', 'Тираспольська', 'вулиця', 'Подільський'),
#  ('211\xa0000', 'Лаврська', 'Лаврська', 'вулиця', 'Печерський'),
#  ('36\xa0500', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('3\xa0176\xa0715', 'Миколайчука', None, None, None),
#  ('155\xa0000', 'Порика', None, None, None),
#  ('109\xa0000', 'Червоноткацька', None, None, None),
#  ('120\xa0000', 'Маккейна', None, None, None),
#  ('55\xa0000', 'Йорданська', 'Йорданська', 'вулиця', 'Оболонський'),
#  ('48\xa0000', 'Тютюнника', None, None, None),
#  ('235\xa0000', 'Регенераторна', 'Регенераторна', 'вулиця', 'Дніпровський'),
#  ('41\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('143\xa0000', 'Заболотного', None, None, None),
#  ('65\xa0000',
#   'Курнатовського',
#   'Курнатовського',
#   'вулиця',
#   'Дніпровський, Деснянський'),
#  ('500\xa0000', 'Інститутська', 'Інститутська', 'вулиця', 'Печерський'),
#  ('94\xa0000', 'Маланюка', None, None, None),
#  ('280\xa0000', 'Гречка', None, None, None),
#  ('67\xa0500', 'Липківського', None, None, None),
#  ('72\xa0000', 'Маккейна', None, None, None),
#  ('54\xa0000', 'Григоренка', None, None, None),
#  ('74\xa0000', 'Коновальця', None, None, None),
#  ('130\xa0000', 'Закревського', None, None, None),
#  ('110\xa0000', '*** not found', None, None, None),
#  ('180\xa0000',
#   'Старонаводницька',
#   'Старонаводницька',
#   'вулиця',
#   'Печерський'),
#  ('69\xa0000', 'Маланюка', None, None, None),
#  ('120\xa0000', 'Заньковецької', 'Заньковецької', 'вулиця', 'Печерський'),
#  ('150\xa0000', 'Кудрявська', 'Кудрявська', 'вулиця', 'Шевченківський'),
#  ('750\xa0000', None, None, None, None),
#  ('75\xa0000', 'Українки', None, None, None),
#  ('53\xa0000', None, None, None, None),
#  ('42\xa0500', 'Милославська', 'Милославська', 'вулиця', 'Деснянський'),
#  ('103\xa0000', 'Донця', None, None, None),
#  ('650\xa0000', 'Верховинця', None, None, None),
#  ('56\xa0000', 'Героїв Дніпра', 'Героїв Дніпра', 'вулиця', 'Оболонський'),
#  ('90\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('77\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('115\xa0000', 'Вишняківська', 'Вишняківська', 'вулиця', 'Дарницький'),
#  ('120\xa0000', 'Липська', None, None, None),
#  ('130\xa0000', 'Сверстюка', None, None, None),
#  ('85\xa0000', 'Драгомирова', None, None, None),
#  ('140\xa0000', 'Причальна', 'Причальна', 'вулиця', 'Дарницький'),
#  ('45\xa0500', 'Болсуновська', 'Болсуновська', 'вулиця', 'Печерський'),
#  ('63\xa0232',
#   'Повітрофлотський',
#   'Повітрофлотський',
#   'проспект',
#   "Шевченківський, Солом'янський"),
#  ('95\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('55\xa0000', 'Григоренка', None, None, None),
#  ('186\xa0900', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('34\xa0200', 'Жабаєва', None, None, None),
#  ('234\xa0899', 'Філатова', None, None, None),
#  ('55\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('136\xa0000', 'Малопідвальна', 'Малопідвальна', 'вулиця', 'Шевченківський'),
#  ('139\xa0000', 'Бойчука', None, None, None),
#  ('210\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('195\xa0000', 'Предславинська', 'Предславинська', 'вулиця', 'Печерський'),
#  ('119\xa0000', 'Івана Мазепи', None, None, None),
#  ('410\xa0000', 'Радченка', None, None, None),
#  ('93\xa0000', 'Лабораторний', 'Лабораторний', 'провулок', 'Печерський'),
#  ('137\xa0634', 'Конєва', None, None, None),
#  ('115\xa0000', 'Шаповала', None, None, None),
#  ('85\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('130\xa0000', 'Клеманська', 'Клеманська', 'вулиця', 'Дарницький'),
#  ('113\xa0000', 'Григоренка', None, None, None),
#  ('39\xa0500', 'Туполєва', None, None, None),
#  ('68\xa0000', 'Хмельницького', None, None, None),
#  ('155\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('110\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('75\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('142\xa0000', 'Тарасівська', 'Тарасівська', 'вулиця', 'Голосіївський'),
#  ('80\xa0000', 'Краківська', 'Краківська', 'вулиця', 'Дніпровський'),
#  ('43\xa0000', 'Юнацька', 'Юнацька', 'вулиця', 'Святошинський'),
#  ('43\xa0000', 'Юнацька', 'Юнацька', 'вулиця', "Солом'янський"),
#  ('248\xa0000', 'Клеманська', 'Клеманська', 'вулиця', 'Дарницький'),
#  ('280\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('209\xa0000', 'Драгомирова', None, None, None),
#  ('58\xa0990', '*** not found', None, None, None),
#  ('111\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('97\xa0000', 'Українки', None, None, None),
#  ('68\xa0000', 'Тимошенка', None, None, None),
#  ('184\xa0900', 'Маяковського', 'Маяковського', 'вулиця', 'Деснянський'),
#  ('61\xa0500', 'Дмитрівська', 'Дмитрівська', 'вулиця', 'Подільський'),
#  ('61\xa0500', 'Дмитрівська', 'Дмитрівська', 'вулиця', 'Шевченківський'),
#  ('111\xa0000', 'Курбаса', None, None, None),
#  ('190\xa0700', 'Комарова', None, None, None),
#  ('53\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('69\xa0000', 'Драгомирова', None, None, None),
#  ('169\xa0000', 'Моторний', None, None, None),
#  ('95\xa0000', 'Милославська', 'Милославська', 'вулиця', 'Деснянський'),
#  ('110\xa0000', 'Бойчука', None, None, None),
#  ('5\xa0880\xa0000', 'Закревського', None, None, None),
#  ('99\xa0999', 'Івана Федорова', None, None, None),
#  ('327\xa0000', 'Філатова', None, None, None),
#  ('85\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('85\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('85\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('790\xa0000',
#   'Миропільська',
#   'Миропільська',
#   'вулиця',
#   'Деснянський, Дніпровський'),
#  ('95\xa0000', 'Григоренка', None, None, None),
#  ('70\xa0000', 'Юнацька', 'Юнацька', 'вулиця', 'Святошинський'),
#  ('70\xa0000', 'Юнацька', 'Юнацька', 'вулиця', "Солом'янський"),
#  ('2\xa0352\xa0122',
#   'Вишгородська',
#   'Вишгородська',
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('807\xa0000', 'Жолудєва', 'Жолудєва', 'вулиця', 'Святошинський'),
#  ('77\xa0000', 'Павлівська', 'Павлівська', 'вулиця', 'Шевченківський'),
#  ('75\xa0000', 'Голосіївський', 'Голосіївський', 'провулок', 'Голосіївський'),
#  ('75\xa0000', 'Голосіївський', 'Голосіївський', 'проспект', 'Голосіївський'),
#  ('480\xa0000', 'Осокорська', 'Осокорська', 'вулиця', 'Дарницький'),
#  ('70\xa0000',
#   'Вишгородська',
#   'Вишгородська',
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('205\xa0000', 'Драгомирова', None, None, None),
#  ('499\xa0990', 'Тютюнника', None, None, None),
#  ('52\xa0000', 'Маккейна', None, None, None),
#  ('93\xa0000', 'Івана Мазепи', None, None, None),
#  ('117\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('53\xa0900', 'Липківського', None, None, None),
#  ('58\xa0000', '*** not found', None, None, None),
#  ('159\xa0000', 'Коновальця', None, None, None),
#  ('116\xa0000', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('42\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('55\xa0500', 'Голосіївська', 'Голосіївська', 'вулиця', 'Голосіївський'),
#  ('55\xa0500', 'Голосіївська', 'Голосіївська', 'площа', 'Голосіївський'),
#  ('370\xa0000', 'Ясинуватський', 'Ясинуватський', 'провулок', 'Голосіївський'),
#  ('650\xa0000', '*** not found', None, None, None),
#  ('355\xa0000', 'Колоса', None, None, None),
#  ('145\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('117\xa0000',
#   'Велика Васильківська',
#   'Велика Васильківська',
#   'вулиця',
#   'Голосіївський, Шевченківський, Печерський'),
#  ('300\xa0000', 'Голосіївський', 'Голосіївський', 'провулок', 'Голосіївський'),
#  ('300\xa0000', 'Голосіївський', 'Голосіївський', 'проспект', 'Голосіївський'),
#  ('55\xa0000', '*** not found', None, None, None),
#  ('41\xa0000', 'Бойчука', None, None, None),
#  ('128\xa0000', 'Центральна', 'Центральна', 'вулиця', 'Дніпровський'),
#  ('128\xa0000', 'Центральна', 'Центральна', 'вулиця', 'Оболонський'),
#  ('128\xa0000', 'Центральна', 'Центральна', 'вулиця', 'Шевченківський'),
#  ('175\xa0000', 'Ясинуватський', 'Ясинуватський', 'провулок', 'Голосіївський'),
#  ('783\xa0000', 'Райдужна', 'Райдужна', 'вулиця', 'Дніпровський'),
#  ('90\xa0000', 'Ломоносова', 'Ломоносова', 'вулиця', 'Голосіївський'),
#  ('98\xa0000', None, None, None, None),
#  ('137\xa0000', '*** not found', None, None, None),
#  ('45\xa0000', 'Гусовського', 'Гусовського', 'вулиця', 'Печерський'),
#  ('2\xa0015\xa0228', 'Окіпної', None, None, None),
#  ('200\xa0000',
#   'Багговутівська',
#   'Багговутівська',
#   'вулиця',
#   'Шевченківський'),
#  ('147\xa0000', 'Дружби Народів', 'Дружби Народів', 'бульвар', 'Печерський'),
#  ('78\xa0000', 'Маккейна', None, None, None),
#  ('82\xa0000', 'Маланюка', None, None, None),
#  ('75\xa0000', 'Михайла Котельникова', None, None, None),
#  ('89\xa0000',
#   'Героїв Севастополя',
#   'Героїв Севастополя',
#   'вулиця',
#   "Солом'янський"),
#  ('710\xa0000', 'Маланюка', None, None, None),
#  ('620\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('69\xa0500', 'Балтійський', 'Балтійський', 'провулок', 'Оболонський'),
#  ('85\xa0000', 'Кудрявська', 'Кудрявська', 'вулиця', 'Шевченківський'),
#  ('43\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('43\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('43\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('330\xa0000', 'Німанська', 'Німанська', 'вулиця', 'Печерський'),
#  ('59\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('40\xa0000', 'Малопідвальна', 'Малопідвальна', 'вулиця', 'Шевченківський'),
#  ('1\xa0200\xa0000', 'Невська', None, None, None),
#  ('405\xa0000', 'Златоустівська', None, None, None),
#  ('100\xa0110', None, None, None, None),
#  ('400\xa0000', 'Берковецька', 'Берковецька', 'вулиця', 'Святошинський'),
#  ('97\xa0500', 'Бажана', None, None, None),
#  ('83\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('44\xa0000', '*** not found', None, None, None),
#  ('66\xa0000', 'Гречка', None, None, None),
#  ('350\xa0000',
#   'Микільсько-Слобідська',
#   'Микільсько-Слобідська',
#   'вулиця',
#   'Дніпровський'),
#  ('77\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('122\xa0250', 'Тимошенка', None, None, None),
#  ('65\xa0000', 'Павла Тичини', None, None, None),
#  ('170\xa0000', 'Олевська', 'Олевська', 'вулиця', 'Святошинський'),
#  ('95\xa0000', 'Освіти', 'Освіти', 'вулиця', "Солом'янський"),
#  ('85\xa0000', 'Іллєнка', None, None, None),
#  ('69\xa0500', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('152\xa0000', 'Івана Мазепи', None, None, None),
#  ('92\xa0000', 'Українки', None, None, None),
#  ('375\xa0000', 'Данченка', None, None, None),
#  ('449\xa0000', 'Драгомирова', None, None, None),
#  ('75\xa0500', 'Тбіліський', None, None, None),
#  ('140\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('45\xa0000', 'Ушинського', 'Ушинського', 'вулиця', "Солом'янський"),
#  ('45\xa0000', 'Ушинського', 'Ушинського', 'провулок', "Солом'янський"),
#  ('135\xa0000', 'Урлівська', 'Урлівська', 'вулиця', 'Дарницький'),
#  ('125\xa0000', 'Світлицького', 'Світлицького', 'вулиця', 'Подільський'),
#  ('140\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('120\xa0000', 'Липківського', None, None, None),
#  ('42\xa0000',
#   'Микільсько-Слобідська',
#   'Микільсько-Слобідська',
#   'вулиця',
#   'Дніпровський'),
#  ('125\xa0000', 'Лобановського', None, None, None),
#  ('48\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('300\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('120\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('649\xa0000', 'Ахматової', None, None, None),
#  ('64\xa0980', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('77\xa0000', 'Данченка', None, None, None),
#  ('48\xa0000', 'Голосіївський', 'Голосіївський', 'провулок', 'Голосіївський'),
#  ('48\xa0000', 'Голосіївський', 'Голосіївський', 'проспект', 'Голосіївський'),
#  ('102\xa0000', '*** not found', None, None, None),
#  ('185\xa0000', 'Глибочицька', 'Глибочицька', 'вулиця', 'Шевченківський'),
#  ('42\xa0000', 'Багговутівська', 'Багговутівська', 'вулиця', 'Шевченківський'),
#  ('115\xa0000',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('175\xa0000', 'Моторний', None, None, None),
#  ('54\xa0000', 'Йорданська', 'Йорданська', 'вулиця', 'Оболонський'),
#  ('10\xa0116\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('137\xa0000', 'Вернадського', None, None, None),
#  ('95\xa0000', 'Курбаса', None, None, None),
#  ('360\xa0000',
#   'Багговутівська',
#   'Багговутівська',
#   'вулиця',
#   'Шевченківський'),
#  ('135\xa0000',
#   'Набережно-Рибальська',
#   'Набережно-Рибальська',
#   'дорога',
#   'Подільський'),
#  ('105\xa0000',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('58\xa0000', 'Малиновського', None, None, None),
#  ('180\xa0000', 'Протасів Яр', 'Протасів Яр', 'вулиця', "Солом'янський"),
#  ('153\xa0000', 'Німанська', 'Німанська', 'вулиця', 'Печерський'),
#  ('159\xa0000', 'Підвисоцького', None, None, None),
#  ('98\xa0000', 'Зодчих', 'Зодчих', 'вулиця', 'Святошинський'),
#  ('1\xa0200\xa0000', 'Рокосовського', None, None, None),
#  ('42\xa0900', 'Шовковична', 'Шовковична', 'вулиця', 'Печерський'),
#  ('86\xa0000', 'Крушельницької', None, None, None),
#  ('155\xa0000', 'Новопольова', 'Новопольова', 'вулиця', "Солом'янський"),
#  ('450\xa0000', 'Визволителів', 'Визволителів', 'проспект', 'Дніпровський'),
#  ('148\xa0000', 'Сонячна', 'Сонячна', 'вулиця', 'Дніпровський'),
#  ('148\xa0000', 'Сонячна', 'Сонячна', 'вулиця', 'Шевченківський'),
#  ('50\xa0000', 'Сікорського', None, None, None),
#  ('81\xa0000', 'Радченка', None, None, None),
#  ('161\xa0003',
#   'Бульварно-Кудрявська',
#   'Бульварно-Кудрявська',
#   'вулиця',
#   'Шевченківський'),
#  ('61\xa0500',
#   'Кайсарова',
#   'Кайсарова',
#   'вулиця',
#   "Голосіївський,Солом'янський"),
#  ('78\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('259\xa0266', 'Перова', 'Перова', 'бульвар', 'Дніпровський'),
#  ('34\xa0500', 'Глушкова', None, None, None),
#  ('122\xa0000', 'Рокосовського', None, None, None),
#  ('147\xa0420',
#   'Саперно-Слобідська',
#   'Саперно-Слобідська',
#   'вулиця',
#   'Голосіївський'),
#  ('73\xa0000', 'Миколи Кибальчича', None, None, None),
#  ('44\xa0000', 'Миколи Ушакова', None, None, None),
#  ('128\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('111\xa0000', 'Богданівська', 'Богданівська', 'вулиця', "Солом'янський"),
#  ('73\xa0000', None, None, None, None),
#  ('89\xa0000', 'Сверстюка', None, None, None),
#  ('64\xa0000', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('375\xa0000', 'Ованеса Туманяна', None, None, None),
#  ('98\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('32\xa0000', 'Григоренка', None, None, None),
#  ('125\xa0000', 'Гречка', None, None, None),
#  ('61\xa0500', 'Богатирська', 'Богатирська', 'вулиця', 'Оболонський'),
#  ('105\xa0000', 'Білоруська', 'Білоруська', 'вулиця', 'Шевченківський'),
#  ('2\xa0425\xa0640',
#   'Регенераторна',
#   'Регенераторна',
#   'вулиця',
#   'Дніпровський'),
#  ('89\xa0000', 'Вишняківська', 'Вишняківська', 'вулиця', 'Дарницький'),
#  ('27\xa0500', 'Гонгадзе', None, None, None),
#  ('47\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('329\xa0000', 'Кольцова', 'Кольцова', 'бульвар', 'Святошинський'),
#  ('71\xa0000', 'Воскресенська', 'Воскресенська', 'вулиця', 'Дніпровський'),
#  ('1\xa0885\xa0431', 'Руставелі', None, None, None),
#  ('980\xa0000', 'Голосіївський', 'Голосіївський', 'провулок', 'Голосіївський'),
#  ('980\xa0000', 'Голосіївський', 'Голосіївський', 'проспект', 'Голосіївський'),
#  ('68\xa0000', 'Комбінатна', 'Комбінатна', 'вулиця', 'Дніпровський'),
#  ('71\xa0000', 'Салютна', 'Салютна', 'вулиця', 'Шевченківський'),
#  ('190\xa0000', 'Маланюка', None, None, None),
#  ('3\xa0641\xa0884', 'Ромоданова', None, None, None),
#  ('115\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('45\xa0000', 'Сім’ї Кульженків', None, None, None),
#  ('57\xa0000',
#   'Лабораторна',
#   'Лабораторна',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('45\xa0500', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('260\xa0000', None, None, None, None),
#  ('80\xa0000', 'Кудрявська', 'Кудрявська', 'вулиця', 'Шевченківський'),
#  ('2\xa0110\xa0252', 'Краківська', 'Краківська', 'вулиця', 'Дніпровський'),
#  ('138\xa0000', 'Кольцова', 'Кольцова', 'бульвар', 'Святошинський'),
#  ('105\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('2\xa0363\xa0130', 'Лариси Руденко', None, None, None),
#  ('89\xa0000', 'Івана Пулюя', None, None, None),
#  ('400\xa0000', 'Українки', None, None, None),
#  ('100\xa0000', 'Тютюнника', None, None, None),
#  ('61\xa0500', 'Юрія Смолича', None, None, None),
#  ('48\xa0000', 'Оболонський', 'Оболонський', 'проспект', 'Оболонський'),
#  ('180\xa0000', 'Курбаса', None, None, None),
#  ('108\xa0000€', 'Верховинця', None, None, None),
#  ('43\xa0500', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('100\xa0999', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('52\xa0000', 'Коломийський', 'Коломийський', 'провулок', 'Голосіївський'),
#  ('146\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('110\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('148\xa0800', 'Бойчука', None, None, None),
#  ('77\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('38\xa0500', 'Маккейна', None, None, None),
#  ('100\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('100\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('100\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('78\xa0000', 'Грушевського', None, None, None),
#  ('75\xa0000', 'Срібнокільська', 'Срібнокільська', 'вулиця', 'Дарницький'),
#  ('45\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('45\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('45\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('900\xa0000', 'Урлівська', 'Урлівська', 'вулиця', 'Дарницький'),
#  ('85\xa0000', 'Заболотного', None, None, None),
#  ('65\xa0600', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('395\xa0000', 'Бажана', None, None, None),
#  ('155\xa0000', 'Сікорського', None, None, None),
#  ('84\xa0000', 'Курбаса', None, None, None),
#  ('73\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('83\xa0000', 'Драгомирова', None, None, None),
#  ('250\xa0000', None, None, None, None),
#  ('299\xa0000', 'Антонова', None, None, None),
#  ('56\xa0000', 'Бучми', None, None, None),
#  ('4\xa0335\xa0178',
#   'Кубанської України',
#   'Кубанської України',
#   'вулиця',
#   'Деснянський'),
#  ('270\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('58\xa0000', 'Панельна', None, None, None),
#  ('62\xa0000', 'Коновальця', None, None, None),
#  ('80\xa0000', 'Богатирська', 'Богатирська', 'вулиця', 'Оболонський'),
#  ('195\xa0000', 'Оболонський', 'Оболонський', 'проспект', 'Оболонський'),
#  ('3\xa0180\xa0495', 'Українки', None, None, None),
#  ('122\xa0000', 'Бориса Гмирі', None, None, None),
#  ('3\xa0793\xa0500', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('65\xa0000', 'Центральна', 'Центральна', 'вулиця', 'Дніпровський'),
#  ('65\xa0000', 'Центральна', 'Центральна', 'вулиця', 'Оболонський'),
#  ('65\xa0000', 'Центральна', 'Центральна', 'вулиця', 'Шевченківський'),
#  ('40\xa0500', 'Преображенська', 'Преображенська', 'вулиця', "Солом'янський"),
#  ('1\xa0181\xa0731', 'Коновальця', None, None, None),
#  ('69\xa0000', 'Українки', None, None, None),
#  ('75\xa0000', '*** not found', None, None, None),
#  ('155\xa0000',
#   'Велика Васильківська',
#   'Велика Васильківська',
#   'вулиця',
#   'Голосіївський, Шевченківський, Печерський'),
#  ('220\xa0000', 'Липківського', None, None, None),
#  ('51\xa0500', 'Бойчука', None, None, None),
#  ('73\xa0900', 'Васильківська', 'Васильківська', 'вулиця', 'Голосіївський'),
#  ('2\xa0458\xa0347', 'Данькевича', None, None, None),
#  ('1\xa0400\xa0000', 'Богатирська', 'Богатирська', 'вулиця', 'Оболонський'),
#  ('93\xa0950', 'Українки', None, None, None),
#  ('395\xa0000', 'Гречка', None, None, None),
#  ('179\xa0000', 'Редутна', 'Редутна', 'вулиця', 'Печерський'),
#  ('260\xa0000', 'Бориса Гмирі', None, None, None),
#  ('52\xa0000', 'Драгомирова', None, None, None),
#  ('395\xa0000', 'Туполєва', None, None, None),
#  ('198\xa0450', 'Кондратюка', None, None, None),
#  ('750\xa0000', 'Мінський', 'Мінський', 'провулок', 'Подільський'),
#  ('750\xa0000', 'Мінський', 'Мінський', 'проспект', 'Оболонський'),
#  ('650\xa0000', 'Княжий Затон', 'Княжий Затон', 'вулиця', 'Дарницький'),
#  ('75\xa0000', 'Герцена', 'Герцена', 'вулиця', 'Шевченківський'),
#  ('75\xa0000', 'Герцена', 'Герцена', 'провулок', 'Шевченківський'),
#  ('75\xa0000', 'Герцена', 'Герцена', 'узвіз', 'Шевченківський'),
#  ('150\xa0000', 'Балтійський', 'Балтійський', 'провулок', 'Оболонський'),
#  ('93\xa0900', 'Ернста', None, None, None),
#  ('120\xa0500', 'Шаповала', None, None, None),
#  ('129\xa0000', 'Городецького', None, None, None),
#  ('62\xa0000', "Сім'ї Сосніних", None, None, None),
#  ('150\xa0000', 'Івана Мазепи', None, None, None),
#  ('55\xa0000', 'Червоноткацька', None, None, None),
#  ('138\xa0000', '*** not found', None, None, None),
#  ('172\xa0000', 'Голосіївська', 'Голосіївська', 'вулиця', 'Голосіївський'),
#  ('172\xa0000', 'Голосіївська', 'Голосіївська', 'площа', 'Голосіївський'),
#  ('79\xa0900', '*** not found', None, None, None),
#  ('49\xa0999', 'Миколи Гулака', None, None, None),
#  ('115\xa0000', 'Івана Федорова', None, None, None),
#  ('87\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('107\xa0000', 'Миколи Хвильового', None, None, None),
#  ('87\xa0700', 'Паторжинського', 'Паторжинського', 'вулиця', 'Шевченківський'),
#  ('65\xa0000', 'Наумовича', None, None, None),
#  ('1\xa0250\xa0000', 'Калнишевського', None, None, None),
#  ('34\xa0700', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('67\xa0000', 'Електриків', 'Електриків', 'вулиця', 'Подільський'),
#  ('67\xa0000', 'Електриків', 'Електриків', 'провулок', 'Подільський'),
#  ('88\xa0000', "Солом'янська", "Солом'янська", 'вулиця', "Солом'янський"),
#  ('88\xa0000', "Солом'янська", "Солом'янська", 'площа', "Солом'янський"),
#  ('285\xa0000', 'Шевченка', 'Шевченка', 'вулиця', 'Дарницький'),
#  ('285\xa0000', 'Шевченка', 'Шевченка', 'вулиця', 'Деснянський'),
#  ('285\xa0000', 'Шевченка', 'Шевченка', 'вулиця', "Солом'янський"),
#  ('285\xa0000', 'Шевченка', 'Шевченка', 'провулок', 'Дарницький'),
#  ('285\xa0000', 'Шевченка', 'Шевченка', 'провулок', "Солом'янський"),
#  ('93\xa0000', 'Озерна', 'Озерна', 'вулиця', 'Дарницький'),
#  ('93\xa0000', 'Озерна', 'Озерна', 'вулиця', 'Оболонський'),
#  ('93\xa0000', 'Озерна', 'Озерна', 'вулиця', 'Святошинський (СТ "Нивки")'),
#  ('93\xa0000', 'Озерна', 'Озерна', 'вулиця', "Солом'янський"),
#  ('85\xa0000', 'Григоренка', None, None, None),
#  ('230\xa0000', 'Антонова', None, None, None),
#  ('155\xa0000', 'Голосіївський', 'Голосіївський', 'провулок', 'Голосіївський'),
#  ('155\xa0000', 'Голосіївський', 'Голосіївський', 'проспект', 'Голосіївський'),
#  ('180\xa0000', 'Комарова', None, None, None),
#  ('95\xa0000',
#   'Борщагівська',
#   'Борщагівська',
#   'вулиця',
#   "Солом'янський, Шевченківський "),
#  ('54\xa0934', 'Шевченка', 'Шевченка', 'вулиця', 'Дарницький'),
#  ('54\xa0934', 'Шевченка', 'Шевченка', 'вулиця', 'Деснянський'),
#  ('54\xa0934', 'Шевченка', 'Шевченка', 'вулиця', "Солом'янський"),
#  ('54\xa0934', 'Шевченка', 'Шевченка', 'провулок', 'Дарницький'),
#  ('54\xa0934', 'Шевченка', 'Шевченка', 'провулок', "Солом'янський"),
#  ('260\xa0000', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('145\xa0000', 'Ковальський', 'Ковальський', 'провулок', "Солом'янський"),
#  ('135\xa0000', 'Малевича', None, None, None),
#  ('50\xa0000', 'Мічуріна', 'Мічуріна', 'вулиця', 'Деснянський'),
#  ('50\xa0000', 'Мічуріна', 'Мічуріна', 'вулиця', 'Оболонський'),
#  ('50\xa0000', 'Мічуріна', 'Мічуріна', 'вулиця', 'Печерський'),
#  ('50\xa0000', 'Мічуріна', 'Мічуріна', 'вулиця', "Солом'янський"),
#  ('50\xa0000', 'Мічуріна', 'Мічуріна', 'провулок', 'Печерський'),
#  ('399\xa0000', '*** not found', None, None, None),
#  ('55\xa0000', 'Балтійський', 'Балтійський', 'провулок', 'Оболонський'),
#  ('270\xa0000',
#   'Азербайджанська',
#   'Азербайджанська',
#   'вулиця',
#   'Дніпровський'),
#  ('337\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('170\xa0000', 'Чавдар', None, None, None),
#  ('85\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('279\xa0000', 'Урлівська', 'Урлівська', 'вулиця', 'Дарницький'),
#  ('44\xa0000', 'Бориспільська', 'Бориспільська', 'вулиця', 'Дарницький'),
#  ('170\xa0000', 'Поправки', None, None, None),
#  ('88\xa0000', 'Бориспільська', 'Бориспільська', 'вулиця', 'Дарницький'),
#  ('41\xa0500', 'Ентузіастів', 'Ентузіастів', 'вулиця', 'Дніпровський'),
#  ('70\xa0000', 'Малоземельна', 'Малоземельна', 'вулиця', 'Дарницький'),
#  ('119\xa0900',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('86\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('138\xa0000', 'Зодчих', 'Зодчих', 'вулиця', 'Святошинський'),
#  ('240\xa0000', 'Калнишевського', None, None, None),
#  ('149\xa0500', 'Філатова', None, None, None),
#  ('1\xa0999\xa0600',
#   'Старонаводницька',
#   'Старонаводницька',
#   'вулиця',
#   'Печерський'),
#  ('67\xa0999', 'Заболотного', None, None, None),
#  ('41\xa0500', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('99\xa0000', '*** not found', None, None, None),
#  ('580\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('75\xa0000', 'Шаповала', None, None, None),
#  ('299\xa0000', 'Івана Федорова', None, None, None),
#  ('44\xa0000', 'Деревлянська', 'Деревлянська', 'вулиця', 'Шевченківський'),
#  ('139\xa0000', 'Вільямса', None, None, None),
#  ('150\xa0000', 'Васильченка', 'Васильченка', 'вулиця', "Солом'янський"),
#  ('45\xa0690', 'Предславинська', 'Предславинська', 'вулиця', 'Печерський'),
#  ('115\xa0000', 'Крайня', 'Крайня', 'вулиця', 'Деснянський'),
#  ('63\xa0500', 'Милославська', 'Милославська', 'вулиця', 'Деснянський'),
#  ('42\xa0000', 'Воскресенська', 'Воскресенська', 'вулиця', 'Дніпровський'),
#  ('56\xa0500', 'Маланюка', None, None, None),
#  ('66\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('103\xa0000', 'Пушкінська', 'Пушкінська', 'вулиця', 'Шевченківський'),
#  ('63\xa0000',
#   'Набережно-Корчуватська',
#   'Набережно-Корчуватська',
#   'вулиця',
#   'Голосіївський'),
#  ('228\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('90\xa0000', 'Тургенєвська', 'Тургенєвська', 'вулиця', 'Шевченківський'),
#  ('87\xa0000', 'Радченка', None, None, None),
#  ('62\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('77\xa0000', 'Метрологічна', 'Метрологічна', 'вулиця', 'Голосіївський'),
#  ('179\xa0900', 'Йорданська', 'Йорданська', 'вулиця', 'Оболонський'),
#  ('49\xa0000', 'Кольцова', 'Кольцова', 'бульвар', 'Святошинський'),
#  ('105\xa0900', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('500\xa0000', 'Науки', 'Науки', 'проспект', 'Голосіївський'),
#  ('38\xa0000',
#   'Саперно-Слобідська',
#   'Саперно-Слобідська',
#   'вулиця',
#   'Голосіївський'),
#  ('130\xa0000', 'Шовковична', 'Шовковична', 'вулиця', 'Печерський'),
#  ('230\xa0000', 'Трускавецька', 'Трускавецька', 'вулиця', 'Дарницький'),
#  ('66\xa0800', 'Гавела', None, None, None),
#  ('125\xa0000',
#   'Повітрофлотський',
#   'Повітрофлотський',
#   'проспект',
#   "Шевченківський, Солом'янський"),
#  ('113\xa0000', 'Запорожця', None, None, None),
#  ('93\xa0000', 'Маккейна', None, None, None),
#  ('422\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('422\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('422\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('80\xa0500', 'Щербаківського', None, None, None),
#  ('123\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('200\xa0000', 'Будищанська', 'Будищанська', 'вулиця', 'Деснянський'),
#  ('52\xa0000',
#   'Жилянська',
#   'Жилянська',
#   'вулиця',
#   'Печерський, Голосіївський, Шевченківський'),
#  ('360\xa0000', 'Комбінатна', 'Комбінатна', 'вулиця', 'Дніпровський'),
#  ('102\xa0000', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('77\xa0000', 'Бородіна', None, None, None),
#  ('125\xa0000', 'Руставелі', None, None, None),
#  ('84\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('185\xa0000', 'Преображенська', 'Преображенська', 'вулиця', "Солом'янський"),
#  ('888\xa0189', 'Депутатська', 'Депутатська', 'вулиця', 'Святошинський'),
#  ('45\xa0142', 'Багговутівська', 'Багговутівська', 'вулиця', 'Шевченківський'),
#  ('980\xa0000', '*** not found', None, None, None),
#  ('180\xa0000', 'Сікорського', None, None, None),
#  ('40\xa0000', 'Драгомирова', None, None, None),
#  ('110\xa0000', 'Коперніка', 'Коперніка', 'вулиця', 'Шевченківський'),
#  ('3\xa0600\xa0804',
#   'Васильківська',
#   'Васильківська',
#   'вулиця',
#   'Голосіївський'),
#  ('165\xa0000', 'Глибочицька', 'Глибочицька', 'вулиця', 'Шевченківський'),
#  ('92\xa0550', 'Чавдар', None, None, None),
#  ('80\xa0000', 'Шовковична', 'Шовковична', 'вулиця', 'Печерський'),
#  ('115\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('4\xa0335\xa0178',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('155\xa0000', None, None, None, None),
#  ('220\xa0000', 'Славгородська', 'Славгородська', 'вулиця', 'Дарницький'),
#  ('95\xa0000', 'Драгомирова', None, None, None),
#  ('115\xa0000', 'Срібнокільська', 'Срібнокільська', 'вулиця', 'Дарницький'),
#  ('1\xa0750\xa0000', 'Харченка', None, None, None),
#  ('240\xa0000', 'Окіпної', None, None, None),
#  ('1\xa0158\xa0740', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('170\xa0000', 'Олени Теліги', None, None, None),
#  ('93\xa0000', 'Кондратюка', None, None, None),
#  ('145\xa0000', 'Мечнікова', 'Мечнікова', 'вулиця', 'Печерський'),
#  ('47\xa0211',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('81\xa0000', 'Рибальська', 'Рибальська', 'вулиця', 'Печерський'),
#  ('750\xa0000', 'Березова', 'Березова', 'вулиця', "Солом'янський"),
#  ('84\xa0950', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('190\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('85\xa0000', 'Маккейна', None, None, None),
#  ('211\xa0000', 'Лейпцизька', 'Лейпцизька', 'вулиця', 'Печерський'),
#  ('136\xa0279', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('71\xa0000', 'Коновальця', None, None, None),
#  ('95\xa0000', 'Василя Стуса', None, None, None),
#  ('120\xa0000', 'Тютюнника', None, None, None),
#  ('335\xa0000',
#   'Січових Стрільців',
#   'Січових Стрільців',
#   'вулиця',
#   'Шевченківський'),
#  ('38\xa0500', 'Райдужна', 'Райдужна', 'вулиця', 'Дніпровський'),
#  ('47\xa0000', 'Закревського', None, None, None),
#  ('105\xa0000', 'Тургенєвська', 'Тургенєвська', 'вулиця', 'Шевченківський'),
#  ('163\xa0000', 'Васильківська', 'Васильківська', 'вулиця', 'Голосіївський'),
#  ('1\xa0500\xa0000', "Зої Космодем'янської", None, None, None),
#  ('49\xa0000', 'Радченка', None, None, None),
#  ('100\xa0000', 'Сверстюка', None, None, None),
#  ('130\xa0000', 'Милославська', 'Милославська', 'вулиця', 'Деснянський'),
#  ('2\xa0688\xa0000',
#   'Метрологічна',
#   'Метрологічна',
#   'вулиця',
#   'Голосіївський'),
#  ('52\xa0600', 'Деміївська', 'Деміївська', 'вулиця', 'Голосіївський'),
#  ('52\xa0600', 'Деміївська', 'Деміївська', 'площа', 'Голосіївський'),
#  ('39\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('39\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('39\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('110\xa0000',
#   'Вишгородська',
#   'Вишгородська',
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('135\xa0000', 'Маккейна', None, None, None),
#  ('139\xa0860', None, None, None, None),
#  ('70\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('70\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('70\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('95\xa0000', 'Балтійський', 'Балтійський', 'провулок', 'Оболонський'),
#  ('155\xa0000', 'Звіринецька', 'Звіринецька', 'вулиця', 'Печерський'),
#  ('56\xa0850', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('140\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('110\xa0000', 'Милославська', 'Милославська', 'вулиця', 'Деснянський'),
#  ('145\xa0000', 'Вербицького', None, None, None),
#  ('280\xa0000', 'Новгородська', 'Новгородська', 'вулиця', "Солом'янський"),
#  ('270\xa0000', 'Бажана', None, None, None),
#  ('50\xa0500', 'Канівська', 'Канівська', 'вулиця', 'Подільський'),
#  ('39\xa0000', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('490\xa0000', 'Донця', None, None, None),
#  ('34\xa0988', 'Драгомирова', None, None, None),
#  ('311\xa0000', 'Тираспольська', 'Тираспольська', 'вулиця', 'Подільський'),
#  ('65\xa0000',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('169\xa0000', 'Тираспольська', 'Тираспольська', 'вулиця', 'Подільський'),
#  ('70\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('103\xa0000', 'Гонгадзе', None, None, None),
#  ('140\xa0000', 'Українки', None, None, None),
#  ('116\xa0500', 'Світлицького', 'Світлицького', 'вулиця', 'Подільський'),
#  ('107\xa0000', 'Воробйова', None, None, None),
#  ('77\xa0000', 'Каховська', 'Каховська', 'вулиця', 'Дніпровський'),
#  ('165\xa0000', 'Глибочицька', 'Глибочицька', 'вулиця', 'Шевченківський'),
#  ('450\xa0000', 'Білокур', None, None, None),
#  ('195\xa0000', 'Балтійський', 'Балтійський', 'провулок', 'Оболонський'),
#  ('480\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('120\xa0000', 'Кондратюка', None, None, None),
#  ('58\xa0000', 'Гончара', None, None, None),
#  ('1\xa0500\xa0000', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('345\xa0700', '*** not found', None, None, None),
#  ('126\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('158\xa0000', 'Сім’ї Кульженків', None, None, None),
#  ('206\xa0315', 'Панельна', None, None, None),
#  ('33\xa0000', 'Вільямса', None, None, None),
#  ('250\xa0000', 'Голосіївська', 'Голосіївська', 'вулиця', 'Голосіївський'),
#  ('250\xa0000', 'Голосіївська', 'Голосіївська', 'площа', 'Голосіївський'),
#  ('63\xa0500', 'Оболонський', 'Оболонський', 'проспект', 'Оболонський'),
#  ('2\xa0100\xa0000',
#   'Миколи Голего',
#   'Миколи Голего',
#   'вулиця',
#   "Солом'янський"),
#  ('1\xa0180\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('42\xa0000', 'Малиновського', None, None, None),
#  ('146\xa0000', 'Назарівська', 'Назарівська', 'вулиця', 'Шевченківський'),
#  ('299\xa0000', 'Гоголівська', 'Гоголівська', 'вулиця', 'Шевченківський'),
#  ('141\xa0000', 'Дорогожицька', 'Дорогожицька', 'вулиця', 'Шевченківський'),
#  ('41\xa0000', 'Петропавлівська', 'Петропавлівська', 'вулиця', 'Подільський'),
#  ('41\xa0000', 'Петропавлівська', 'Петропавлівська', 'площа', 'Оболонський'),
#  ('115\xa0000', 'Грушевського', None, None, None),
#  ('81\xa0000', 'Іллєнка', None, None, None),
#  ('103\xa0950', 'Липківського', None, None, None),
#  ('1\xa0468\xa0067', 'Ушинського', 'Ушинського', 'вулиця', "Солом'янський"),
#  ('1\xa0468\xa0067', 'Ушинського', 'Ушинського', 'провулок', "Солом'янський"),
#  ('68\xa0000', 'Польова', 'Польова', 'вулиця', 'Дарницький'),
#  ('68\xa0000', 'Польова', 'Польова', 'вулиця', 'Деснянський'),
#  ('68\xa0000', 'Польова', 'Польова', 'вулиця', "Солом'янський"),
#  ('80\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('112\xa0000', 'Панельна', None, None, None),
#  ('319\xa0000', 'Коновальця', None, None, None),
#  ('98\xa0000', 'Хмельницького', None, None, None),
#  ('50\xa0000', 'Маккейна', None, None, None),
#  ('49\xa0990',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('89\xa0500', 'Толстого', 'Толстого', 'провулок', 'Дарницький'),
#  ('350\xa0000', 'Дружби Народів', 'Дружби Народів', 'бульвар', 'Печерський'),
#  ('210\xa0000', 'Оболонський', 'Оболонський', 'проспект', 'Оболонський'),
#  ('345\xa0000',
#   'Багговутівська',
#   'Багговутівська',
#   'вулиця',
#   'Шевченківський'),
#  ('90\xa0000', 'Антонова', None, None, None),
#  ('170\xa0000',
#   'Володимирська',
#   'Володимирська',
#   'вулиця',
#   'Голосіївський, Шевченківський'),
#  ('110\xa0000', 'Українки', None, None, None),
#  ('59\xa0000', 'Сім’ї Кульженків', None, None, None),
#  ('145\xa0000', 'Коновальця', None, None, None),
#  ('79\xa0000', 'Мирного', None, None, None),
#  ('375\xa0000', 'Московська', 'Московська', 'вулиця', 'Печерський'),
#  ('375\xa0000', 'Московська', 'Московська', 'вулиця', "Солом'янський"),
#  ('122\xa0000', 'Жмеринська', 'Жмеринська', 'вулиця', 'Святошинський'),
#  ('255\xa0000', 'Бойчука', None, None, None),
#  ('85\xa0000', 'Липківського', None, None, None),
#  ('240\xa0800', 'Лабораторний', 'Лабораторний', 'провулок', 'Печерський'),
#  ('455\xa0000', 'Інститутська', 'Інститутська', 'вулиця', 'Печерський'),
#  ('165\xa0000', 'Українки', None, None, None),
#  ('100\xa0000',
#   'Хрещатик',
#   'Хрещатик',
#   'вулиця',
#   'Печерський, Шевченківський'),
#  ('195\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('41\xa0000', 'Осокорська', 'Осокорська', 'вулиця', 'Дарницький'),
#  ('70\xa0000', 'Саперне Поле', 'Саперне Поле', 'вулиця', 'Печерський'),
#  ('71\xa0400', 'Комарова', None, None, None),
#  ('3\xa0711\xa0865', 'Драгомирова', None, None, None),
#  ('60\xa0000', 'Срібнокільська', 'Срібнокільська', 'вулиця', 'Дарницький'),
#  ('240\xa0000', 'Чоколівський', 'Чоколівський', 'бульвар', "Солом'янський"),
#  ('260\xa0000', 'Звіринецька', 'Звіринецька', 'вулиця', 'Печерський'),
#  ('127\xa0000',
#   'Вишгородська',
#   'Вишгородська',
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('40\xa0000', 'Драгомирова', None, None, None),
#  ('1\xa0796\xa0439',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('3\xa0400\xa0000',
#   'Будівельників',
#   'Будівельників',
#   'вулиця',
#   'Деснянський'),
#  ('3\xa0400\xa0000',
#   'Будівельників',
#   'Будівельників',
#   'вулиця',
#   'Дніпровський'),
#  ('3\xa0400\xa0000',
#   'Будівельників',
#   'Будівельників',
#   'провулок',
#   'Дніпровський'),
#  ('3\xa0400\xa0000',
#   'Будівельників',
#   'Будівельників',
#   'провулок',
#   'Святошинський'),
#  ('44\xa0500', 'Іллєнка', None, None, None),
#  ('125\xa0000', 'Урлівська', 'Урлівська', 'вулиця', 'Дарницький'),
#  ('51\xa0000', 'Сормовська', 'Сормовська', 'вулиця', 'Дарницький'),
#  ('1\xa0707\xa0790', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('65\xa0000', 'Верховинна', 'Верховинна', 'вулиця', 'Святошинський'),
#  ('55\xa0000', 'Вербицького', None, None, None),
#  ('94\xa0500', '*** not found', None, None, None),
#  ('115\xa0000',
#   'Велика Васильківська',
#   'Велика Васильківська',
#   'вулиця',
#   'Голосіївський, Шевченківський, Печерський'),
#  ('45\xa0000', 'Бойчука', None, None, None),
#  ('85\xa0000', 'Лобановського', None, None, None),
#  ('5\xa0204\xa0750', 'Миколи Шепелєва', None, None, None),
#  ('84\xa0500', 'Кропивницького', 'Кропивницького', 'вулиця', 'Печерський'),
#  ('350\xa0000', 'Трускавецька', 'Трускавецька', 'вулиця', 'Дарницький'),
#  ('182\xa0000', 'Голосіївська', 'Голосіївська', 'вулиця', 'Голосіївський'),
#  ('182\xa0000', 'Голосіївська', 'Голосіївська', 'площа', 'Голосіївський'),
#  ('188\xa0999', 'Маланюка', None, None, None),
#  ('147\xa0000', 'Драгомирова', None, None, None),
#  ('89\xa0900', 'Юнацька', 'Юнацька', 'вулиця', 'Святошинський'),
#  ('89\xa0900', 'Юнацька', 'Юнацька', 'вулиця', "Солом'янський"),
#  ('66\xa0900', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('75\xa0000', 'Комарова', None, None, None),
#  ('58\xa0000', 'Багговутівська', 'Багговутівська', 'вулиця', 'Шевченківський'),
#  ('140\xa0000', None, None, None, None),
#  ('82\xa0000', 'Костанайська', 'Костанайська', 'вулиця', 'Голосіївський'),
#  ('215\xa0000', 'Срібнокільська', 'Срібнокільська', 'вулиця', 'Дарницький'),
#  ('33\xa0400', 'Курчатова', None, None, None),
#  ('100\xa0000', 'Гусовського', 'Гусовського', 'вулиця', 'Печерський'),
#  ('240\xa0000', 'Українки', None, None, None),
#  ('62\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('115\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('143\xa0560', 'Заболотного', None, None, None),
#  ('130\xa0000', 'Заболотного', None, None, None),
#  ('152\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('152\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('152\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('33\xa0800', 'Сверстюка', None, None, None),
#  ('55\xa0000', 'Липківського', None, None, None),
#  ('110\xa0000', 'Маккейна', None, None, None),
#  ('200\xa0000', 'Дніпровська', 'Дніпровська', 'вулиця', 'Оболонський'),
#  ('70\xa0000', 'Волгоградська', 'Волгоградська', 'вулиця', "Солом'янський"),
#  ('70\xa0000', 'Волгоградська', 'Волгоградська', 'площа', 'Деснянський'),
#  ('160\xa0888', 'Новопольова', 'Новопольова', 'вулиця', "Солом'янський"),
#  ('189\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('135\xa0000', 'Лебедєва', None, None, None),
#  ('215\xa0000', '*** not found', None, None, None),
#  ('102\xa0000', 'Драгомирова', None, None, None),
#  ('193\xa0750', 'Лейпцизька', 'Лейпцизька', 'вулиця', 'Печерський'),
#  ('54\xa0000', 'Глибочицька', 'Глибочицька', 'вулиця', 'Шевченківський'),
#  ('70\xa0000', 'Салютна', 'Салютна', 'вулиця', 'Шевченківський'),
#  ('3\xa0180\xa0495',
#   'Метрологічна',
#   'Метрологічна',
#   'вулиця',
#   'Голосіївський'),
#  ('50\xa0500',
#   'Північно-Сирецька',
#   'Північно-Сирецька',
#   'вулиця',
#   'Подільський'),
#  ('57\xa0000', 'Правди', 'Правди', 'проспект', 'Подільський'),
#  ('130\xa0000', 'Вернадського', None, None, None),
#  ('262\xa0000', 'Пчілки', None, None, None),
#  ('66\xa0000', 'Лейпцизька', 'Лейпцизька', 'вулиця', 'Печерський'),
#  ('3\xa0249\xa0056',
#   'Басейна',
#   'Басейна',
#   'вулиця',
#   'Печерський, Шевченківський'),
#  ('2\xa0000\xa0000', 'Шаповала', None, None, None),
#  ('78\xa0000', 'Бережанська', 'Бережанська', 'вулиця', 'Оболонський'),
#  ('90\xa0500', 'Бойчука', None, None, None),
#  ('80\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('80\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('80\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('906\xa0080', 'Івана Федорова', None, None, None),
#  ('4\xa0500\xa0000',
#   'Антоновича',
#   'Антоновича',
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('32\xa0000', 'Вільямса', None, None, None),
#  ('190\xa0000', 'Бойчука', None, None, None),
#  ('220\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('220\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('220\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('110\xa0000', 'Ковпака', 'Ковпака', 'вулиця', 'Голосіївський, Печерський'),
#  ('43\xa0000', 'Русанівський', 'Русанівський', 'бульвар', 'Дніпровський'),
#  ('983\xa0253', 'Українки', None, None, None),
#  ('65\xa0000', 'Празька', 'Празька', 'вулиця', 'Дніпровський'),
#  ('110\xa0000', 'Гончара', None, None, None),
#  ('150\xa0000', 'Маккейна', None, None, None),
#  ('125\xa0500', 'Балтійський', 'Балтійський', 'провулок', 'Оболонський'),
#  ('200\xa0000', 'Білоруська', 'Білоруська', 'вулиця', 'Шевченківський'),
#  ('480\xa0000', 'Драгоманова', 'Драгоманова', 'вулиця', 'Дарницький'),
#  ('235\xa0000', 'Липківського', None, None, None),
#  ('82\xa0000', 'Новогоспітальна', 'Новогоспітальна', 'вулиця', 'Печерський'),
#  ('121\xa0975', 'Радченка', None, None, None),
#  ('200\xa0000', 'Богомольця', None, None, None),
#  ('250\xa0000', 'Донця', None, None, None),
#  ('205\xa0000', 'Оболонський', 'Оболонський', 'проспект', 'Оболонський'),
#  ('76\xa0466', 'Щекавицька', 'Щекавицька', 'вулиця', 'Подільський'),
#  ('76\xa0466', 'Щекавицька', 'Щекавицька', 'площа', 'Подільський'),
#  ('240\xa0000', 'Пожарського', 'Пожарського', 'вулиця', 'Деснянський'),
#  ('240\xa0000', 'Пожарського', 'Пожарського', 'вулиця', 'Дніпровський'),
#  ('150\xa0000', 'Полкова', 'Полкова', 'вулиця', 'Подільський'),
#  ('69\xa0000', 'Донця', None, None, None),
#  ('74\xa0900', 'Палладіна', None, None, None),
#  ('1\xa0350\xa0000', 'Бойчука', None, None, None),
#  ('386\xa0000', 'Липківського', None, None, None),
#  ('31\xa0500', 'Павлівська', 'Павлівська', 'вулиця', 'Шевченківський'),
#  ('58\xa0000', 'Івашкевича', None, None, None),
#  ('115\xa0000', 'Іскрівська', 'Іскрівська', 'вулиця', "Солом'янський"),
#  ('64\xa0999', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('69\xa0900', '*** not found', None, None, None),
#  ('220\xa0000', 'Драгомирова', None, None, None),
#  ('2\xa0873\xa0080',
#   'Теремківська',
#   'Теремківська',
#   'вулиця',
#   'Голосіївський'),
#  ('186\xa0000', 'Осокорська', 'Осокорська', 'вулиця', 'Дарницький'),
#  ('43\xa0000', 'Дмитрівська', 'Дмитрівська', 'вулиця', 'Подільський'),
#  ('43\xa0000', 'Дмитрівська', 'Дмитрівська', 'вулиця', 'Шевченківський'),
#  ('55\xa0000', 'Кондратюка', None, None, None),
#  ('193\xa0750', 'Регенераторна', 'Регенераторна', 'вулиця', 'Дніпровський'),
#  ('100\xa0999', None, None, None, None),
#  ('11\xa0017\xa0941',
#   'Глибочицька',
#   'Глибочицька',
#   'вулиця',
#   'Шевченківський'),
#  ('149\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('3\xa0600\xa0804',
#   'Борщагівська',
#   'Борщагівська',
#   'вулиця',
#   "Солом'янський, Шевченківський "),
#  ('45\xa0000', 'Ревуцького', 'Ревуцького', 'вулиця', 'Дарницький'),
#  ('92\xa0000', 'Юнацька', 'Юнацька', 'вулиця', 'Святошинський'),
#  ('92\xa0000', 'Юнацька', 'Юнацька', 'вулиця', "Солом'янський"),
#  ('295\xa0000', 'Заболотного', None, None, None),
#  ('39\xa0900', 'Автозаводська', 'Автозаводська', 'вулиця', 'Оболонський'),
#  ('215\xa0000', 'Заболотного', None, None, None),
#  ('2\xa0458\xa0347',
#   'Саксаганського',
#   'Саксаганського',
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('138\xa0000', 'Зарічна', 'Зарічна', 'вулиця', 'Дарницький'),
#  ('50\xa0000', '*** not found', None, None, None),
#  ('92\xa0284', 'Невська', None, None, None),
#  ('140\xa0000',
#   'Героїв Сталінграда',
#   'Героїв Сталінграда',
#   'проспект',
#   'Оболонський'),
#  ('3\xa0707\xa0378', 'Вишняківська', 'Вишняківська', 'вулиця', 'Дарницький'),
#  ('94\xa0000', 'Драгомирова', None, None, None),
#  ('45\xa0000', 'Драгомирова', None, None, None),
#  ('56\xa0000', 'Гавела', None, None, None),
#  ('140\xa0000', 'Здолбунівська', 'Здолбунівська', 'вулиця', 'Дарницький'),
#  ('90\xa0000', 'Драгомирова', None, None, None),
#  ('159\xa0000', 'Мечнікова', 'Мечнікова', 'вулиця', 'Печерський'),
#  ('1\xa0848\xa0450', '*** not found', None, None, None),
#  ('106\xa0000', 'Максимовича', 'Максимовича', 'вулиця', 'Святошинський'),
#  ('170\xa0000',
#   'Багговутівська',
#   'Багговутівська',
#   'вулиця',
#   'Шевченківський'),
#  ('91\xa0000', 'Шолуденка', 'Шолуденка', 'вулиця', 'Шевченківський'),
#  ('110\xa0000', 'Щекавицька', 'Щекавицька', 'вулиця', 'Подільський'),
#  ('110\xa0000', 'Щекавицька', 'Щекавицька', 'площа', 'Подільський'),
#  ('65\xa0000', 'Коласа', None, None, None),
#  ('260\xa0000', '*** not found', None, None, None),
#  ('125\xa0000', '*** not found', None, None, None),
#  ('65\xa0000', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('65\xa0000', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('65\xa0000',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('158\xa0000', '*** not found', None, None, None),
#  ('80\xa0000', 'Наумова', None, None, None),
#  ('68\xa0900', 'Перемоги', 'Перемоги', 'вулиця', 'Святошинський'),
#  ('68\xa0900', 'Перемоги', 'Перемоги', 'площа', 'Шевченківський'),
#  ('68\xa0900',
#   'Перемоги',
#   'Перемоги',
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('168\xa0000',
#   'Велика Васильківська',
#   'Велика Васильківська',
#   'вулиця',
#   'Голосіївський, Шевченківський, Печерський'),
#  ('41\xa0000', 'Червоноткацька', None, None, None),
#  ('134\xa0900',
#   'Вишгородська',
#   'Вишгородська',
#   'вулиця',
#   'Подільський, Оболонський')]

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = напишить код ..

# %%
# виконати запит на заповнення
cur.execute(stmt_insert)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = напишить код ...

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = напишить код ...

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : напишить код ... ,
    "середнє значення"         : напишить код ... ,
    "максимальне значення"     : напишить код ... ,
    "мінімальне значення"      : напишить код ... ,
    "стандартне відхилення"    : напишить код ... ,
    "розмах вариації"          : напишить код ...
    }

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
напишить код ...
