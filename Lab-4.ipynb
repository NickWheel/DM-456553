# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-64a8289b2d8e> in <module>
#       1 # створимо інстанс для операції `SELECT`
# ----> 2 students_cur = cur.execute("SELECT * FROM jornal")
#       3
#       4 # будуємо список записів за допомогою метода `fetchall()`
#       5 students_list = students_cur.fetchall()
#
# OperationalError: no such table: jornal

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('jornal_test',)]

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test.\"Оцінка/100\" FROM  \
            jornal LEFT JOIN test ON jornal.Surname = test.\"Ім\'я\" "

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-6ca9d9ffa997> in <module>
#       4
#       5 # для перевірки виконаємо і виведемо результати запиту
# ----> 6 cur.execute(sql_stmt).fetchall()
#
# OperationalError: no such table: jornal

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# %%
result_dict

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %%
Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.

__Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.). 
Необхідно:
1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються) 
3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

YOUR_FILE = 'aprt_total_price.txt'
with open(YOUR_FILE) as f1, \
     open('street_name.csv') as f2, \
     open('street_flat_property.csv', 'w') as f3:
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# price,street
#
# 115000.0,Омеляновича-Павленка
#
# 75000.0,
#
# 140000.0,Ованеса Туманяна
#
# 140000.0,Петропавлівська
#
# 160000.0,Дніпровська
#
# 870000.0,Саксаганського
#
# 14883863.0,Івана Мазепи
#
# 220000.0,Дніпровська
#
# 133000.0,Ділова
#
# 69000.0,Новодарницька
#
# 169999.0,Ревуцького
#
# 212000.0,Липківського
#
# 83500.0,Бендукідзе
#
# 75000.0,Введенська
#
# 65000.0,Виноградний
#
# 82000.0,Кайсарова
#
# 207000.0,Ахматової
#
# 51990.0,Радченка
#
# 57999.0,Дніпровська
#
# 57000.0,Ділова
#
# 95000.0,Бориспільська
#
# 50000.0,Болсуновська
#
# 95000.0,Українки
#
# 46860.0,Антонова
#
# 38500.0,Омеляновича-Павленка
#
# 110000.0,
#
# 269000.0,Ованеса Туманяна
#
# 1983000.0,Петропавлівська
#
# 119000.0,Дніпровська
#
# 210000.0,Саксаганського
#
# 310000.0,Івана Мазепи
#
# 93000.0,Дніпровська
#
# 98000.0,Ділова
#
# 78000.0,Новодарницька
#
# 68000.0,Ревуцького
#
# 77000.0,Липківського
#
# 176000.0,Бендукідзе
#
# 5572000.0,Введенська
#
# 129000.0,Виноградний
#
# 136000.0,Кайсарова
#
# 71000.0,Ахматової
#
# 108000.0,Радченка
#
# 175000.0,Дніпровська
#
# 45006.0,Ділова
#
# 78000.0,Бориспільська
#
# 65000.0,Болсуновська
#
# 3396000.0,Українки
#
# 68899.0,Антонова
#
# 205000.0,Науки
#
# 211000.0,Метрологічна
#
# 36500.0,Дружби Народів
#
# 3176715.0,*** not found
#
# 155000.0,Драгомирова
#
# 109000.0,Данченка
#
# 120000.0,Кримська
#
# 55000.0,Новопольова
#
# 48000.0,Туполєва
#
# 235000.0,*** not found
#
# 41000.0,Дніпровська
#
# 143000.0,Перемоги
#
# 65000.0,Івана Федорова
#
# 500000.0,Братиславська
#
# 94000.0,*** not found
#
# 280000.0,Червоноткацька
#
# 67500.0,Златоустівська
#
# 72000.0,Бойченка
#
# 54000.0,Трускавецька
#
# 74000.0,Каховська
#
# 130000.0,Лобановського
#
# 110000.0,*** not found
#
# 180000.0,Курчатова
#
# 69000.0,Голосіївська
#
# 205000.0,Тираспольська
#
# 211000.0,Лаврська
#
# 36500.0,Правди
#
# 3176715.0,Миколайчука
#
# 155000.0,Порика
#
# 109000.0,Червоноткацька
#
# 120000.0,Маккейна
#
# 55000.0,Йорданська
#
# 48000.0,Тютюнника
#
# 235000.0,Регенераторна
#
# 41000.0,Зарічна
#
# 143000.0,Заболотного
#
# 65000.0,Курнатовського
#
# 500000.0,Інститутська
#
# 94000.0,Маланюка
#
# 280000.0,Гречка
#
# 67500.0,Липківського
#
# 72000.0,Маккейна
#
# 54000.0,Григоренка
#
# 74000.0,Коновальця
#
# 130000.0,Закревського
#
# 110000.0,*** not found
#
# 180000.0,Старонаводницька
#
# 69000.0,Маланюка
#
# 120000.0,Заньковецької
#
# 150000.0,Кудрявська
#
# 750000.0,
#
# 75000.0,Українки
#
# 53000.0,
#
# 42500.0,Милославська
#
# 103000.0,Донця
#
# 650000.0,Верховинця
#
# 56000.0,Героїв Дніпра
#
# 90000.0,Каховська
#
# 77000.0,Каховська
#
# 115000.0,Вишняківська
#
# 120000.0,Липська
#
# 130000.0,Сверстюка
#
# 85000.0,Драгомирова
#
# 140000.0,Причальна
#
# 45500.0,Болсуновська
#
# 63232.0,Повітрофлотський
#
# 95000.0,Драгоманова
#
# 55000.0,Григоренка
#
# 186900.0,Дніпровська
#
# 34200.0,Жабаєва
#
# 234899.0,Філатова
#
# 55000.0,Правди
#
# 136000.0,Малопідвальна
#
# 139000.0,Бойчука
#
# 210000.0,Зарічна
#
# 195000.0,Предславинська
#
# 119000.0,Івана Мазепи
#
# 410000.0,Радченка
#
# 93000.0,Лабораторний
#
# 137634.0,Конєва
#
# 115000.0,Шаповала
#
# 85000.0,Дніпровська
#
# 130000.0,Клеманська
#
# 113000.0,Григоренка
#
# 39500.0,Туполєва
#
# 68000.0,Хмельницького
#
# 155000.0,Саперне Поле
#
# 110000.0,Героїв Сталінграда
#
# 75000.0,Дніпровська
#
# 142000.0,Тарасівська
#
# 80000.0,Краківська
#
# 43000.0,Юнацька
#
# 248000.0,Клеманська
#
# 280000.0,Героїв Сталінграда
#
# 209000.0,Драгомирова
#
# 58990.0,*** not found
#
# 111000.0,Драгоманова
#
# 97000.0,Українки
#
# 68000.0,Тимошенка
#
# 184900.0,Маяковського
#
# 61500.0,Дмитрівська
#
# 111000.0,Курбаса
#
# 190700.0,Комарова
#
# 53000.0,Драгоманова
#
# 69000.0,Драгомирова
#
# 169000.0,Моторний
#
# 95000.0,Милославська
#
# 110000.0,Бойчука
#
# 5880000.0,Закревського
#
# 99999.0,Івана Федорова
#
# 327000.0,Філатова
#
# 85000.0,Перемоги
#
# 790000.0,Миропільська
#
# 95000.0,Григоренка
#
# 70000.0,Юнацька
#
# 2352122.0,Вишгородська
#
# 807000.0,Жолудєва
#
# 77000.0,Павлівська
#
# 75000.0,Голосіївський
#
# 480000.0,Осокорська
#
# 70000.0,Вишгородська
#
# 205000.0,Драгомирова
#
# 499990.0,Тютюнника
#
# 52000.0,Маккейна
#
# 93000.0,Івана Мазепи
#
# 117000.0,Героїв Сталінграда
#
# 53900.0,Липківського
#
# 58000.0,*** not found
#
# 159000.0,Коновальця
#
# 116000.0,Максимовича
#
# 42000.0,Зарічна
#
# 55500.0,Голосіївська
#
# 370000.0,Ясинуватський
#
# 650000.0,*** not found
#
# 355000.0,Колоса
#
# 145000.0,Правди
#
# 117000.0,Велика Васильківська
#
# 300000.0,Голосіївський
#
# 55000.0,*** not found
#
# 41000.0,Бойчука
#
# 128000.0,Центральна
#
# 175000.0,Ясинуватський
#
# 783000.0,Райдужна
#
# 90000.0,Ломоносова
#
# 98000.0,
#
# 137000.0,*** not found
#
# 45000.0,Гусовського
#
# 2015228.0,Окіпної
#
# 200000.0,Багговутівська
#
# 147000.0,Дружби Народів
#
# 78000.0,Маккейна
#
# 82000.0,Маланюка
#
# 75000.0,Михайла Котельникова
#
# 89000.0,Героїв Севастополя
#
# 710000.0,Маланюка
#
# 620000.0,Саперне Поле
#
# 69500.0,Балтійський
#
# 85000.0,Кудрявська
#
# 43000.0,Перемоги
#
# 330000.0,Німанська
#
# 59000.0,Каховська
#
# 40000.0,Малопідвальна
#
# 1200000.0,Невська
#
# 405000.0,Златоустівська
#
# 100110.0,
#
# 400000.0,Берковецька
#
# 97500.0,Бажана
#
# 83000.0,Антоновича
#
# 44000.0,*** not found
#
# 66000.0,Гречка
#
# 350000.0,Микільсько-Слобідська
#
# 77000.0,Правди
#
# 122250.0,Тимошенка
#
# 65000.0,Павла Тичини
#
# 170000.0,Олевська
#
# 95000.0,Освіти
#
# 85000.0,Іллєнка
#
# 69500.0,Дніпровська
#
# 152000.0,Івана Мазепи
#
# 92000.0,Українки
#
# 375000.0,Данченка
#
# 449000.0,Драгомирова
#
# 75500.0,Тбіліський
#
# 140000.0,Каховська
#
# 45000.0,Ушинського
#
# 135000.0,Урлівська
#
# 125000.0,Світлицького
#
# 140000.0,Дніпровська
#
# 120000.0,Липківського
#
# 42000.0,Микільсько-Слобідська
#
# 125000.0,Лобановського
#
# 48000.0,Героїв Сталінграда
#
# 300000.0,Дніпровська
#
# 120000.0,Драгоманова
#
# 649000.0,Ахматової
#
# 64980.0,Саперне Поле
#
# 77000.0,Данченка
#
# 48000.0,Голосіївський
#
# 102000.0,*** not found
#
# 185000.0,Глибочицька
#
# 42000.0,Багговутівська
#
# 115000.0,Саксаганського
#
# 175000.0,Моторний
#
# 54000.0,Йорданська
#
# 10116000.0,Саперне Поле
#
# 137000.0,Вернадського
#
# 95000.0,Курбаса
#
# 360000.0,Багговутівська
#
# 135000.0,Набережно-Рибальська
#
# 105000.0,Саксаганського
#
# 58000.0,Малиновського
#
# 180000.0,Протасів Яр
#
# 153000.0,Німанська
#
# 159000.0,Підвисоцького
#
# 98000.0,Зодчих
#
# 1200000.0,Рокосовського
#
# 42900.0,Шовковична
#
# 86000.0,Крушельницької
#
# 155000.0,Новопольова
#
# 450000.0,Визволителів
#
# 148000.0,Сонячна
#
# 50000.0,Сікорського
#
# 81000.0,Радченка
#
# 161003.0,Бульварно-Кудрявська
#
# 61500.0,Кайсарова
#
# 78000.0,Дніпровська
#
# 259266.0,Перова
#
# 34500.0,Глушкова
#
# 122000.0,Рокосовського
#
# 147420.0,Саперно-Слобідська
#
# 73000.0,Миколи Кибальчича
#
# 44000.0,Миколи Ушакова
#
# 128000.0,Антоновича
#
# 111000.0,Богданівська
#
# 73000.0,
#
# 89000.0,Сверстюка
#
# 64000.0,Ревуцького
#
# 375000.0,Ованеса Туманяна
#
# 98000.0,Саперне Поле
#
# 32000.0,Григоренка
#
# 125000.0,Гречка
#
# 61500.0,Богатирська
#
# 105000.0,Білоруська
#
# 2425640.0,Регенераторна
#
# 89000.0,Вишняківська
#
# 27500.0,Гонгадзе
#
# 47000.0,Правди
#
# 329000.0,Кольцова
#
# 71000.0,Воскресенська
#
# 1885431.0,Руставелі
#
# 980000.0,Голосіївський
#
# 68000.0,Комбінатна
#
# 71000.0,Салютна
#
# 190000.0,Маланюка
#
# 3641884.0,Ромоданова
#
# 115000.0,Саперне Поле
#
# 45000.0,Сім’ї Кульженків
#
# 57000.0,Лабораторна
#
# 45500.0,Драгоманова
#
# 260000.0,
#
# 80000.0,Кудрявська
#
# 2110252.0,Краківська
#
# 138000.0,Кольцова
#
# 105000.0,Антоновича
#
# 2363130.0,Лариси Руденко
#
# 89000.0,Івана Пулюя
#
# 400000.0,Українки
#
# 100000.0,Тютюнника
#
# 61500.0,Юрія Смолича
#
# 48000.0,Оболонський
#
# 180000.0,Курбаса
#
# 108000.0,Верховинця
#
# 43500.0,Зарічна
#
# 100999.0,Дніпровська
#
# 52000.0,Коломийський
#
# 146000.0,Правди
#
# 110000.0,Каховська
#
# 148800.0,Бойчука
#
# 77000.0,Правди
#
# 38500.0,Маккейна
#
# 100000.0,Перемоги
#
# 78000.0,Грушевського
#
# 75000.0,Срібнокільська
#
# 45000.0,Перемоги
#
# 900000.0,Урлівська
#
# 85000.0,Заболотного
#
# 65600.0,Максимовича
#
# 395000.0,Бажана
#
# 155000.0,Сікорського
#
# 84000.0,Курбаса
#
# 73000.0,Дніпровська
#
# 83000.0,Драгомирова
#
# 250000.0,
#
# 299000.0,Антонова
#
# 56000.0,Бучми
#
# 4335178.0,Кубанської України
#
# 270000.0,Дніпровська
#
# 58000.0,Панельна
#
# 62000.0,Коновальця
#
# 80000.0,Богатирська
#
# 195000.0,Оболонський
#
# 3180495.0,Українки
#
# 122000.0,Бориса Гмирі
#
# 3793500.0,Правди
#
# 65000.0,Центральна
#
# 40500.0,Преображенська
#
# 1181731.0,Коновальця
#
# 69000.0,Українки
#
# 75000.0,*** not found
#
# 155000.0,Велика Васильківська
#
# 220000.0,Липківського
#
# 51500.0,Бойчука
#
# 73900.0,Васильківська
#
# 2458347.0,Данькевича
#
# 1400000.0,Богатирська
#
# 93950.0,Українки
#
# 395000.0,Гречка
#
# 179000.0,Редутна
#
# 260000.0,Бориса Гмирі
#
# 52000.0,Драгомирова
#
# 395000.0,Туполєва
#
# 198450.0,Кондратюка
#
# 750000.0,Мінський
#
# 650000.0,Княжий Затон
#
# 75000.0,Герцена
#
# 150000.0,Балтійський
#
# 93900.0,Ернста
#
# 120500.0,Шаповала
#
# 129000.0,Городецького
#
# 62000.0,Сім'ї Сосніних
#
# 150000.0,Івана Мазепи
#
# 55000.0,Червоноткацька
#
# 138000.0,*** not found
#
# 172000.0,Голосіївська
#
# 79900.0,*** not found
#
# 49999.0,Миколи Гулака
#
# 115000.0,Івана Федорова
#
# 87000.0,Саперне Поле
#
# 107000.0,Миколи Хвильового
#
# 87700.0,Паторжинського
#
# 65000.0,Наумовича
#
# 1250000.0,Калнишевського
#
# 34700.0,Дніпровська
#
# 67000.0,Електриків
#
# 88000.0,Солом'янська
#
# 285000.0,Шевченка
#
# 93000.0,Озерна
#
# 85000.0,Григоренка
#
# 230000.0,Антонова
#
# 155000.0,Голосіївський
#
# 180000.0,Комарова
#
# 95000.0,Борщагівська
#
# 54934.0,Шевченка
#
# 260000.0,Максимовича
#
# 145000.0,Ковальський
#
# 135000.0,Малевича
#
# 50000.0,Мічуріна
#
# 399000.0,*** not found
#
# 55000.0,Балтійський
#
# 270000.0,Азербайджанська
#
# 337000.0,Зарічна
#
# 170000.0,Чавдар
#
# 85000.0,Правди
#
# 279000.0,Урлівська
#
# 44000.0,Бориспільська
#
# 170000.0,Поправки
#
# 88000.0,Бориспільська
#
# 41500.0,Ентузіастів
#
# 70000.0,Малоземельна
#
# 119900.0,Саксаганського
#
# 86000.0,Героїв Сталінграда
#
# 138000.0,Зодчих
#
# 240000.0,Калнишевського
#
# 149500.0,Філатова
#
# 1999600.0,Старонаводницька
#
# 67999.0,Заболотного
#
# 41500.0,Правди
#
# 99000.0,*** not found
#
# 580000.0,Антоновича
#
# 75000.0,Шаповала
#
# 299000.0,Івана Федорова
#
# 44000.0,Деревлянська
#
# 139000.0,Вільямса
#
# 150000.0,Васильченка
#
# 45690.0,Предславинська
#
# 115000.0,Крайня
#
# 63500.0,Милославська
#
# 42000.0,Воскресенська
#
# 56500.0,Маланюка
#
# 66000.0,Дніпровська
#
# 103000.0,Пушкінська
#
# 63000.0,Набережно-Корчуватська
#
# 228000.0,Зарічна
#
# 90000.0,Тургенєвська
#
# 87000.0,Радченка
#
# 62000.0,Зарічна
#
# 77000.0,Метрологічна
#
# 179900.0,Йорданська
#
# 49000.0,Кольцова
#
# 105900.0,Максимовича
#
# 500000.0,Науки
#
# 38000.0,Саперно-Слобідська
#
# 130000.0,Шовковична
#
# 230000.0,Трускавецька
#
# 66800.0,Гавела
#
# 125000.0,Повітрофлотський
#
# 113000.0,Запорожця
#
# 93000.0,Маккейна
#
# 422000.0,Перемоги
#
# 80500.0,Щербаківського
#
# 123000.0,Зарічна
#
# 200000.0,Будищанська
#
# 52000.0,Жилянська
#
# 360000.0,Комбінатна
#
# 102000.0,Ревуцького
#
# 77000.0,Бородіна
#
# 125000.0,Руставелі
#
# 84000.0,Драгоманова
#
# 185000.0,Преображенська
#
# 888189.0,Депутатська
#
# 45142.0,Багговутівська
#
# 980000.0,*** not found
#
# 180000.0,Сікорського
#
# 40000.0,Драгомирова
#
# 110000.0,Коперніка
#
# 3600804.0,Васильківська
#
# 165000.0,Глибочицька
#
# 92550.0,Чавдар
#
# 80000.0,Шовковична
#
# 115000.0,Дніпровська
#
# 4335178.0,Антоновича
#
# 155000.0,
#
# 220000.0,Славгородська
#
# 95000.0,Драгомирова
#
# 115000.0,Срібнокільська
#
# 1750000.0,Харченка
#
# 240000.0,Окіпної
#
# 1158740.0,Саперне Поле
#
# 170000.0,Олени Теліги
#
# 93000.0,Кондратюка
#
# 145000.0,Мечнікова
#
# 47211.0,Героїв Сталінграда
#
# 81000.0,Рибальська
#
# 750000.0,Березова
#
# 84950.0,Саперне Поле
#
# 190000.0,Антоновича
#
# 85000.0,Маккейна
#
# 211000.0,Лейпцизька
#
# 136279.0,Драгоманова
#
# 71000.0,Коновальця
#
# 95000.0,Василя Стуса
#
# 120000.0,Тютюнника
#
# 335000.0,Січових Стрільців
#
# 38500.0,Райдужна
#
# 47000.0,Закревського
#
# 105000.0,Тургенєвська
#
# 163000.0,Васильківська
#
# 1500000.0,Зої Космодем'янської
#
# 49000.0,Радченка
#
# 100000.0,Сверстюка
#
# 130000.0,Милославська
#
# 2688000.0,Метрологічна
#
# 52600.0,Деміївська
#
# 39000.0,Перемоги
#
# 110000.0,Вишгородська
#
# 135000.0,Маккейна
#
# 139860.0,
#
# 70000.0,Перемоги
#
# 95000.0,Балтійський
#
# 155000.0,Звіринецька
#
# 56850.0,Ревуцького
#
# 140000.0,Правди
#
# 110000.0,Милославська
#
# 145000.0,Вербицького
#
# 280000.0,Новгородська
#
# 270000.0,Бажана
#
# 50500.0,Канівська
#
# 39000.0,Максимовича
#
# 490000.0,Донця
#
# 34988.0,Драгомирова
#
# 311000.0,Тираспольська
#
# 65000.0,Саксаганського
#
# 169000.0,Тираспольська
#
# 70000.0,Зарічна
#
# 103000.0,Гонгадзе
#
# 140000.0,Українки
#
# 116500.0,Світлицького
#
# 107000.0,Воробйова
#
# 77000.0,Каховська
#
# 165000.0,Глибочицька
#
# 450000.0,Білокур
#
# 195000.0,Балтійський
#
# 480000.0,Антоновича
#
# 120000.0,Кондратюка
#
# 58000.0,Гончара
#
# 1500000.0,Ревуцького
#
# 345700.0,*** not found
#
# 126000.0,Драгоманова
#
# 158000.0,Сім’ї Кульженків
#
# 206315.0,Панельна
#
# 33000.0,Вільямса
#
# 250000.0,Голосіївська
#
# 63500.0,Оболонський
#
# 2100000.0,Миколи Голего
#
# 1180000.0,Дніпровська
#
# 42000.0,Малиновського
#
# 146000.0,Назарівська
#
# 299000.0,Гоголівська
#
# 141000.0,Дорогожицька
#
# 41000.0,Петропавлівська
#
# 115000.0,Грушевського
#
# 81000.0,Іллєнка
#
# 103950.0,Липківського
#
# 1468067.0,Ушинського
#
# 68000.0,Польова
#
# 80000.0,Саперне Поле
#
# 112000.0,Панельна
#
# 319000.0,Коновальця
#
# 98000.0,Хмельницького
#
# 50000.0,Маккейна
#
# 49990.0,Антоновича
#
# 89500.0,Толстого
#
# 350000.0,Дружби Народів
#
# 210000.0,Оболонський
#
# 345000.0,Багговутівська
#
# 90000.0,Антонова
#
# 170000.0,Володимирська
#
# 110000.0,Українки
#
# 59000.0,Сім’ї Кульженків
#
# 145000.0,Коновальця
#
# 79000.0,Мирного
#
# 375000.0,Московська
#
# 122000.0,Жмеринська
#
# 255000.0,Бойчука
#
# 85000.0,Липківського
#
# 240800.0,Лабораторний
#
# 455000.0,Інститутська
#
# 165000.0,Українки
#
# 100000.0,Хрещатик
#
# 195000.0,Дніпровська
#
# 41000.0,Осокорська
#
# 70000.0,Саперне Поле
#
# 71400.0,Комарова
#
# 3711865.0,Драгомирова
#
# 60000.0,Срібнокільська
#
# 240000.0,Чоколівський
#
# 260000.0,Звіринецька
#
# 127000.0,Вишгородська
#
# 40000.0,Драгомирова
#
# 1796439.0,Героїв Сталінграда
#
# 3400000.0,Будівельників
#
# 44500.0,Іллєнка
#
# 125000.0,Урлівська
#
# 51000.0,Сормовська
#
# 1707790.0,Правди
#
# 65000.0,Верховинна
#
# 55000.0,Вербицького
#
# 94500.0,*** not found
#
# 115000.0,Велика Васильківська
#
# 45000.0,Бойчука
#
# 85000.0,Лобановського
#
# 5204750.0,Миколи Шепелєва
#
# 84500.0,Кропивницького
#
# 350000.0,Трускавецька
#
# 182000.0,Голосіївська
#
# 188999.0,Маланюка
#
# 147000.0,Драгомирова
#
# 89900.0,Юнацька
#
# 66900.0,Максимовича
#
# 75000.0,Комарова
#
# 58000.0,Багговутівська
#
# 140000.0,
#
# 82000.0,Костанайська
#
# 215000.0,Срібнокільська
#
# 33400.0,Курчатова
#
# 100000.0,Гусовського
#
# 240000.0,Українки
#
# 62000.0,Драгоманова
#
# 115000.0,Дніпровська
#
# 143560.0,Заболотного
#
# 130000.0,Заболотного
#
# 152000.0,Перемоги
#
# 33800.0,Сверстюка
#
# 55000.0,Липківського
#
# 110000.0,Маккейна
#
# 200000.0,Дніпровська
#
# 70000.0,Волгоградська
#
# 160888.0,Новопольова
#
# 189000.0,Драгоманова
#
# 135000.0,Лебедєва
#
# 215000.0,*** not found
#
# 102000.0,Драгомирова
#
# 193750.0,Лейпцизька
#
# 54000.0,Глибочицька
#
# 70000.0,Салютна
#
# 3180495.0,Метрологічна
#
# 50500.0,Північно-Сирецька
#
# 57000.0,Правди
#
# 130000.0,Вернадського
#
# 262000.0,Пчілки
#
# 66000.0,Лейпцизька
#
# 3249056.0,Басейна
#
# 2000000.0,Шаповала
#
# 78000.0,Бережанська
#
# 90500.0,Бойчука
#
# 80000.0,Перемоги
#
# 906080.0,Івана Федорова
#
# 4500000.0,Антоновича
#
# 32000.0,Вільямса
#
# 190000.0,Бойчука
#
# 220000.0,Перемоги
#
# 110000.0,Ковпака
#
# 43000.0,Русанівський
#
# 983253.0,Українки
#
# 65000.0,Празька
#
# 110000.0,Гончара
#
# 150000.0,Маккейна
#
# 125500.0,Балтійський
#
# 200000.0,Білоруська
#
# 480000.0,Драгоманова
#
# 235000.0,Липківського
#
# 82000.0,Новогоспітальна
#
# 121975.0,Радченка
#
# 200000.0,Богомольця
#
# 250000.0,Донця
#
# 205000.0,Оболонський
#
# 76466.0,Щекавицька
#
# 240000.0,Пожарського
#
# 150000.0,Полкова
#
# 69000.0,Донця
#
# 74900.0,Палладіна
#
# 1350000.0,Бойчука
#
# 386000.0,Липківського
#
# 31500.0,Павлівська
#
# 58000.0,Івашкевича
#
# 115000.0,Іскрівська
#
# 64999.0,Максимовича
#
# 69900.0,*** not found
#
# 220000.0,Драгомирова
#
# 2873080.0,Теремківська
#
# 186000.0,Осокорська
#
# 43000.0,Дмитрівська
#
# 55000.0,Кондратюка
#
# 193750.0,Регенераторна
#
# 100999.0,
#
# 11017941.0,Глибочицька
#
# 149000.0,Героїв Сталінграда
#
# 3600804.0,Борщагівська
#
# 45000.0,Ревуцького
#
# 92000.0,Юнацька
#
# 295000.0,Заболотного
#
# 39900.0,Автозаводська
#
# 215000.0,Заболотного
#
# 2458347.0,Саксаганського
#
# 138000.0,Зарічна
#
# 50000.0,*** not found
#
# 92284.0,Невська
#
# 140000.0,Героїв Сталінграда
#
# 3707378.0,Вишняківська
#
# 94000.0,Драгомирова
#
# 45000.0,Драгомирова
#
# 56000.0,Гавела
#
# 140000.0,Здолбунівська
#
# 90000.0,Драгомирова
#
# 159000.0,Мечнікова
#
# 1848450.0,*** not found
#
# 106000.0,Максимовича
#
# 170000.0,Багговутівська
#
# 91000.0,Шолуденка
#
# 110000.0,Щекавицька
#
# 65000.0,Коласа
#
# 260000.0,*** not found
#
# 125000.0,*** not found
#
# 65000.0,Перемоги
#
# 158000.0,*** not found
#
# 80000.0,Наумова
#
# 68900.0,Перемоги
#
# 168000.0,Велика Васильківська
#
# 41000.0,Червоноткацька
#
# 134900.0,Вишгородська

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur  = conn.cursor()

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'
rows = cur.execute("SELECT * FROM street_district LIMIT 10")

rows_list = rows.fetchall()

_ = [print(x) for x in rows_list]
# Out:
# ('9-го Травня', 'вулиця', 'Святошинський')
# ('Абрикосова', 'вулиця', 'Оболонський')
# ('Абрикосова', 'вулиця', 'Дарницький')
# ('Абрикосова', 'вулиця', 'Подільський')
# ('Августина Волошина', 'вулиця', 'Солом’янський')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський')
# ('Автозаводська', 'вулиця', 'Оболонський')
# ('Автозаводський ', 'провулок', 'Оболонський')
# ('Автопаркова', 'вулиця', 'Дарницький')
# ('Авторемонтна', 'вулиця', "Солом'янський")

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property INT);"

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('property',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = "SELECT street_district.district, street_flat_property.* FROM \
             street_flat_property LEFT JOIN street_district ON street_flat_property.street = street_district.street"

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()
# Out:
# [(None, 115000.0, 'Омеляновича-Павленка'),
#  (None, 75000.0, None),
#  (None, 140000.0, 'Ованеса Туманяна'),
#  ('Оболонський', 140000.0, 'Петропавлівська'),
#  ('Подільський', 140000.0, 'Петропавлівська'),
#  ('Оболонський', 160000.0, 'Дніпровська'),
#  ('Голосіївський, Печерський, Шевченківський', 870000.0, 'Саксаганського'),
#  (None, 14883863.0, 'Івана Мазепи'),
#  ('Оболонський', 220000.0, 'Дніпровська'),
#  ('Голосіївський, Печерський', 133000.0, 'Ділова'),
#  (None, 69000.0, 'Новодарницька'),
#  ('Дарницький', 169999.0, 'Ревуцького'),
#  (None, 212000.0, 'Липківського'),
#  (None, 83500.0, 'Бендукідзе'),
#  ('Подільський', 75000.0, 'Введенська'),
#  ('Печерський', 65000.0, 'Виноградний'),
#  ("Голосіївський,Солом'янський", 82000.0, 'Кайсарова'),
#  (None, 207000.0, 'Ахматової'),
#  (None, 51990.0, 'Радченка'),
#  ('Оболонський', 57999.0, 'Дніпровська'),
#  ('Голосіївський, Печерський', 57000.0, 'Ділова'),
#  ('Дарницький', 95000.0, 'Бориспільська'),
#  ('Печерський', 50000.0, 'Болсуновська'),
#  (None, 95000.0, 'Українки'),
#  (None, 46860.0, 'Антонова'),
#  (None, 38500.0, 'Омеляновича-Павленка'),
#  (None, 110000.0, None),
#  (None, 269000.0, 'Ованеса Туманяна'),
#  ('Оболонський', 1983000.0, 'Петропавлівська'),
#  ('Подільський', 1983000.0, 'Петропавлівська'),
#  ('Оболонський', 119000.0, 'Дніпровська'),
#  ('Голосіївський, Печерський, Шевченківський', 210000.0, 'Саксаганського'),
#  (None, 310000.0, 'Івана Мазепи'),
#  ('Оболонський', 93000.0, 'Дніпровська'),
#  ('Голосіївський, Печерський', 98000.0, 'Ділова'),
#  (None, 78000.0, 'Новодарницька'),
#  ('Дарницький', 68000.0, 'Ревуцького'),
#  (None, 77000.0, 'Липківського'),
#  (None, 176000.0, 'Бендукідзе'),
#  ('Подільський', 5572000.0, 'Введенська'),
#  ('Печерський', 129000.0, 'Виноградний'),
#  ("Голосіївський,Солом'янський", 136000.0, 'Кайсарова'),
#  (None, 71000.0, 'Ахматової'),
#  (None, 108000.0, 'Радченка'),
#  ('Оболонський', 175000.0, 'Дніпровська'),
#  ('Голосіївський, Печерський', 45006.0, 'Ділова'),
#  ('Дарницький', 78000.0, 'Бориспільська'),
#  ('Печерський', 65000.0, 'Болсуновська'),
#  (None, 3396000.0, 'Українки'),
#  (None, 68899.0, 'Антонова'),
#  ('Голосіївський', 205000.0, 'Науки'),
#  ('Голосіївський', 211000.0, 'Метрологічна'),
#  ('Печерський', 36500.0, 'Дружби Народів'),
#  (None, 3176715.0, '*** not found'),
#  (None, 155000.0, 'Драгомирова'),
#  (None, 109000.0, 'Данченка'),
#  ('Голосіївський', 120000.0, 'Кримська'),
#  ("Солом'янський", 55000.0, 'Новопольова'),
#  (None, 48000.0, 'Туполєва'),
#  (None, 235000.0, '*** not found'),
#  ('Оболонський', 41000.0, 'Дніпровська'),
#  ('Святошинський', 143000.0, 'Перемоги'),
#  ('Шевченківський', 143000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 143000.0, 'Перемоги'),
#  (None, 65000.0, 'Івана Федорова'),
#  ('Деснянський, Дніпровський', 500000.0, 'Братиславська'),
#  (None, 94000.0, '*** not found'),
#  (None, 280000.0, 'Червоноткацька'),
#  (None, 67500.0, 'Златоустівська'),
#  (None, 72000.0, 'Бойченка'),
#  ('Дарницький', 54000.0, 'Трускавецька'),
#  ('Дніпровський', 74000.0, 'Каховська'),
#  (None, 130000.0, 'Лобановського'),
#  (None, 110000.0, '*** not found'),
#  (None, 180000.0, 'Курчатова'),
#  ('Голосіївський', 69000.0, 'Голосіївська'),
#  ('Голосіївський', 69000.0, 'Голосіївська'),
#  ('Подільський', 205000.0, 'Тираспольська'),
#  ('Печерський', 211000.0, 'Лаврська'),
#  ('Подільський', 36500.0, 'Правди'),
#  (None, 3176715.0, 'Миколайчука'),
#  (None, 155000.0, 'Порика'),
#  (None, 109000.0, 'Червоноткацька'),
#  (None, 120000.0, 'Маккейна'),
#  ('Оболонський', 55000.0, 'Йорданська'),
#  (None, 48000.0, 'Тютюнника'),
#  ('Дніпровський', 235000.0, 'Регенераторна'),
#  ('Дарницький', 41000.0, 'Зарічна'),
#  (None, 143000.0, 'Заболотного'),
#  ('Дніпровський, Деснянський', 65000.0, 'Курнатовського'),
#  ('Печерський', 500000.0, 'Інститутська'),
#  (None, 94000.0, 'Маланюка'),
#  (None, 280000.0, 'Гречка'),
#  (None, 67500.0, 'Липківського'),
#  (None, 72000.0, 'Маккейна'),
#  (None, 54000.0, 'Григоренка'),
#  (None, 74000.0, 'Коновальця'),
#  (None, 130000.0, 'Закревського'),
#  (None, 110000.0, '*** not found'),
#  ('Печерський', 180000.0, 'Старонаводницька'),
#  (None, 69000.0, 'Маланюка'),
#  ('Печерський', 120000.0, 'Заньковецької'),
#  ('Шевченківський', 150000.0, 'Кудрявська'),
#  (None, 750000.0, None),
#  (None, 75000.0, 'Українки'),
#  (None, 53000.0, None),
#  ('Деснянський', 42500.0, 'Милославська'),
#  (None, 103000.0, 'Донця'),
#  (None, 650000.0, 'Верховинця'),
#  ('Оболонський', 56000.0, 'Героїв Дніпра'),
#  ('Дніпровський', 90000.0, 'Каховська'),
#  ('Дніпровський', 77000.0, 'Каховська'),
#  ('Дарницький', 115000.0, 'Вишняківська'),
#  (None, 120000.0, 'Липська'),
#  (None, 130000.0, 'Сверстюка'),
#  (None, 85000.0, 'Драгомирова'),
#  ('Дарницький', 140000.0, 'Причальна'),
#  ('Печерський', 45500.0, 'Болсуновська'),
#  ("Шевченківський, Солом'янський", 63232.0, 'Повітрофлотський'),
#  ('Дарницький', 95000.0, 'Драгоманова'),
#  (None, 55000.0, 'Григоренка'),
#  ('Оболонський', 186900.0, 'Дніпровська'),
#  (None, 34200.0, 'Жабаєва'),
#  (None, 234899.0, 'Філатова'),
#  ('Подільський', 55000.0, 'Правди'),
#  ('Шевченківський', 136000.0, 'Малопідвальна'),
#  (None, 139000.0, 'Бойчука'),
#  ('Дарницький', 210000.0, 'Зарічна'),
#  ('Печерський', 195000.0, 'Предславинська'),
#  (None, 119000.0, 'Івана Мазепи'),
#  (None, 410000.0, 'Радченка'),
#  ('Печерський', 93000.0, 'Лабораторний'),
#  (None, 137634.0, 'Конєва'),
#  (None, 115000.0, 'Шаповала'),
#  ('Оболонський', 85000.0, 'Дніпровська'),
#  ('Дарницький', 130000.0, 'Клеманська'),
#  (None, 113000.0, 'Григоренка'),
#  (None, 39500.0, 'Туполєва'),
#  (None, 68000.0, 'Хмельницького'),
#  ('Печерський', 155000.0, 'Саперне Поле'),
#  ('Оболонський', 110000.0, 'Героїв Сталінграда'),
#  ('Оболонський', 75000.0, 'Дніпровська'),
#  ('Голосіївський', 142000.0, 'Тарасівська'),
#  ('Дніпровський', 80000.0, 'Краківська'),
#  ('Святошинський', 43000.0, 'Юнацька'),
#  ("Солом'янський", 43000.0, 'Юнацька'),
#  ('Дарницький', 248000.0, 'Клеманська'),
#  ('Оболонський', 280000.0, 'Героїв Сталінграда'),
#  (None, 209000.0, 'Драгомирова'),
#  (None, 58990.0, '*** not found'),
#  ('Дарницький', 111000.0, 'Драгоманова'),
#  (None, 97000.0, 'Українки'),
#  (None, 68000.0, 'Тимошенка'),
#  ('Деснянський', 184900.0, 'Маяковського'),
#  ('Подільський', 61500.0, 'Дмитрівська'),
#  ('Шевченківський', 61500.0, 'Дмитрівська'),
#  (None, 111000.0, 'Курбаса'),
#  (None, 190700.0, 'Комарова'),
#  ('Дарницький', 53000.0, 'Драгоманова'),
#  (None, 69000.0, 'Драгомирова'),
#  (None, 169000.0, 'Моторний'),
#  ('Деснянський', 95000.0, 'Милославська'),
#  (None, 110000.0, 'Бойчука'),
#  (None, 5880000.0, 'Закревського'),
#  (None, 99999.0, 'Івана Федорова'),
#  (None, 327000.0, 'Філатова'),
#  ('Святошинський', 85000.0, 'Перемоги'),
#  ('Шевченківський', 85000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 85000.0, 'Перемоги'),
#  ('Деснянський, Дніпровський', 790000.0, 'Миропільська'),
#  (None, 95000.0, 'Григоренка'),
#  ('Святошинський', 70000.0, 'Юнацька'),
#  ("Солом'янський", 70000.0, 'Юнацька'),
#  ('Подільський, Оболонський', 2352122.0, 'Вишгородська'),
#  ('Святошинський', 807000.0, 'Жолудєва'),
#  ('Шевченківський', 77000.0, 'Павлівська'),
#  ('Голосіївський', 75000.0, 'Голосіївський'),
#  ('Голосіївський', 75000.0, 'Голосіївський'),
#  ('Дарницький', 480000.0, 'Осокорська'),
#  ('Подільський, Оболонський', 70000.0, 'Вишгородська'),
#  (None, 205000.0, 'Драгомирова'),
#  (None, 499990.0, 'Тютюнника'),
#  (None, 52000.0, 'Маккейна'),
#  (None, 93000.0, 'Івана Мазепи'),
#  ('Оболонський', 117000.0, 'Героїв Сталінграда'),
#  (None, 53900.0, 'Липківського'),
#  (None, 58000.0, '*** not found'),
#  (None, 159000.0, 'Коновальця'),
#  ('Святошинський', 116000.0, 'Максимовича'),
#  ('Дарницький', 42000.0, 'Зарічна'),
#  ('Голосіївський', 55500.0, 'Голосіївська'),
#  ('Голосіївський', 55500.0, 'Голосіївська'),
#  ('Голосіївський', 370000.0, 'Ясинуватський'),
#  (None, 650000.0, '*** not found'),
#  (None, 355000.0, 'Колоса'),
#  ('Подільський', 145000.0, 'Правди'),
#  ('Голосіївський, Шевченківський, Печерський',
#   117000.0,
#   'Велика Васильківська'),
#  ('Голосіївський', 300000.0, 'Голосіївський'),
#  ('Голосіївський', 300000.0, 'Голосіївський'),
#  (None, 55000.0, '*** not found'),
#  (None, 41000.0, 'Бойчука'),
#  ('Дніпровський', 128000.0, 'Центральна'),
#  ('Оболонський', 128000.0, 'Центральна'),
#  ('Шевченківський', 128000.0, 'Центральна'),
#  ('Голосіївський', 175000.0, 'Ясинуватський'),
#  ('Дніпровський', 783000.0, 'Райдужна'),
#  ('Голосіївський', 90000.0, 'Ломоносова'),
#  (None, 98000.0, None),
#  (None, 137000.0, '*** not found'),
#  ('Печерський', 45000.0, 'Гусовського'),
#  (None, 2015228.0, 'Окіпної'),
#  ('Шевченківський', 200000.0, 'Багговутівська'),
#  ('Печерський', 147000.0, 'Дружби Народів'),
#  (None, 78000.0, 'Маккейна'),
#  (None, 82000.0, 'Маланюка'),
#  (None, 75000.0, 'Михайла Котельникова'),
#  ("Солом'янський", 89000.0, 'Героїв Севастополя'),
#  (None, 710000.0, 'Маланюка'),
#  ('Печерський', 620000.0, 'Саперне Поле'),
#  ('Оболонський', 69500.0, 'Балтійський'),
#  ('Шевченківський', 85000.0, 'Кудрявська'),
#  ('Святошинський', 43000.0, 'Перемоги'),
#  ('Шевченківський', 43000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 43000.0, 'Перемоги'),
#  ('Печерський', 330000.0, 'Німанська'),
#  ('Дніпровський', 59000.0, 'Каховська'),
#  ('Шевченківський', 40000.0, 'Малопідвальна'),
#  (None, 1200000.0, 'Невська'),
#  (None, 405000.0, 'Златоустівська'),
#  (None, 100110.0, None),
#  ('Святошинський', 400000.0, 'Берковецька'),
#  (None, 97500.0, 'Бажана'),
#  ('Голосіївський, Печерський', 83000.0, 'Антоновича'),
#  (None, 44000.0, '*** not found'),
#  (None, 66000.0, 'Гречка'),
#  ('Дніпровський', 350000.0, 'Микільсько-Слобідська'),
#  ('Подільський', 77000.0, 'Правди'),
#  (None, 122250.0, 'Тимошенка'),
#  (None, 65000.0, 'Павла Тичини'),
#  ('Святошинський', 170000.0, 'Олевська'),
#  ("Солом'янський", 95000.0, 'Освіти'),
#  (None, 85000.0, 'Іллєнка'),
#  ('Оболонський', 69500.0, 'Дніпровська'),
#  (None, 152000.0, 'Івана Мазепи'),
#  (None, 92000.0, 'Українки'),
#  (None, 375000.0, 'Данченка'),
#  (None, 449000.0, 'Драгомирова'),
#  (None, 75500.0, 'Тбіліський'),
#  ('Дніпровський', 140000.0, 'Каховська'),
#  ("Солом'янський", 45000.0, 'Ушинського'),
#  ("Солом'янський", 45000.0, 'Ушинського'),
#  ('Дарницький', 135000.0, 'Урлівська'),
#  ('Подільський', 125000.0, 'Світлицького'),
#  ('Оболонський', 140000.0, 'Дніпровська'),
#  (None, 120000.0, 'Липківського'),
#  ('Дніпровський', 42000.0, 'Микільсько-Слобідська'),
#  (None, 125000.0, 'Лобановського'),
#  ('Оболонський', 48000.0, 'Героїв Сталінграда'),
#  ('Оболонський', 300000.0, 'Дніпровська'),
#  ('Дарницький', 120000.0, 'Драгоманова'),
#  (None, 649000.0, 'Ахматової'),
#  ('Печерський', 64980.0, 'Саперне Поле'),
#  (None, 77000.0, 'Данченка'),
#  ('Голосіївський', 48000.0, 'Голосіївський'),
#  ('Голосіївський', 48000.0, 'Голосіївський'),
#  (None, 102000.0, '*** not found'),
#  ('Шевченківський', 185000.0, 'Глибочицька'),
#  ('Шевченківський', 42000.0, 'Багговутівська'),
#  ('Голосіївський, Печерський, Шевченківський', 115000.0, 'Саксаганського'),
#  (None, 175000.0, 'Моторний'),
#  ('Оболонський', 54000.0, 'Йорданська'),
#  ('Печерський', 10116000.0, 'Саперне Поле'),
#  (None, 137000.0, 'Вернадського'),
#  (None, 95000.0, 'Курбаса'),
#  ('Шевченківський', 360000.0, 'Багговутівська'),
#  ('Подільський', 135000.0, 'Набережно-Рибальська'),
#  ('Голосіївський, Печерський, Шевченківський', 105000.0, 'Саксаганського'),
#  (None, 58000.0, 'Малиновського'),
#  ("Солом'янський", 180000.0, 'Протасів Яр'),
#  ('Печерський', 153000.0, 'Німанська'),
#  (None, 159000.0, 'Підвисоцького'),
#  ('Святошинський', 98000.0, 'Зодчих'),
#  (None, 1200000.0, 'Рокосовського'),
#  ('Печерський', 42900.0, 'Шовковична'),
#  (None, 86000.0, 'Крушельницької'),
#  ("Солом'янський", 155000.0, 'Новопольова'),
#  ('Дніпровський', 450000.0, 'Визволителів'),
#  ('Дніпровський', 148000.0, 'Сонячна'),
#  ('Шевченківський', 148000.0, 'Сонячна'),
#  (None, 50000.0, 'Сікорського'),
#  (None, 81000.0, 'Радченка'),
#  ('Шевченківський', 161003.0, 'Бульварно-Кудрявська'),
#  ("Голосіївський,Солом'янський", 61500.0, 'Кайсарова'),
#  ('Оболонський', 78000.0, 'Дніпровська'),
#  ('Дніпровський', 259266.0, 'Перова'),
#  (None, 34500.0, 'Глушкова'),
#  (None, 122000.0, 'Рокосовського'),
#  ('Голосіївський', 147420.0, 'Саперно-Слобідська'),
#  (None, 73000.0, 'Миколи Кибальчича'),
#  (None, 44000.0, 'Миколи Ушакова'),
#  ('Голосіївський, Печерський', 128000.0, 'Антоновича'),
#  ("Солом'янський", 111000.0, 'Богданівська'),
#  (None, 73000.0, None),
#  (None, 89000.0, 'Сверстюка'),
#  ('Дарницький', 64000.0, 'Ревуцького'),
#  (None, 375000.0, 'Ованеса Туманяна'),
#  ('Печерський', 98000.0, 'Саперне Поле'),
#  (None, 32000.0, 'Григоренка'),
#  (None, 125000.0, 'Гречка'),
#  ('Оболонський', 61500.0, 'Богатирська'),
#  ('Шевченківський', 105000.0, 'Білоруська'),
#  ('Дніпровський', 2425640.0, 'Регенераторна'),
#  ('Дарницький', 89000.0, 'Вишняківська'),
#  (None, 27500.0, 'Гонгадзе'),
#  ('Подільський', 47000.0, 'Правди'),
#  ('Святошинський', 329000.0, 'Кольцова'),
#  ('Дніпровський', 71000.0, 'Воскресенська'),
#  (None, 1885431.0, 'Руставелі'),
#  ('Голосіївський', 980000.0, 'Голосіївський'),
#  ('Голосіївський', 980000.0, 'Голосіївський'),
#  ('Дніпровський', 68000.0, 'Комбінатна'),
#  ('Шевченківський', 71000.0, 'Салютна'),
#  (None, 190000.0, 'Маланюка'),
#  (None, 3641884.0, 'Ромоданова'),
#  ('Печерський', 115000.0, 'Саперне Поле'),
#  (None, 45000.0, 'Сім’ї Кульженків'),
#  ('Голосіївський, Печерський', 57000.0, 'Лабораторна'),
#  ('Дарницький', 45500.0, 'Драгоманова'),
#  (None, 260000.0, None),
#  ('Шевченківський', 80000.0, 'Кудрявська'),
#  ('Дніпровський', 2110252.0, 'Краківська'),
#  ('Святошинський', 138000.0, 'Кольцова'),
#  ('Голосіївський, Печерський', 105000.0, 'Антоновича'),
#  (None, 2363130.0, 'Лариси Руденко'),
#  (None, 89000.0, 'Івана Пулюя'),
#  (None, 400000.0, 'Українки'),
#  (None, 100000.0, 'Тютюнника'),
#  (None, 61500.0, 'Юрія Смолича'),
#  ('Оболонський', 48000.0, 'Оболонський'),
#  (None, 180000.0, 'Курбаса'),
#  (None, 108000.0, 'Верховинця'),
#  ('Дарницький', 43500.0, 'Зарічна'),
#  ('Оболонський', 100999.0, 'Дніпровська'),
#  ('Голосіївський', 52000.0, 'Коломийський'),
#  ('Подільський', 146000.0, 'Правди'),
#  ('Дніпровський', 110000.0, 'Каховська'),
#  (None, 148800.0, 'Бойчука'),
#  ('Подільський', 77000.0, 'Правди'),
#  (None, 38500.0, 'Маккейна'),
#  ('Святошинський', 100000.0, 'Перемоги'),
#  ('Шевченківський', 100000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 100000.0, 'Перемоги'),
#  (None, 78000.0, 'Грушевського'),
#  ('Дарницький', 75000.0, 'Срібнокільська'),
#  ('Святошинський', 45000.0, 'Перемоги'),
#  ('Шевченківський', 45000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 45000.0, 'Перемоги'),
#  ('Дарницький', 900000.0, 'Урлівська'),
#  (None, 85000.0, 'Заболотного'),
#  ('Святошинський', 65600.0, 'Максимовича'),
#  (None, 395000.0, 'Бажана'),
#  (None, 155000.0, 'Сікорського'),
#  (None, 84000.0, 'Курбаса'),
#  ('Оболонський', 73000.0, 'Дніпровська'),
#  (None, 83000.0, 'Драгомирова'),
#  (None, 250000.0, None),
#  (None, 299000.0, 'Антонова'),
#  (None, 56000.0, 'Бучми'),
#  ('Деснянський', 4335178.0, 'Кубанської України'),
#  ('Оболонський', 270000.0, 'Дніпровська'),
#  (None, 58000.0, 'Панельна'),
#  (None, 62000.0, 'Коновальця'),
#  ('Оболонський', 80000.0, 'Богатирська'),
#  ('Оболонський', 195000.0, 'Оболонський'),
#  (None, 3180495.0, 'Українки'),
#  (None, 122000.0, 'Бориса Гмирі'),
#  ('Подільський', 3793500.0, 'Правди'),
#  ('Дніпровський', 65000.0, 'Центральна'),
#  ('Оболонський', 65000.0, 'Центральна'),
#  ('Шевченківський', 65000.0, 'Центральна'),
#  ("Солом'янський", 40500.0, 'Преображенська'),
#  (None, 1181731.0, 'Коновальця'),
#  (None, 69000.0, 'Українки'),
#  (None, 75000.0, '*** not found'),
#  ('Голосіївський, Шевченківський, Печерський',
#   155000.0,
#   'Велика Васильківська'),
#  (None, 220000.0, 'Липківського'),
#  (None, 51500.0, 'Бойчука'),
#  ('Голосіївський', 73900.0, 'Васильківська'),
#  (None, 2458347.0, 'Данькевича'),
#  ('Оболонський', 1400000.0, 'Богатирська'),
#  (None, 93950.0, 'Українки'),
#  (None, 395000.0, 'Гречка'),
#  ('Печерський', 179000.0, 'Редутна'),
#  (None, 260000.0, 'Бориса Гмирі'),
#  (None, 52000.0, 'Драгомирова'),
#  (None, 395000.0, 'Туполєва'),
#  (None, 198450.0, 'Кондратюка'),
#  ('Оболонський', 750000.0, 'Мінський'),
#  ('Подільський', 750000.0, 'Мінський'),
#  ('Дарницький', 650000.0, 'Княжий Затон'),
#  ('Шевченківський', 75000.0, 'Герцена'),
#  ('Шевченківський', 75000.0, 'Герцена'),
#  ('Шевченківський', 75000.0, 'Герцена'),
#  ('Оболонський', 150000.0, 'Балтійський'),
#  (None, 93900.0, 'Ернста'),
#  (None, 120500.0, 'Шаповала'),
#  (None, 129000.0, 'Городецького'),
#  (None, 62000.0, "Сім'ї Сосніних"),
#  (None, 150000.0, 'Івана Мазепи'),
#  (None, 55000.0, 'Червоноткацька'),
#  (None, 138000.0, '*** not found'),
#  ('Голосіївський', 172000.0, 'Голосіївська'),
#  ('Голосіївський', 172000.0, 'Голосіївська'),
#  (None, 79900.0, '*** not found'),
#  (None, 49999.0, 'Миколи Гулака'),
#  (None, 115000.0, 'Івана Федорова'),
#  ('Печерський', 87000.0, 'Саперне Поле'),
#  (None, 107000.0, 'Миколи Хвильового'),
#  ('Шевченківський', 87700.0, 'Паторжинського'),
#  (None, 65000.0, 'Наумовича'),
#  (None, 1250000.0, 'Калнишевського'),
#  ('Оболонський', 34700.0, 'Дніпровська'),
#  ('Подільський', 67000.0, 'Електриків'),
#  ('Подільський', 67000.0, 'Електриків'),
#  ("Солом'янський", 88000.0, "Солом'янська"),
#  ("Солом'янський", 88000.0, "Солом'янська"),
#  ('Дарницький', 285000.0, 'Шевченка'),
#  ('Дарницький', 285000.0, 'Шевченка'),
#  ('Деснянський', 285000.0, 'Шевченка'),
#  ("Солом'янський", 285000.0, 'Шевченка'),
#  ("Солом'янський", 285000.0, 'Шевченка'),
#  ('Дарницький', 93000.0, 'Озерна'),
#  ('Оболонський', 93000.0, 'Озерна'),
#  ('Святошинський (СТ "Нивки")', 93000.0, 'Озерна'),
#  ("Солом'янський", 93000.0, 'Озерна'),
#  (None, 85000.0, 'Григоренка'),
#  (None, 230000.0, 'Антонова'),
#  ('Голосіївський', 155000.0, 'Голосіївський'),
#  ('Голосіївський', 155000.0, 'Голосіївський'),
#  (None, 180000.0, 'Комарова'),
#  ("Солом'янський, Шевченківський ", 95000.0, 'Борщагівська'),
#  ('Дарницький', 54934.0, 'Шевченка'),
#  ('Дарницький', 54934.0, 'Шевченка'),
#  ('Деснянський', 54934.0, 'Шевченка'),
#  ("Солом'янський", 54934.0, 'Шевченка'),
#  ("Солом'янський", 54934.0, 'Шевченка'),
#  ('Святошинський', 260000.0, 'Максимовича'),
#  ("Солом'янський", 145000.0, 'Ковальський'),
#  (None, 135000.0, 'Малевича'),
#  ('Деснянський', 50000.0, 'Мічуріна'),
#  ('Оболонський', 50000.0, 'Мічуріна'),
#  ('Печерський', 50000.0, 'Мічуріна'),
#  ('Печерський', 50000.0, 'Мічуріна'),
#  ("Солом'янський", 50000.0, 'Мічуріна'),
#  (None, 399000.0, '*** not found'),
#  ('Оболонський', 55000.0, 'Балтійський'),
#  ('Дніпровський', 270000.0, 'Азербайджанська'),
#  ('Дарницький', 337000.0, 'Зарічна'),
#  (None, 170000.0, 'Чавдар'),
#  ('Подільський', 85000.0, 'Правди'),
#  ('Дарницький', 279000.0, 'Урлівська'),
#  ('Дарницький', 44000.0, 'Бориспільська'),
#  (None, 170000.0, 'Поправки'),
#  ('Дарницький', 88000.0, 'Бориспільська'),
#  ('Дніпровський', 41500.0, 'Ентузіастів'),
#  ('Дарницький', 70000.0, 'Малоземельна'),
#  ('Голосіївський, Печерський, Шевченківський', 119900.0, 'Саксаганського'),
#  ('Оболонський', 86000.0, 'Героїв Сталінграда'),
#  ('Святошинський', 138000.0, 'Зодчих'),
#  (None, 240000.0, 'Калнишевського'),
#  (None, 149500.0, 'Філатова'),
#  ('Печерський', 1999600.0, 'Старонаводницька'),
#  (None, 67999.0, 'Заболотного'),
#  ('Подільський', 41500.0, 'Правди'),
#  (None, 99000.0, '*** not found'),
#  ('Голосіївський, Печерський', 580000.0, 'Антоновича'),
#  (None, 75000.0, 'Шаповала'),
#  (None, 299000.0, 'Івана Федорова'),
#  ('Шевченківський', 44000.0, 'Деревлянська'),
#  (None, 139000.0, 'Вільямса'),
#  ("Солом'янський", 150000.0, 'Васильченка'),
#  ('Печерський', 45690.0, 'Предславинська'),
#  ('Деснянський', 115000.0, 'Крайня'),
#  ('Деснянський', 63500.0, 'Милославська'),
#  ('Дніпровський', 42000.0, 'Воскресенська'),
#  (None, 56500.0, 'Маланюка'),
#  ('Оболонський', 66000.0, 'Дніпровська'),
#  ('Шевченківський', 103000.0, 'Пушкінська'),
#  ('Голосіївський', 63000.0, 'Набережно-Корчуватська'),
#  ('Дарницький', 228000.0, 'Зарічна'),
#  ('Шевченківський', 90000.0, 'Тургенєвська'),
#  (None, 87000.0, 'Радченка'),
#  ('Дарницький', 62000.0, 'Зарічна'),
#  ('Голосіївський', 77000.0, 'Метрологічна'),
#  ('Оболонський', 179900.0, 'Йорданська'),
#  ('Святошинський', 49000.0, 'Кольцова'),
#  ('Святошинський', 105900.0, 'Максимовича'),
#  ('Голосіївський', 500000.0, 'Науки'),
#  ('Голосіївський', 38000.0, 'Саперно-Слобідська'),
#  ('Печерський', 130000.0, 'Шовковична'),
#  ('Дарницький', 230000.0, 'Трускавецька'),
#  (None, 66800.0, 'Гавела'),
#  ("Шевченківський, Солом'янський", 125000.0, 'Повітрофлотський'),
#  (None, 113000.0, 'Запорожця'),
#  (None, 93000.0, 'Маккейна'),
#  ('Святошинський', 422000.0, 'Перемоги'),
#  ('Шевченківський', 422000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 422000.0, 'Перемоги'),
#  (None, 80500.0, 'Щербаківського'),
#  ('Дарницький', 123000.0, 'Зарічна'),
#  ('Деснянський', 200000.0, 'Будищанська'),
#  ('Печерський, Голосіївський, Шевченківський', 52000.0, 'Жилянська'),
#  ('Дніпровський', 360000.0, 'Комбінатна'),
#  ('Дарницький', 102000.0, 'Ревуцького'),
#  (None, 77000.0, 'Бородіна'),
#  (None, 125000.0, 'Руставелі'),
#  ('Дарницький', 84000.0, 'Драгоманова'),
#  ("Солом'янський", 185000.0, 'Преображенська'),
#  ('Святошинський', 888189.0, 'Депутатська'),
#  ('Шевченківський', 45142.0, 'Багговутівська'),
#  (None, 980000.0, '*** not found'),
#  (None, 180000.0, 'Сікорського'),
#  (None, 40000.0, 'Драгомирова'),
#  ('Шевченківський', 110000.0, 'Коперніка'),
#  ('Голосіївський', 3600804.0, 'Васильківська'),
#  ('Шевченківський', 165000.0, 'Глибочицька'),
#  (None, 92550.0, 'Чавдар'),
#  ('Печерський', 80000.0, 'Шовковична'),
#  ('Оболонський', 115000.0, 'Дніпровська'),
#  ('Голосіївський, Печерський', 4335178.0, 'Антоновича'),
#  (None, 155000.0, None),
#  ('Дарницький', 220000.0, 'Славгородська'),
#  (None, 95000.0, 'Драгомирова'),
#  ('Дарницький', 115000.0, 'Срібнокільська'),
#  (None, 1750000.0, 'Харченка'),
#  (None, 240000.0, 'Окіпної'),
#  ('Печерський', 1158740.0, 'Саперне Поле'),
#  (None, 170000.0, 'Олени Теліги'),
#  (None, 93000.0, 'Кондратюка'),
#  ('Печерський', 145000.0, 'Мечнікова'),
#  ('Оболонський', 47211.0, 'Героїв Сталінграда'),
#  ('Печерський', 81000.0, 'Рибальська'),
#  ("Солом'янський", 750000.0, 'Березова'),
#  ('Печерський', 84950.0, 'Саперне Поле'),
#  ('Голосіївський, Печерський', 190000.0, 'Антоновича'),
#  (None, 85000.0, 'Маккейна'),
#  ('Печерський', 211000.0, 'Лейпцизька'),
#  ('Дарницький', 136279.0, 'Драгоманова'),
#  (None, 71000.0, 'Коновальця'),
#  (None, 95000.0, 'Василя Стуса'),
#  (None, 120000.0, 'Тютюнника'),
#  ('Шевченківський', 335000.0, 'Січових Стрільців'),
#  ('Дніпровський', 38500.0, 'Райдужна'),
#  (None, 47000.0, 'Закревського'),
#  ('Шевченківський', 105000.0, 'Тургенєвська'),
#  ('Голосіївський', 163000.0, 'Васильківська'),
#  (None, 1500000.0, "Зої Космодем'янської"),
#  (None, 49000.0, 'Радченка'),
#  (None, 100000.0, 'Сверстюка'),
#  ('Деснянський', 130000.0, 'Милославська'),
#  ('Голосіївський', 2688000.0, 'Метрологічна'),
#  ('Голосіївський', 52600.0, 'Деміївська'),
#  ('Голосіївський', 52600.0, 'Деміївська'),
#  ('Святошинський', 39000.0, 'Перемоги'),
#  ('Шевченківський', 39000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 39000.0, 'Перемоги'),
#  ('Подільський, Оболонський', 110000.0, 'Вишгородська'),
#  (None, 135000.0, 'Маккейна'),
#  (None, 139860.0, None),
#  ('Святошинський', 70000.0, 'Перемоги'),
#  ('Шевченківський', 70000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 70000.0, 'Перемоги'),
#  ('Оболонський', 95000.0, 'Балтійський'),
#  ('Печерський', 155000.0, 'Звіринецька'),
#  ('Дарницький', 56850.0, 'Ревуцького'),
#  ('Подільський', 140000.0, 'Правди'),
#  ('Деснянський', 110000.0, 'Милославська'),
#  (None, 145000.0, 'Вербицького'),
#  ("Солом'янський", 280000.0, 'Новгородська'),
#  (None, 270000.0, 'Бажана'),
#  ('Подільський', 50500.0, 'Канівська'),
#  ('Святошинський', 39000.0, 'Максимовича'),
#  (None, 490000.0, 'Донця'),
#  (None, 34988.0, 'Драгомирова'),
#  ('Подільський', 311000.0, 'Тираспольська'),
#  ('Голосіївський, Печерський, Шевченківський', 65000.0, 'Саксаганського'),
#  ('Подільський', 169000.0, 'Тираспольська'),
#  ('Дарницький', 70000.0, 'Зарічна'),
#  (None, 103000.0, 'Гонгадзе'),
#  (None, 140000.0, 'Українки'),
#  ('Подільський', 116500.0, 'Світлицького'),
#  (None, 107000.0, 'Воробйова'),
#  ('Дніпровський', 77000.0, 'Каховська'),
#  ('Шевченківський', 165000.0, 'Глибочицька'),
#  (None, 450000.0, 'Білокур'),
#  ('Оболонський', 195000.0, 'Балтійський'),
#  ('Голосіївський, Печерський', 480000.0, 'Антоновича'),
#  (None, 120000.0, 'Кондратюка'),
#  (None, 58000.0, 'Гончара'),
#  ('Дарницький', 1500000.0, 'Ревуцького'),
#  (None, 345700.0, '*** not found'),
#  ('Дарницький', 126000.0, 'Драгоманова'),
#  (None, 158000.0, 'Сім’ї Кульженків'),
#  (None, 206315.0, 'Панельна'),
#  (None, 33000.0, 'Вільямса'),
#  ('Голосіївський', 250000.0, 'Голосіївська'),
#  ('Голосіївський', 250000.0, 'Голосіївська'),
#  ('Оболонський', 63500.0, 'Оболонський'),
#  ("Солом'янський", 2100000.0, 'Миколи Голего'),
#  ('Оболонський', 1180000.0, 'Дніпровська'),
#  (None, 42000.0, 'Малиновського'),
#  ('Шевченківський', 146000.0, 'Назарівська'),
#  ('Шевченківський', 299000.0, 'Гоголівська'),
#  ('Шевченківський', 141000.0, 'Дорогожицька'),
#  ('Оболонський', 41000.0, 'Петропавлівська'),
#  ('Подільський', 41000.0, 'Петропавлівська'),
#  (None, 115000.0, 'Грушевського'),
#  (None, 81000.0, 'Іллєнка'),
#  (None, 103950.0, 'Липківського'),
#  ("Солом'янський", 1468067.0, 'Ушинського'),
#  ("Солом'янський", 1468067.0, 'Ушинського'),
#  ('Дарницький', 68000.0, 'Польова'),
#  ('Деснянський', 68000.0, 'Польова'),
#  ("Солом'янський", 68000.0, 'Польова'),
#  ('Печерський', 80000.0, 'Саперне Поле'),
#  (None, 112000.0, 'Панельна'),
#  (None, 319000.0, 'Коновальця'),
#  (None, 98000.0, 'Хмельницького'),
#  (None, 50000.0, 'Маккейна'),
#  ('Голосіївський, Печерський', 49990.0, 'Антоновича'),
#  ('Дарницький', 89500.0, 'Толстого'),
#  ('Печерський', 350000.0, 'Дружби Народів'),
#  ('Оболонський', 210000.0, 'Оболонський'),
#  ('Шевченківський', 345000.0, 'Багговутівська'),
#  (None, 90000.0, 'Антонова'),
#  ('Голосіївський, Шевченківський', 170000.0, 'Володимирська'),
#  (None, 110000.0, 'Українки'),
#  (None, 59000.0, 'Сім’ї Кульженків'),
#  (None, 145000.0, 'Коновальця'),
#  (None, 79000.0, 'Мирного'),
#  ('Печерський', 375000.0, 'Московська'),
#  ("Солом'янський", 375000.0, 'Московська'),
#  ('Святошинський', 122000.0, 'Жмеринська'),
#  (None, 255000.0, 'Бойчука'),
#  (None, 85000.0, 'Липківського'),
#  ('Печерський', 240800.0, 'Лабораторний'),
#  ('Печерський', 455000.0, 'Інститутська'),
#  (None, 165000.0, 'Українки'),
#  ('Печерський, Шевченківський', 100000.0, 'Хрещатик'),
#  ('Оболонський', 195000.0, 'Дніпровська'),
#  ('Дарницький', 41000.0, 'Осокорська'),
#  ('Печерський', 70000.0, 'Саперне Поле'),
#  (None, 71400.0, 'Комарова'),
#  (None, 3711865.0, 'Драгомирова'),
#  ('Дарницький', 60000.0, 'Срібнокільська'),
#  ("Солом'янський", 240000.0, 'Чоколівський'),
#  ('Печерський', 260000.0, 'Звіринецька'),
#  ('Подільський, Оболонський', 127000.0, 'Вишгородська'),
#  (None, 40000.0, 'Драгомирова'),
#  ('Оболонський', 1796439.0, 'Героїв Сталінграда'),
#  ('Деснянський', 3400000.0, 'Будівельників'),
#  ('Дніпровський', 3400000.0, 'Будівельників'),
#  ('Дніпровський', 3400000.0, 'Будівельників'),
#  ('Святошинський', 3400000.0, 'Будівельників'),
#  (None, 44500.0, 'Іллєнка'),
#  ('Дарницький', 125000.0, 'Урлівська'),
#  ('Дарницький', 51000.0, 'Сормовська'),
#  ('Подільський', 1707790.0, 'Правди'),
#  ('Святошинський', 65000.0, 'Верховинна'),
#  (None, 55000.0, 'Вербицького'),
#  (None, 94500.0, '*** not found'),
#  ('Голосіївський, Шевченківський, Печерський',
#   115000.0,
#   'Велика Васильківська'),
#  (None, 45000.0, 'Бойчука'),
#  (None, 85000.0, 'Лобановського'),
#  (None, 5204750.0, 'Миколи Шепелєва'),
#  ('Печерський', 84500.0, 'Кропивницького'),
#  ('Дарницький', 350000.0, 'Трускавецька'),
#  ('Голосіївський', 182000.0, 'Голосіївська'),
#  ('Голосіївський', 182000.0, 'Голосіївська'),
#  (None, 188999.0, 'Маланюка'),
#  (None, 147000.0, 'Драгомирова'),
#  ('Святошинський', 89900.0, 'Юнацька'),
#  ("Солом'янський", 89900.0, 'Юнацька'),
#  ('Святошинський', 66900.0, 'Максимовича'),
#  (None, 75000.0, 'Комарова'),
#  ('Шевченківський', 58000.0, 'Багговутівська'),
#  (None, 140000.0, None),
#  ('Голосіївський', 82000.0, 'Костанайська'),
#  ('Дарницький', 215000.0, 'Срібнокільська'),
#  (None, 33400.0, 'Курчатова'),
#  ('Печерський', 100000.0, 'Гусовського'),
#  (None, 240000.0, 'Українки'),
#  ('Дарницький', 62000.0, 'Драгоманова'),
#  ('Оболонський', 115000.0, 'Дніпровська'),
#  (None, 143560.0, 'Заболотного'),
#  (None, 130000.0, 'Заболотного'),
#  ('Святошинський', 152000.0, 'Перемоги'),
#  ('Шевченківський', 152000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 152000.0, 'Перемоги'),
#  (None, 33800.0, 'Сверстюка'),
#  (None, 55000.0, 'Липківського'),
#  (None, 110000.0, 'Маккейна'),
#  ('Оболонський', 200000.0, 'Дніпровська'),
#  ('Деснянський', 70000.0, 'Волгоградська'),
#  ("Солом'янський", 70000.0, 'Волгоградська'),
#  ("Солом'янський", 160888.0, 'Новопольова'),
#  ('Дарницький', 189000.0, 'Драгоманова'),
#  (None, 135000.0, 'Лебедєва'),
#  (None, 215000.0, '*** not found'),
#  (None, 102000.0, 'Драгомирова'),
#  ('Печерський', 193750.0, 'Лейпцизька'),
#  ('Шевченківський', 54000.0, 'Глибочицька'),
#  ('Шевченківський', 70000.0, 'Салютна'),
#  ('Голосіївський', 3180495.0, 'Метрологічна'),
#  ('Подільський', 50500.0, 'Північно-Сирецька'),
#  ('Подільський', 57000.0, 'Правди'),
#  (None, 130000.0, 'Вернадського'),
#  (None, 262000.0, 'Пчілки'),
#  ('Печерський', 66000.0, 'Лейпцизька'),
#  ('Печерський, Шевченківський', 3249056.0, 'Басейна'),
#  (None, 2000000.0, 'Шаповала'),
#  ('Оболонський', 78000.0, 'Бережанська'),
#  (None, 90500.0, 'Бойчука'),
#  ('Святошинський', 80000.0, 'Перемоги'),
#  ('Шевченківський', 80000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 80000.0, 'Перемоги'),
#  (None, 906080.0, 'Івана Федорова'),
#  ('Голосіївський, Печерський', 4500000.0, 'Антоновича'),
#  (None, 32000.0, 'Вільямса'),
#  (None, 190000.0, 'Бойчука'),
#  ('Святошинський', 220000.0, 'Перемоги'),
#  ('Шевченківський', 220000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 220000.0, 'Перемоги'),
#  ('Голосіївський, Печерський', 110000.0, 'Ковпака'),
#  ('Дніпровський', 43000.0, 'Русанівський'),
#  (None, 983253.0, 'Українки'),
#  ('Дніпровський', 65000.0, 'Празька'),
#  (None, 110000.0, 'Гончара'),
#  (None, 150000.0, 'Маккейна'),
#  ('Оболонський', 125500.0, 'Балтійський'),
#  ('Шевченківський', 200000.0, 'Білоруська'),
#  ('Дарницький', 480000.0, 'Драгоманова'),
#  (None, 235000.0, 'Липківського'),
#  ('Печерський', 82000.0, 'Новогоспітальна'),
#  (None, 121975.0, 'Радченка'),
#  (None, 200000.0, 'Богомольця'),
#  (None, 250000.0, 'Донця'),
#  ('Оболонський', 205000.0, 'Оболонський'),
#  ('Подільський', 76466.0, 'Щекавицька'),
#  ('Подільський', 76466.0, 'Щекавицька'),
#  ('Деснянський', 240000.0, 'Пожарського'),
#  ('Дніпровський', 240000.0, 'Пожарського'),
#  ('Подільський', 150000.0, 'Полкова'),
#  (None, 69000.0, 'Донця'),
#  (None, 74900.0, 'Палладіна'),
#  (None, 1350000.0, 'Бойчука'),
#  (None, 386000.0, 'Липківського'),
#  ('Шевченківський', 31500.0, 'Павлівська'),
#  (None, 58000.0, 'Івашкевича'),
#  ("Солом'янський", 115000.0, 'Іскрівська'),
#  ('Святошинський', 64999.0, 'Максимовича'),
#  (None, 69900.0, '*** not found'),
#  (None, 220000.0, 'Драгомирова'),
#  ('Голосіївський', 2873080.0, 'Теремківська'),
#  ('Дарницький', 186000.0, 'Осокорська'),
#  ('Подільський', 43000.0, 'Дмитрівська'),
#  ('Шевченківський', 43000.0, 'Дмитрівська'),
#  (None, 55000.0, 'Кондратюка'),
#  ('Дніпровський', 193750.0, 'Регенераторна'),
#  (None, 100999.0, None),
#  ('Шевченківський', 11017941.0, 'Глибочицька'),
#  ('Оболонський', 149000.0, 'Героїв Сталінграда'),
#  ("Солом'янський, Шевченківський ", 3600804.0, 'Борщагівська'),
#  ('Дарницький', 45000.0, 'Ревуцького'),
#  ('Святошинський', 92000.0, 'Юнацька'),
#  ("Солом'янський", 92000.0, 'Юнацька'),
#  (None, 295000.0, 'Заболотного'),
#  ('Оболонський', 39900.0, 'Автозаводська'),
#  (None, 215000.0, 'Заболотного'),
#  ('Голосіївський, Печерський, Шевченківський', 2458347.0, 'Саксаганського'),
#  ('Дарницький', 138000.0, 'Зарічна'),
#  (None, 50000.0, '*** not found'),
#  (None, 92284.0, 'Невська'),
#  ('Оболонський', 140000.0, 'Героїв Сталінграда'),
#  ('Дарницький', 3707378.0, 'Вишняківська'),
#  (None, 94000.0, 'Драгомирова'),
#  (None, 45000.0, 'Драгомирова'),
#  (None, 56000.0, 'Гавела'),
#  ('Дарницький', 140000.0, 'Здолбунівська'),
#  (None, 90000.0, 'Драгомирова'),
#  ('Печерський', 159000.0, 'Мечнікова'),
#  (None, 1848450.0, '*** not found'),
#  ('Святошинський', 106000.0, 'Максимовича'),
#  ('Шевченківський', 170000.0, 'Багговутівська'),
#  ('Шевченківський', 91000.0, 'Шолуденка'),
#  ('Подільський', 110000.0, 'Щекавицька'),
#  ('Подільський', 110000.0, 'Щекавицька'),
#  (None, 65000.0, 'Коласа'),
#  (None, 260000.0, '*** not found'),
#  (None, 125000.0, '*** not found'),
#  ('Святошинський', 65000.0, 'Перемоги'),
#  ('Шевченківський', 65000.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 65000.0, 'Перемоги'),
#  (None, 158000.0, '*** not found'),
#  (None, 80000.0, 'Наумова'),
#  ('Святошинський', 68900.0, 'Перемоги'),
#  ('Шевченківський', 68900.0, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 68900.0, 'Перемоги'),
#  ('Голосіївський, Шевченківський, Печерський',
#   168000.0,
#   'Велика Васильківська'),
#  (None, 41000.0, 'Червоноткацька'),
#  ('Подільський, Оболонський', 134900.0, 'Вишгородська')]

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = ("INSERT INTO result " + stmt_join)

# %%
# виконати запит на заповнення
cur.execute(stmt_insert)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = cur.execute("SELECT * FROM result").fetchall()

_ = [print(x) for x in result_list]
# Out:
# (None, '115000.0', 'Омеляновича-Павленка')
# (None, '75000.0', None)
# (None, '140000.0', 'Ованеса Туманяна')
# ('Оболонський', '140000.0', 'Петропавлівська')
# ('Подільський', '140000.0', 'Петропавлівська')
# ('Оболонський', '160000.0', 'Дніпровська')
# ('Голосіївський, Печерський, Шевченківський', '870000.0', 'Саксаганського')
# (None, '14883863.0', 'Івана Мазепи')
# ('Оболонський', '220000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '133000.0', 'Ділова')
# (None, '69000.0', 'Новодарницька')
# ('Дарницький', '169999.0', 'Ревуцького')
# (None, '212000.0', 'Липківського')
# (None, '83500.0', 'Бендукідзе')
# ('Подільський', '75000.0', 'Введенська')
# ('Печерський', '65000.0', 'Виноградний')
# ("Голосіївський,Солом'янський", '82000.0', 'Кайсарова')
# (None, '207000.0', 'Ахматової')
# (None, '51990.0', 'Радченка')
# ('Оболонський', '57999.0', 'Дніпровська')
# ('Голосіївський, Печерський', '57000.0', 'Ділова')
# ('Дарницький', '95000.0', 'Бориспільська')
# ('Печерський', '50000.0', 'Болсуновська')
# (None, '95000.0', 'Українки')
# (None, '46860.0', 'Антонова')
# (None, '38500.0', 'Омеляновича-Павленка')
# (None, '110000.0', None)
# (None, '269000.0', 'Ованеса Туманяна')
# ('Оболонський', '1983000.0', 'Петропавлівська')
# ('Подільський', '1983000.0', 'Петропавлівська')
# ('Оболонський', '119000.0', 'Дніпровська')
# ('Голосіївський, Печерський, Шевченківський', '210000.0', 'Саксаганського')
# (None, '310000.0', 'Івана Мазепи')
# ('Оболонський', '93000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '98000.0', 'Ділова')
# (None, '78000.0', 'Новодарницька')
# ('Дарницький', '68000.0', 'Ревуцького')
# (None, '77000.0', 'Липківського')
# (None, '176000.0', 'Бендукідзе')
# ('Подільський', '5572000.0', 'Введенська')
# ('Печерський', '129000.0', 'Виноградний')
# ("Голосіївський,Солом'янський", '136000.0', 'Кайсарова')
# (None, '71000.0', 'Ахматової')
# (None, '108000.0', 'Радченка')
# ('Оболонський', '175000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '45006.0', 'Ділова')
# ('Дарницький', '78000.0', 'Бориспільська')
# ('Печерський', '65000.0', 'Болсуновська')
# (None, '3396000.0', 'Українки')
# (None, '68899.0', 'Антонова')
# ('Голосіївський', '205000.0', 'Науки')
# ('Голосіївський', '211000.0', 'Метрологічна')
# ('Печерський', '36500.0', 'Дружби Народів')
# (None, '3176715.0', '*** not found')
# (None, '155000.0', 'Драгомирова')
# (None, '109000.0', 'Данченка')
# ('Голосіївський', '120000.0', 'Кримська')
# ("Солом'янський", '55000.0', 'Новопольова')
# (None, '48000.0', 'Туполєва')
# (None, '235000.0', '*** not found')
# ('Оболонський', '41000.0', 'Дніпровська')
# ('Святошинський', '143000.0', 'Перемоги')
# ('Шевченківський', '143000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '143000.0', 'Перемоги')
# (None, '65000.0', 'Івана Федорова')
# ('Деснянський, Дніпровський', '500000.0', 'Братиславська')
# (None, '94000.0', '*** not found')
# (None, '280000.0', 'Червоноткацька')
# (None, '67500.0', 'Златоустівська')
# (None, '72000.0', 'Бойченка')
# ('Дарницький', '54000.0', 'Трускавецька')
# ('Дніпровський', '74000.0', 'Каховська')
# (None, '130000.0', 'Лобановського')
# (None, '110000.0', '*** not found')
# (None, '180000.0', 'Курчатова')
# ('Голосіївський', '69000.0', 'Голосіївська')
# ('Голосіївський', '69000.0', 'Голосіївська')
# ('Подільський', '205000.0', 'Тираспольська')
# ('Печерський', '211000.0', 'Лаврська')
# ('Подільський', '36500.0', 'Правди')
# (None, '3176715.0', 'Миколайчука')
# (None, '155000.0', 'Порика')
# (None, '109000.0', 'Червоноткацька')
# (None, '120000.0', 'Маккейна')
# ('Оболонський', '55000.0', 'Йорданська')
# (None, '48000.0', 'Тютюнника')
# ('Дніпровський', '235000.0', 'Регенераторна')
# ('Дарницький', '41000.0', 'Зарічна')
# (None, '143000.0', 'Заболотного')
# ('Дніпровський, Деснянський', '65000.0', 'Курнатовського')
# ('Печерський', '500000.0', 'Інститутська')
# (None, '94000.0', 'Маланюка')
# (None, '280000.0', 'Гречка')
# (None, '67500.0', 'Липківського')
# (None, '72000.0', 'Маккейна')
# (None, '54000.0', 'Григоренка')
# (None, '74000.0', 'Коновальця')
# (None, '130000.0', 'Закревського')
# (None, '110000.0', '*** not found')
# ('Печерський', '180000.0', 'Старонаводницька')
# (None, '69000.0', 'Маланюка')
# ('Печерський', '120000.0', 'Заньковецької')
# ('Шевченківський', '150000.0', 'Кудрявська')
# (None, '750000.0', None)
# (None, '75000.0', 'Українки')
# (None, '53000.0', None)
# ('Деснянський', '42500.0', 'Милославська')
# (None, '103000.0', 'Донця')
# (None, '650000.0', 'Верховинця')
# ('Оболонський', '56000.0', 'Героїв Дніпра')
# ('Дніпровський', '90000.0', 'Каховська')
# ('Дніпровський', '77000.0', 'Каховська')
# ('Дарницький', '115000.0', 'Вишняківська')
# (None, '120000.0', 'Липська')
# (None, '130000.0', 'Сверстюка')
# (None, '85000.0', 'Драгомирова')
# ('Дарницький', '140000.0', 'Причальна')
# ('Печерський', '45500.0', 'Болсуновська')
# ("Шевченківський, Солом'янський", '63232.0', 'Повітрофлотський')
# ('Дарницький', '95000.0', 'Драгоманова')
# (None, '55000.0', 'Григоренка')
# ('Оболонський', '186900.0', 'Дніпровська')
# (None, '34200.0', 'Жабаєва')
# (None, '234899.0', 'Філатова')
# ('Подільський', '55000.0', 'Правди')
# ('Шевченківський', '136000.0', 'Малопідвальна')
# (None, '139000.0', 'Бойчука')
# ('Дарницький', '210000.0', 'Зарічна')
# ('Печерський', '195000.0', 'Предславинська')
# (None, '119000.0', 'Івана Мазепи')
# (None, '410000.0', 'Радченка')
# ('Печерський', '93000.0', 'Лабораторний')
# (None, '137634.0', 'Конєва')
# (None, '115000.0', 'Шаповала')
# ('Оболонський', '85000.0', 'Дніпровська')
# ('Дарницький', '130000.0', 'Клеманська')
# (None, '113000.0', 'Григоренка')
# (None, '39500.0', 'Туполєва')
# (None, '68000.0', 'Хмельницького')
# ('Печерський', '155000.0', 'Саперне Поле')
# ('Оболонський', '110000.0', 'Героїв Сталінграда')
# ('Оболонський', '75000.0', 'Дніпровська')
# ('Голосіївський', '142000.0', 'Тарасівська')
# ('Дніпровський', '80000.0', 'Краківська')
# ('Святошинський', '43000.0', 'Юнацька')
# ("Солом'янський", '43000.0', 'Юнацька')
# ('Дарницький', '248000.0', 'Клеманська')
# ('Оболонський', '280000.0', 'Героїв Сталінграда')
# (None, '209000.0', 'Драгомирова')
# (None, '58990.0', '*** not found')
# ('Дарницький', '111000.0', 'Драгоманова')
# (None, '97000.0', 'Українки')
# (None, '68000.0', 'Тимошенка')
# ('Деснянський', '184900.0', 'Маяковського')
# ('Подільський', '61500.0', 'Дмитрівська')
# ('Шевченківський', '61500.0', 'Дмитрівська')
# (None, '111000.0', 'Курбаса')
# (None, '190700.0', 'Комарова')
# ('Дарницький', '53000.0', 'Драгоманова')
# (None, '69000.0', 'Драгомирова')
# (None, '169000.0', 'Моторний')
# ('Деснянський', '95000.0', 'Милославська')
# (None, '110000.0', 'Бойчука')
# (None, '5880000.0', 'Закревського')
# (None, '99999.0', 'Івана Федорова')
# (None, '327000.0', 'Філатова')
# ('Святошинський', '85000.0', 'Перемоги')
# ('Шевченківський', '85000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '85000.0', 'Перемоги')
# ('Деснянський, Дніпровський', '790000.0', 'Миропільська')
# (None, '95000.0', 'Григоренка')
# ('Святошинський', '70000.0', 'Юнацька')
# ("Солом'янський", '70000.0', 'Юнацька')
# ('Подільський, Оболонський', '2352122.0', 'Вишгородська')
# ('Святошинський', '807000.0', 'Жолудєва')
# ('Шевченківський', '77000.0', 'Павлівська')
# ('Голосіївський', '75000.0', 'Голосіївський')
# ('Голосіївський', '75000.0', 'Голосіївський')
# ('Дарницький', '480000.0', 'Осокорська')
# ('Подільський, Оболонський', '70000.0', 'Вишгородська')
# (None, '205000.0', 'Драгомирова')
# (None, '499990.0', 'Тютюнника')
# (None, '52000.0', 'Маккейна')
# (None, '93000.0', 'Івана Мазепи')
# ('Оболонський', '117000.0', 'Героїв Сталінграда')
# (None, '53900.0', 'Липківського')
# (None, '58000.0', '*** not found')
# (None, '159000.0', 'Коновальця')
# ('Святошинський', '116000.0', 'Максимовича')
# ('Дарницький', '42000.0', 'Зарічна')
# ('Голосіївський', '55500.0', 'Голосіївська')
# ('Голосіївський', '55500.0', 'Голосіївська')
# ('Голосіївський', '370000.0', 'Ясинуватський')
# (None, '650000.0', '*** not found')
# (None, '355000.0', 'Колоса')
# ('Подільський', '145000.0', 'Правди')
# ('Голосіївський, Шевченківський, Печерський', '117000.0', 'Велика Васильківська')
# ('Голосіївський', '300000.0', 'Голосіївський')
# ('Голосіївський', '300000.0', 'Голосіївський')
# (None, '55000.0', '*** not found')
# (None, '41000.0', 'Бойчука')
# ('Дніпровський', '128000.0', 'Центральна')
# ('Оболонський', '128000.0', 'Центральна')
# ('Шевченківський', '128000.0', 'Центральна')
# ('Голосіївський', '175000.0', 'Ясинуватський')
# ('Дніпровський', '783000.0', 'Райдужна')
# ('Голосіївський', '90000.0', 'Ломоносова')
# (None, '98000.0', None)
# (None, '137000.0', '*** not found')
# ('Печерський', '45000.0', 'Гусовського')
# (None, '2015228.0', 'Окіпної')
# ('Шевченківський', '200000.0', 'Багговутівська')
# ('Печерський', '147000.0', 'Дружби Народів')
# (None, '78000.0', 'Маккейна')
# (None, '82000.0', 'Маланюка')
# (None, '75000.0', 'Михайла Котельникова')
# ("Солом'янський", '89000.0', 'Героїв Севастополя')
# (None, '710000.0', 'Маланюка')
# ('Печерський', '620000.0', 'Саперне Поле')
# ('Оболонський', '69500.0', 'Балтійський')
# ('Шевченківський', '85000.0', 'Кудрявська')
# ('Святошинський', '43000.0', 'Перемоги')
# ('Шевченківський', '43000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '43000.0', 'Перемоги')
# ('Печерський', '330000.0', 'Німанська')
# ('Дніпровський', '59000.0', 'Каховська')
# ('Шевченківський', '40000.0', 'Малопідвальна')
# (None, '1200000.0', 'Невська')
# (None, '405000.0', 'Златоустівська')
# (None, '100110.0', None)
# ('Святошинський', '400000.0', 'Берковецька')
# (None, '97500.0', 'Бажана')
# ('Голосіївський, Печерський', '83000.0', 'Антоновича')
# (None, '44000.0', '*** not found')
# (None, '66000.0', 'Гречка')
# ('Дніпровський', '350000.0', 'Микільсько-Слобідська')
# ('Подільський', '77000.0', 'Правди')
# (None, '122250.0', 'Тимошенка')
# (None, '65000.0', 'Павла Тичини')
# ('Святошинський', '170000.0', 'Олевська')
# ("Солом'янський", '95000.0', 'Освіти')
# (None, '85000.0', 'Іллєнка')
# ('Оболонський', '69500.0', 'Дніпровська')
# (None, '152000.0', 'Івана Мазепи')
# (None, '92000.0', 'Українки')
# (None, '375000.0', 'Данченка')
# (None, '449000.0', 'Драгомирова')
# (None, '75500.0', 'Тбіліський')
# ('Дніпровський', '140000.0', 'Каховська')
# ("Солом'янський", '45000.0', 'Ушинського')
# ("Солом'янський", '45000.0', 'Ушинського')
# ('Дарницький', '135000.0', 'Урлівська')
# ('Подільський', '125000.0', 'Світлицького')
# ('Оболонський', '140000.0', 'Дніпровська')
# (None, '120000.0', 'Липківського')
# ('Дніпровський', '42000.0', 'Микільсько-Слобідська')
# (None, '125000.0', 'Лобановського')
# ('Оболонський', '48000.0', 'Героїв Сталінграда')
# ('Оболонський', '300000.0', 'Дніпровська')
# ('Дарницький', '120000.0', 'Драгоманова')
# (None, '649000.0', 'Ахматової')
# ('Печерський', '64980.0', 'Саперне Поле')
# (None, '77000.0', 'Данченка')
# ('Голосіївський', '48000.0', 'Голосіївський')
# ('Голосіївський', '48000.0', 'Голосіївський')
# (None, '102000.0', '*** not found')
# ('Шевченківський', '185000.0', 'Глибочицька')
# ('Шевченківський', '42000.0', 'Багговутівська')
# ('Голосіївський, Печерський, Шевченківський', '115000.0', 'Саксаганського')
# (None, '175000.0', 'Моторний')
# ('Оболонський', '54000.0', 'Йорданська')
# ('Печерський', '10116000.0', 'Саперне Поле')
# (None, '137000.0', 'Вернадського')
# (None, '95000.0', 'Курбаса')
# ('Шевченківський', '360000.0', 'Багговутівська')
# ('Подільський', '135000.0', 'Набережно-Рибальська')
# ('Голосіївський, Печерський, Шевченківський', '105000.0', 'Саксаганського')
# (None, '58000.0', 'Малиновського')
# ("Солом'янський", '180000.0', 'Протасів Яр')
# ('Печерський', '153000.0', 'Німанська')
# (None, '159000.0', 'Підвисоцького')
# ('Святошинський', '98000.0', 'Зодчих')
# (None, '1200000.0', 'Рокосовського')
# ('Печерський', '42900.0', 'Шовковична')
# (None, '86000.0', 'Крушельницької')
# ("Солом'янський", '155000.0', 'Новопольова')
# ('Дніпровський', '450000.0', 'Визволителів')
# ('Дніпровський', '148000.0', 'Сонячна')
# ('Шевченківський', '148000.0', 'Сонячна')
# (None, '50000.0', 'Сікорського')
# (None, '81000.0', 'Радченка')
# ('Шевченківський', '161003.0', 'Бульварно-Кудрявська')
# ("Голосіївський,Солом'янський", '61500.0', 'Кайсарова')
# ('Оболонський', '78000.0', 'Дніпровська')
# ('Дніпровський', '259266.0', 'Перова')
# (None, '34500.0', 'Глушкова')
# (None, '122000.0', 'Рокосовського')
# ('Голосіївський', '147420.0', 'Саперно-Слобідська')
# (None, '73000.0', 'Миколи Кибальчича')
# (None, '44000.0', 'Миколи Ушакова')
# ('Голосіївський, Печерський', '128000.0', 'Антоновича')
# ("Солом'янський", '111000.0', 'Богданівська')
# (None, '73000.0', None)
# (None, '89000.0', 'Сверстюка')
# ('Дарницький', '64000.0', 'Ревуцького')
# (None, '375000.0', 'Ованеса Туманяна')
# ('Печерський', '98000.0', 'Саперне Поле')
# (None, '32000.0', 'Григоренка')
# (None, '125000.0', 'Гречка')
# ('Оболонський', '61500.0', 'Богатирська')
# ('Шевченківський', '105000.0', 'Білоруська')
# ('Дніпровський', '2425640.0', 'Регенераторна')
# ('Дарницький', '89000.0', 'Вишняківська')
# (None, '27500.0', 'Гонгадзе')
# ('Подільський', '47000.0', 'Правди')
# ('Святошинський', '329000.0', 'Кольцова')
# ('Дніпровський', '71000.0', 'Воскресенська')
# (None, '1885431.0', 'Руставелі')
# ('Голосіївський', '980000.0', 'Голосіївський')
# ('Голосіївський', '980000.0', 'Голосіївський')
# ('Дніпровський', '68000.0', 'Комбінатна')
# ('Шевченківський', '71000.0', 'Салютна')
# (None, '190000.0', 'Маланюка')
# (None, '3641884.0', 'Ромоданова')
# ('Печерський', '115000.0', 'Саперне Поле')
# (None, '45000.0', 'Сім’ї Кульженків')
# ('Голосіївський, Печерський', '57000.0', 'Лабораторна')
# ('Дарницький', '45500.0', 'Драгоманова')
# (None, '260000.0', None)
# ('Шевченківський', '80000.0', 'Кудрявська')
# ('Дніпровський', '2110252.0', 'Краківська')
# ('Святошинський', '138000.0', 'Кольцова')
# ('Голосіївський, Печерський', '105000.0', 'Антоновича')
# (None, '2363130.0', 'Лариси Руденко')
# (None, '89000.0', 'Івана Пулюя')
# (None, '400000.0', 'Українки')
# (None, '100000.0', 'Тютюнника')
# (None, '61500.0', 'Юрія Смолича')
# ('Оболонський', '48000.0', 'Оболонський')
# (None, '180000.0', 'Курбаса')
# (None, '108000.0', 'Верховинця')
# ('Дарницький', '43500.0', 'Зарічна')
# ('Оболонський', '100999.0', 'Дніпровська')
# ('Голосіївський', '52000.0', 'Коломийський')
# ('Подільський', '146000.0', 'Правди')
# ('Дніпровський', '110000.0', 'Каховська')
# (None, '148800.0', 'Бойчука')
# ('Подільський', '77000.0', 'Правди')
# (None, '38500.0', 'Маккейна')
# ('Святошинський', '100000.0', 'Перемоги')
# ('Шевченківський', '100000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '100000.0', 'Перемоги')
# (None, '78000.0', 'Грушевського')
# ('Дарницький', '75000.0', 'Срібнокільська')
# ('Святошинський', '45000.0', 'Перемоги')
# ('Шевченківський', '45000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '45000.0', 'Перемоги')
# ('Дарницький', '900000.0', 'Урлівська')
# (None, '85000.0', 'Заболотного')
# ('Святошинський', '65600.0', 'Максимовича')
# (None, '395000.0', 'Бажана')
# (None, '155000.0', 'Сікорського')
# (None, '84000.0', 'Курбаса')
# ('Оболонський', '73000.0', 'Дніпровська')
# (None, '83000.0', 'Драгомирова')
# (None, '250000.0', None)
# (None, '299000.0', 'Антонова')
# (None, '56000.0', 'Бучми')
# ('Деснянський', '4335178.0', 'Кубанської України')
# ('Оболонський', '270000.0', 'Дніпровська')
# (None, '58000.0', 'Панельна')
# (None, '62000.0', 'Коновальця')
# ('Оболонський', '80000.0', 'Богатирська')
# ('Оболонський', '195000.0', 'Оболонський')
# (None, '3180495.0', 'Українки')
# (None, '122000.0', 'Бориса Гмирі')
# ('Подільський', '3793500.0', 'Правди')
# ('Дніпровський', '65000.0', 'Центральна')
# ('Оболонський', '65000.0', 'Центральна')
# ('Шевченківський', '65000.0', 'Центральна')
# ("Солом'янський", '40500.0', 'Преображенська')
# (None, '1181731.0', 'Коновальця')
# (None, '69000.0', 'Українки')
# (None, '75000.0', '*** not found')
# ('Голосіївський, Шевченківський, Печерський', '155000.0', 'Велика Васильківська')
# (None, '220000.0', 'Липківського')
# (None, '51500.0', 'Бойчука')
# ('Голосіївський', '73900.0', 'Васильківська')
# (None, '2458347.0', 'Данькевича')
# ('Оболонський', '1400000.0', 'Богатирська')
# (None, '93950.0', 'Українки')
# (None, '395000.0', 'Гречка')
# ('Печерський', '179000.0', 'Редутна')
# (None, '260000.0', 'Бориса Гмирі')
# (None, '52000.0', 'Драгомирова')
# (None, '395000.0', 'Туполєва')
# (None, '198450.0', 'Кондратюка')
# ('Оболонський', '750000.0', 'Мінський')
# ('Подільський', '750000.0', 'Мінський')
# ('Дарницький', '650000.0', 'Княжий Затон')
# ('Шевченківський', '75000.0', 'Герцена')
# ('Шевченківський', '75000.0', 'Герцена')
# ('Шевченківський', '75000.0', 'Герцена')
# ('Оболонський', '150000.0', 'Балтійський')
# (None, '93900.0', 'Ернста')
# (None, '120500.0', 'Шаповала')
# (None, '129000.0', 'Городецького')
# (None, '62000.0', "Сім'ї Сосніних")
# (None, '150000.0', 'Івана Мазепи')
# (None, '55000.0', 'Червоноткацька')
# (None, '138000.0', '*** not found')
# ('Голосіївський', '172000.0', 'Голосіївська')
# ('Голосіївський', '172000.0', 'Голосіївська')
# (None, '79900.0', '*** not found')
# (None, '49999.0', 'Миколи Гулака')
# (None, '115000.0', 'Івана Федорова')
# ('Печерський', '87000.0', 'Саперне Поле')
# (None, '107000.0', 'Миколи Хвильового')
# ('Шевченківський', '87700.0', 'Паторжинського')
# (None, '65000.0', 'Наумовича')
# (None, '1250000.0', 'Калнишевського')
# ('Оболонський', '34700.0', 'Дніпровська')
# ('Подільський', '67000.0', 'Електриків')
# ('Подільський', '67000.0', 'Електриків')
# ("Солом'янський", '88000.0', "Солом'янська")
# ("Солом'янський", '88000.0', "Солом'янська")
# ('Дарницький', '285000.0', 'Шевченка')
# ('Дарницький', '285000.0', 'Шевченка')
# ('Деснянський', '285000.0', 'Шевченка')
# ("Солом'янський", '285000.0', 'Шевченка')
# ("Солом'янський", '285000.0', 'Шевченка')
# ('Дарницький', '93000.0', 'Озерна')
# ('Оболонський', '93000.0', 'Озерна')
# ('Святошинський (СТ "Нивки")', '93000.0', 'Озерна')
# ("Солом'янський", '93000.0', 'Озерна')
# (None, '85000.0', 'Григоренка')
# (None, '230000.0', 'Антонова')
# ('Голосіївський', '155000.0', 'Голосіївський')
# ('Голосіївський', '155000.0', 'Голосіївський')
# (None, '180000.0', 'Комарова')
# ("Солом'янський, Шевченківський ", '95000.0', 'Борщагівська')
# ('Дарницький', '54934.0', 'Шевченка')
# ('Дарницький', '54934.0', 'Шевченка')
# ('Деснянський', '54934.0', 'Шевченка')
# ("Солом'янський", '54934.0', 'Шевченка')
# ("Солом'янський", '54934.0', 'Шевченка')
# ('Святошинський', '260000.0', 'Максимовича')
# ("Солом'янський", '145000.0', 'Ковальський')
# (None, '135000.0', 'Малевича')
# ('Деснянський', '50000.0', 'Мічуріна')
# ('Оболонський', '50000.0', 'Мічуріна')
# ('Печерський', '50000.0', 'Мічуріна')
# ('Печерський', '50000.0', 'Мічуріна')
# ("Солом'янський", '50000.0', 'Мічуріна')
# (None, '399000.0', '*** not found')
# ('Оболонський', '55000.0', 'Балтійський')
# ('Дніпровський', '270000.0', 'Азербайджанська')
# ('Дарницький', '337000.0', 'Зарічна')
# (None, '170000.0', 'Чавдар')
# ('Подільський', '85000.0', 'Правди')
# ('Дарницький', '279000.0', 'Урлівська')
# ('Дарницький', '44000.0', 'Бориспільська')
# (None, '170000.0', 'Поправки')
# ('Дарницький', '88000.0', 'Бориспільська')
# ('Дніпровський', '41500.0', 'Ентузіастів')
# ('Дарницький', '70000.0', 'Малоземельна')
# ('Голосіївський, Печерський, Шевченківський', '119900.0', 'Саксаганського')
# ('Оболонський', '86000.0', 'Героїв Сталінграда')
# ('Святошинський', '138000.0', 'Зодчих')
# (None, '240000.0', 'Калнишевського')
# (None, '149500.0', 'Філатова')
# ('Печерський', '1999600.0', 'Старонаводницька')
# (None, '67999.0', 'Заболотного')
# ('Подільський', '41500.0', 'Правди')
# (None, '99000.0', '*** not found')
# ('Голосіївський, Печерський', '580000.0', 'Антоновича')
# (None, '75000.0', 'Шаповала')
# (None, '299000.0', 'Івана Федорова')
# ('Шевченківський', '44000.0', 'Деревлянська')
# (None, '139000.0', 'Вільямса')
# ("Солом'янський", '150000.0', 'Васильченка')
# ('Печерський', '45690.0', 'Предславинська')
# ('Деснянський', '115000.0', 'Крайня')
# ('Деснянський', '63500.0', 'Милославська')
# ('Дніпровський', '42000.0', 'Воскресенська')
# (None, '56500.0', 'Маланюка')
# ('Оболонський', '66000.0', 'Дніпровська')
# ('Шевченківський', '103000.0', 'Пушкінська')
# ('Голосіївський', '63000.0', 'Набережно-Корчуватська')
# ('Дарницький', '228000.0', 'Зарічна')
# ('Шевченківський', '90000.0', 'Тургенєвська')
# (None, '87000.0', 'Радченка')
# ('Дарницький', '62000.0', 'Зарічна')
# ('Голосіївський', '77000.0', 'Метрологічна')
# ('Оболонський', '179900.0', 'Йорданська')
# ('Святошинський', '49000.0', 'Кольцова')
# ('Святошинський', '105900.0', 'Максимовича')
# ('Голосіївський', '500000.0', 'Науки')
# ('Голосіївський', '38000.0', 'Саперно-Слобідська')
# ('Печерський', '130000.0', 'Шовковична')
# ('Дарницький', '230000.0', 'Трускавецька')
# (None, '66800.0', 'Гавела')
# ("Шевченківський, Солом'янський", '125000.0', 'Повітрофлотський')
# (None, '113000.0', 'Запорожця')
# (None, '93000.0', 'Маккейна')
# ('Святошинський', '422000.0', 'Перемоги')
# ('Шевченківський', '422000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '422000.0', 'Перемоги')
# (None, '80500.0', 'Щербаківського')
# ('Дарницький', '123000.0', 'Зарічна')
# ('Деснянський', '200000.0', 'Будищанська')
# ('Печерський, Голосіївський, Шевченківський', '52000.0', 'Жилянська')
# ('Дніпровський', '360000.0', 'Комбінатна')
# ('Дарницький', '102000.0', 'Ревуцького')
# (None, '77000.0', 'Бородіна')
# (None, '125000.0', 'Руставелі')
# ('Дарницький', '84000.0', 'Драгоманова')
# ("Солом'янський", '185000.0', 'Преображенська')
# ('Святошинський', '888189.0', 'Депутатська')
# ('Шевченківський', '45142.0', 'Багговутівська')
# (None, '980000.0', '*** not found')
# (None, '180000.0', 'Сікорського')
# (None, '40000.0', 'Драгомирова')
# ('Шевченківський', '110000.0', 'Коперніка')
# ('Голосіївський', '3600804.0', 'Васильківська')
# ('Шевченківський', '165000.0', 'Глибочицька')
# (None, '92550.0', 'Чавдар')
# ('Печерський', '80000.0', 'Шовковична')
# ('Оболонський', '115000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '4335178.0', 'Антоновича')
# (None, '155000.0', None)
# ('Дарницький', '220000.0', 'Славгородська')
# (None, '95000.0', 'Драгомирова')
# ('Дарницький', '115000.0', 'Срібнокільська')
# (None, '1750000.0', 'Харченка')
# (None, '240000.0', 'Окіпної')
# ('Печерський', '1158740.0', 'Саперне Поле')
# (None, '170000.0', 'Олени Теліги')
# (None, '93000.0', 'Кондратюка')
# ('Печерський', '145000.0', 'Мечнікова')
# ('Оболонський', '47211.0', 'Героїв Сталінграда')
# ('Печерський', '81000.0', 'Рибальська')
# ("Солом'янський", '750000.0', 'Березова')
# ('Печерський', '84950.0', 'Саперне Поле')
# ('Голосіївський, Печерський', '190000.0', 'Антоновича')
# (None, '85000.0', 'Маккейна')
# ('Печерський', '211000.0', 'Лейпцизька')
# ('Дарницький', '136279.0', 'Драгоманова')
# (None, '71000.0', 'Коновальця')
# (None, '95000.0', 'Василя Стуса')
# (None, '120000.0', 'Тютюнника')
# ('Шевченківський', '335000.0', 'Січових Стрільців')
# ('Дніпровський', '38500.0', 'Райдужна')
# (None, '47000.0', 'Закревського')
# ('Шевченківський', '105000.0', 'Тургенєвська')
# ('Голосіївський', '163000.0', 'Васильківська')
# (None, '1500000.0', "Зої Космодем'янської")
# (None, '49000.0', 'Радченка')
# (None, '100000.0', 'Сверстюка')
# ('Деснянський', '130000.0', 'Милославська')
# ('Голосіївський', '2688000.0', 'Метрологічна')
# ('Голосіївський', '52600.0', 'Деміївська')
# ('Голосіївський', '52600.0', 'Деміївська')
# ('Святошинський', '39000.0', 'Перемоги')
# ('Шевченківський', '39000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '39000.0', 'Перемоги')
# ('Подільський, Оболонський', '110000.0', 'Вишгородська')
# (None, '135000.0', 'Маккейна')
# (None, '139860.0', None)
# ('Святошинський', '70000.0', 'Перемоги')
# ('Шевченківський', '70000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '70000.0', 'Перемоги')
# ('Оболонський', '95000.0', 'Балтійський')
# ('Печерський', '155000.0', 'Звіринецька')
# ('Дарницький', '56850.0', 'Ревуцького')
# ('Подільський', '140000.0', 'Правди')
# ('Деснянський', '110000.0', 'Милославська')
# (None, '145000.0', 'Вербицького')
# ("Солом'янський", '280000.0', 'Новгородська')
# (None, '270000.0', 'Бажана')
# ('Подільський', '50500.0', 'Канівська')
# ('Святошинський', '39000.0', 'Максимовича')
# (None, '490000.0', 'Донця')
# (None, '34988.0', 'Драгомирова')
# ('Подільський', '311000.0', 'Тираспольська')
# ('Голосіївський, Печерський, Шевченківський', '65000.0', 'Саксаганського')
# ('Подільський', '169000.0', 'Тираспольська')
# ('Дарницький', '70000.0', 'Зарічна')
# (None, '103000.0', 'Гонгадзе')
# (None, '140000.0', 'Українки')
# ('Подільський', '116500.0', 'Світлицького')
# (None, '107000.0', 'Воробйова')
# ('Дніпровський', '77000.0', 'Каховська')
# ('Шевченківський', '165000.0', 'Глибочицька')
# (None, '450000.0', 'Білокур')
# ('Оболонський', '195000.0', 'Балтійський')
# ('Голосіївський, Печерський', '480000.0', 'Антоновича')
# (None, '120000.0', 'Кондратюка')
# (None, '58000.0', 'Гончара')
# ('Дарницький', '1500000.0', 'Ревуцького')
# (None, '345700.0', '*** not found')
# ('Дарницький', '126000.0', 'Драгоманова')
# (None, '158000.0', 'Сім’ї Кульженків')
# (None, '206315.0', 'Панельна')
# (None, '33000.0', 'Вільямса')
# ('Голосіївський', '250000.0', 'Голосіївська')
# ('Голосіївський', '250000.0', 'Голосіївська')
# ('Оболонський', '63500.0', 'Оболонський')
# ("Солом'янський", '2100000.0', 'Миколи Голего')
# ('Оболонський', '1180000.0', 'Дніпровська')
# (None, '42000.0', 'Малиновського')
# ('Шевченківський', '146000.0', 'Назарівська')
# ('Шевченківський', '299000.0', 'Гоголівська')
# ('Шевченківський', '141000.0', 'Дорогожицька')
# ('Оболонський', '41000.0', 'Петропавлівська')
# ('Подільський', '41000.0', 'Петропавлівська')
# (None, '115000.0', 'Грушевського')
# (None, '81000.0', 'Іллєнка')
# (None, '103950.0', 'Липківського')
# ("Солом'янський", '1468067.0', 'Ушинського')
# ("Солом'янський", '1468067.0', 'Ушинського')
# ('Дарницький', '68000.0', 'Польова')
# ('Деснянський', '68000.0', 'Польова')
# ("Солом'янський", '68000.0', 'Польова')
# ('Печерський', '80000.0', 'Саперне Поле')
# (None, '112000.0', 'Панельна')
# (None, '319000.0', 'Коновальця')
# (None, '98000.0', 'Хмельницького')
# (None, '50000.0', 'Маккейна')
# ('Голосіївський, Печерський', '49990.0', 'Антоновича')
# ('Дарницький', '89500.0', 'Толстого')
# ('Печерський', '350000.0', 'Дружби Народів')
# ('Оболонський', '210000.0', 'Оболонський')
# ('Шевченківський', '345000.0', 'Багговутівська')
# (None, '90000.0', 'Антонова')
# ('Голосіївський, Шевченківський', '170000.0', 'Володимирська')
# (None, '110000.0', 'Українки')
# (None, '59000.0', 'Сім’ї Кульженків')
# (None, '145000.0', 'Коновальця')
# (None, '79000.0', 'Мирного')
# ('Печерський', '375000.0', 'Московська')
# ("Солом'янський", '375000.0', 'Московська')
# ('Святошинський', '122000.0', 'Жмеринська')
# (None, '255000.0', 'Бойчука')
# (None, '85000.0', 'Липківського')
# ('Печерський', '240800.0', 'Лабораторний')
# ('Печерський', '455000.0', 'Інститутська')
# (None, '165000.0', 'Українки')
# ('Печерський, Шевченківський', '100000.0', 'Хрещатик')
# ('Оболонський', '195000.0', 'Дніпровська')
# ('Дарницький', '41000.0', 'Осокорська')
# ('Печерський', '70000.0', 'Саперне Поле')
# (None, '71400.0', 'Комарова')
# (None, '3711865.0', 'Драгомирова')
# ('Дарницький', '60000.0', 'Срібнокільська')
# ("Солом'янський", '240000.0', 'Чоколівський')
# ('Печерський', '260000.0', 'Звіринецька')
# ('Подільський, Оболонський', '127000.0', 'Вишгородська')
# (None, '40000.0', 'Драгомирова')
# ('Оболонський', '1796439.0', 'Героїв Сталінграда')
# ('Деснянський', '3400000.0', 'Будівельників')
# ('Дніпровський', '3400000.0', 'Будівельників')
# ('Дніпровський', '3400000.0', 'Будівельників')
# ('Святошинський', '3400000.0', 'Будівельників')
# (None, '44500.0', 'Іллєнка')
# ('Дарницький', '125000.0', 'Урлівська')
# ('Дарницький', '51000.0', 'Сормовська')
# ('Подільський', '1707790.0', 'Правди')
# ('Святошинський', '65000.0', 'Верховинна')
# (None, '55000.0', 'Вербицького')
# (None, '94500.0', '*** not found')
# ('Голосіївський, Шевченківський, Печерський', '115000.0', 'Велика Васильківська')
# (None, '45000.0', 'Бойчука')
# (None, '85000.0', 'Лобановського')
# (None, '5204750.0', 'Миколи Шепелєва')
# ('Печерський', '84500.0', 'Кропивницького')
# ('Дарницький', '350000.0', 'Трускавецька')
# ('Голосіївський', '182000.0', 'Голосіївська')
# ('Голосіївський', '182000.0', 'Голосіївська')
# (None, '188999.0', 'Маланюка')
# (None, '147000.0', 'Драгомирова')
# ('Святошинський', '89900.0', 'Юнацька')
# ("Солом'янський", '89900.0', 'Юнацька')
# ('Святошинський', '66900.0', 'Максимовича')
# (None, '75000.0', 'Комарова')
# ('Шевченківський', '58000.0', 'Багговутівська')
# (None, '140000.0', None)
# ('Голосіївський', '82000.0', 'Костанайська')
# ('Дарницький', '215000.0', 'Срібнокільська')
# (None, '33400.0', 'Курчатова')
# ('Печерський', '100000.0', 'Гусовського')
# (None, '240000.0', 'Українки')
# ('Дарницький', '62000.0', 'Драгоманова')
# ('Оболонський', '115000.0', 'Дніпровська')
# (None, '143560.0', 'Заболотного')
# (None, '130000.0', 'Заболотного')
# ('Святошинський', '152000.0', 'Перемоги')
# ('Шевченківський', '152000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '152000.0', 'Перемоги')
# (None, '33800.0', 'Сверстюка')
# (None, '55000.0', 'Липківського')
# (None, '110000.0', 'Маккейна')
# ('Оболонський', '200000.0', 'Дніпровська')
# ('Деснянський', '70000.0', 'Волгоградська')
# ("Солом'янський", '70000.0', 'Волгоградська')
# ("Солом'янський", '160888.0', 'Новопольова')
# ('Дарницький', '189000.0', 'Драгоманова')
# (None, '135000.0', 'Лебедєва')
# (None, '215000.0', '*** not found')
# (None, '102000.0', 'Драгомирова')
# ('Печерський', '193750.0', 'Лейпцизька')
# ('Шевченківський', '54000.0', 'Глибочицька')
# ('Шевченківський', '70000.0', 'Салютна')
# ('Голосіївський', '3180495.0', 'Метрологічна')
# ('Подільський', '50500.0', 'Північно-Сирецька')
# ('Подільський', '57000.0', 'Правди')
# (None, '130000.0', 'Вернадського')
# (None, '262000.0', 'Пчілки')
# ('Печерський', '66000.0', 'Лейпцизька')
# ('Печерський, Шевченківський', '3249056.0', 'Басейна')
# (None, '2000000.0', 'Шаповала')
# ('Оболонський', '78000.0', 'Бережанська')
# (None, '90500.0', 'Бойчука')
# ('Святошинський', '80000.0', 'Перемоги')
# ('Шевченківський', '80000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '80000.0', 'Перемоги')
# (None, '906080.0', 'Івана Федорова')
# ('Голосіївський, Печерський', '4500000.0', 'Антоновича')
# (None, '32000.0', 'Вільямса')
# (None, '190000.0', 'Бойчука')
# ('Святошинський', '220000.0', 'Перемоги')
# ('Шевченківський', '220000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '220000.0', 'Перемоги')
# ('Голосіївський, Печерський', '110000.0', 'Ковпака')
# ('Дніпровський', '43000.0', 'Русанівський')
# (None, '983253.0', 'Українки')
# ('Дніпровський', '65000.0', 'Празька')
# (None, '110000.0', 'Гончара')
# (None, '150000.0', 'Маккейна')
# ('Оболонський', '125500.0', 'Балтійський')
# ('Шевченківський', '200000.0', 'Білоруська')
# ('Дарницький', '480000.0', 'Драгоманова')
# (None, '235000.0', 'Липківського')
# ('Печерський', '82000.0', 'Новогоспітальна')
# (None, '121975.0', 'Радченка')
# (None, '200000.0', 'Богомольця')
# (None, '250000.0', 'Донця')
# ('Оболонський', '205000.0', 'Оболонський')
# ('Подільський', '76466.0', 'Щекавицька')
# ('Подільський', '76466.0', 'Щекавицька')
# ('Деснянський', '240000.0', 'Пожарського')
# ('Дніпровський', '240000.0', 'Пожарського')
# ('Подільський', '150000.0', 'Полкова')
# (None, '69000.0', 'Донця')
# (None, '74900.0', 'Палладіна')
# (None, '1350000.0', 'Бойчука')
# (None, '386000.0', 'Липківського')
# ('Шевченківський', '31500.0', 'Павлівська')
# (None, '58000.0', 'Івашкевича')
# ("Солом'янський", '115000.0', 'Іскрівська')
# ('Святошинський', '64999.0', 'Максимовича')
# (None, '69900.0', '*** not found')
# (None, '220000.0', 'Драгомирова')
# ('Голосіївський', '2873080.0', 'Теремківська')
# ('Дарницький', '186000.0', 'Осокорська')
# ('Подільський', '43000.0', 'Дмитрівська')
# ('Шевченківський', '43000.0', 'Дмитрівська')
# (None, '55000.0', 'Кондратюка')
# ('Дніпровський', '193750.0', 'Регенераторна')
# (None, '100999.0', None)
# ('Шевченківський', '11017941.0', 'Глибочицька')
# ('Оболонський', '149000.0', 'Героїв Сталінграда')
# ("Солом'янський, Шевченківський ", '3600804.0', 'Борщагівська')
# ('Дарницький', '45000.0', 'Ревуцького')
# ('Святошинський', '92000.0', 'Юнацька')
# ("Солом'янський", '92000.0', 'Юнацька')
# (None, '295000.0', 'Заболотного')
# ('Оболонський', '39900.0', 'Автозаводська')
# (None, '215000.0', 'Заболотного')
# ('Голосіївський, Печерський, Шевченківський', '2458347.0', 'Саксаганського')
# ('Дарницький', '138000.0', 'Зарічна')
# (None, '50000.0', '*** not found')
# (None, '92284.0', 'Невська')
# ('Оболонський', '140000.0', 'Героїв Сталінграда')
# ('Дарницький', '3707378.0', 'Вишняківська')
# (None, '94000.0', 'Драгомирова')
# (None, '45000.0', 'Драгомирова')
# (None, '56000.0', 'Гавела')
# ('Дарницький', '140000.0', 'Здолбунівська')
# (None, '90000.0', 'Драгомирова')
# ('Печерський', '159000.0', 'Мечнікова')
# (None, '1848450.0', '*** not found')
# ('Святошинський', '106000.0', 'Максимовича')
# ('Шевченківський', '170000.0', 'Багговутівська')
# ('Шевченківський', '91000.0', 'Шолуденка')
# ('Подільський', '110000.0', 'Щекавицька')
# ('Подільський', '110000.0', 'Щекавицька')
# (None, '65000.0', 'Коласа')
# (None, '260000.0', '*** not found')
# (None, '125000.0', '*** not found')
# ('Святошинський', '65000.0', 'Перемоги')
# ('Шевченківський', '65000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '65000.0', 'Перемоги')
# (None, '158000.0', '*** not found')
# (None, '80000.0', 'Наумова')
# ('Святошинський', '68900.0', 'Перемоги')
# ('Шевченківський', '68900.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '68900.0', 'Перемоги')
# ('Голосіївський, Шевченківський, Печерський', '168000.0', 'Велика Васильківська')
# (None, '41000.0', 'Червоноткацька')
# ('Подільський, Оболонський', '134900.0', 'Вишгородська')
# (None, '115000.0', 'Омеляновича-Павленка')
# (None, '75000.0', None)
# (None, '140000.0', 'Ованеса Туманяна')
# ('Оболонський', '140000.0', 'Петропавлівська')
# ('Подільський', '140000.0', 'Петропавлівська')
# ('Оболонський', '160000.0', 'Дніпровська')
# ('Голосіївський, Печерський, Шевченківський', '870000.0', 'Саксаганського')
# (None, '14883863.0', 'Івана Мазепи')
# ('Оболонський', '220000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '133000.0', 'Ділова')
# (None, '69000.0', 'Новодарницька')
# ('Дарницький', '169999.0', 'Ревуцького')
# (None, '212000.0', 'Липківського')
# (None, '83500.0', 'Бендукідзе')
# ('Подільський', '75000.0', 'Введенська')
# ('Печерський', '65000.0', 'Виноградний')
# ("Голосіївський,Солом'янський", '82000.0', 'Кайсарова')
# (None, '207000.0', 'Ахматової')
# (None, '51990.0', 'Радченка')
# ('Оболонський', '57999.0', 'Дніпровська')
# ('Голосіївський, Печерський', '57000.0', 'Ділова')
# ('Дарницький', '95000.0', 'Бориспільська')
# ('Печерський', '50000.0', 'Болсуновська')
# (None, '95000.0', 'Українки')
# (None, '46860.0', 'Антонова')
# (None, '38500.0', 'Омеляновича-Павленка')
# (None, '110000.0', None)
# (None, '269000.0', 'Ованеса Туманяна')
# ('Оболонський', '1983000.0', 'Петропавлівська')
# ('Подільський', '1983000.0', 'Петропавлівська')
# ('Оболонський', '119000.0', 'Дніпровська')
# ('Голосіївський, Печерський, Шевченківський', '210000.0', 'Саксаганського')
# (None, '310000.0', 'Івана Мазепи')
# ('Оболонський', '93000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '98000.0', 'Ділова')
# (None, '78000.0', 'Новодарницька')
# ('Дарницький', '68000.0', 'Ревуцького')
# (None, '77000.0', 'Липківського')
# (None, '176000.0', 'Бендукідзе')
# ('Подільський', '5572000.0', 'Введенська')
# ('Печерський', '129000.0', 'Виноградний')
# ("Голосіївський,Солом'янський", '136000.0', 'Кайсарова')
# (None, '71000.0', 'Ахматової')
# (None, '108000.0', 'Радченка')
# ('Оболонський', '175000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '45006.0', 'Ділова')
# ('Дарницький', '78000.0', 'Бориспільська')
# ('Печерський', '65000.0', 'Болсуновська')
# (None, '3396000.0', 'Українки')
# (None, '68899.0', 'Антонова')
# ('Голосіївський', '205000.0', 'Науки')
# ('Голосіївський', '211000.0', 'Метрологічна')
# ('Печерський', '36500.0', 'Дружби Народів')
# (None, '3176715.0', '*** not found')
# (None, '155000.0', 'Драгомирова')
# (None, '109000.0', 'Данченка')
# ('Голосіївський', '120000.0', 'Кримська')
# ("Солом'янський", '55000.0', 'Новопольова')
# (None, '48000.0', 'Туполєва')
# (None, '235000.0', '*** not found')
# ('Оболонський', '41000.0', 'Дніпровська')
# ('Святошинський', '143000.0', 'Перемоги')
# ('Шевченківський', '143000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '143000.0', 'Перемоги')
# (None, '65000.0', 'Івана Федорова')
# ('Деснянський, Дніпровський', '500000.0', 'Братиславська')
# (None, '94000.0', '*** not found')
# (None, '280000.0', 'Червоноткацька')
# (None, '67500.0', 'Златоустівська')
# (None, '72000.0', 'Бойченка')
# ('Дарницький', '54000.0', 'Трускавецька')
# ('Дніпровський', '74000.0', 'Каховська')
# (None, '130000.0', 'Лобановського')
# (None, '110000.0', '*** not found')
# (None, '180000.0', 'Курчатова')
# ('Голосіївський', '69000.0', 'Голосіївська')
# ('Голосіївський', '69000.0', 'Голосіївська')
# ('Подільський', '205000.0', 'Тираспольська')
# ('Печерський', '211000.0', 'Лаврська')
# ('Подільський', '36500.0', 'Правди')
# (None, '3176715.0', 'Миколайчука')
# (None, '155000.0', 'Порика')
# (None, '109000.0', 'Червоноткацька')
# (None, '120000.0', 'Маккейна')
# ('Оболонський', '55000.0', 'Йорданська')
# (None, '48000.0', 'Тютюнника')
# ('Дніпровський', '235000.0', 'Регенераторна')
# ('Дарницький', '41000.0', 'Зарічна')
# (None, '143000.0', 'Заболотного')
# ('Дніпровський, Деснянський', '65000.0', 'Курнатовського')
# ('Печерський', '500000.0', 'Інститутська')
# (None, '94000.0', 'Маланюка')
# (None, '280000.0', 'Гречка')
# (None, '67500.0', 'Липківського')
# (None, '72000.0', 'Маккейна')
# (None, '54000.0', 'Григоренка')
# (None, '74000.0', 'Коновальця')
# (None, '130000.0', 'Закревського')
# (None, '110000.0', '*** not found')
# ('Печерський', '180000.0', 'Старонаводницька')
# (None, '69000.0', 'Маланюка')
# ('Печерський', '120000.0', 'Заньковецької')
# ('Шевченківський', '150000.0', 'Кудрявська')
# (None, '750000.0', None)
# (None, '75000.0', 'Українки')
# (None, '53000.0', None)
# ('Деснянський', '42500.0', 'Милославська')
# (None, '103000.0', 'Донця')
# (None, '650000.0', 'Верховинця')
# ('Оболонський', '56000.0', 'Героїв Дніпра')
# ('Дніпровський', '90000.0', 'Каховська')
# ('Дніпровський', '77000.0', 'Каховська')
# ('Дарницький', '115000.0', 'Вишняківська')
# (None, '120000.0', 'Липська')
# (None, '130000.0', 'Сверстюка')
# (None, '85000.0', 'Драгомирова')
# ('Дарницький', '140000.0', 'Причальна')
# ('Печерський', '45500.0', 'Болсуновська')
# ("Шевченківський, Солом'янський", '63232.0', 'Повітрофлотський')
# ('Дарницький', '95000.0', 'Драгоманова')
# (None, '55000.0', 'Григоренка')
# ('Оболонський', '186900.0', 'Дніпровська')
# (None, '34200.0', 'Жабаєва')
# (None, '234899.0', 'Філатова')
# ('Подільський', '55000.0', 'Правди')
# ('Шевченківський', '136000.0', 'Малопідвальна')
# (None, '139000.0', 'Бойчука')
# ('Дарницький', '210000.0', 'Зарічна')
# ('Печерський', '195000.0', 'Предславинська')
# (None, '119000.0', 'Івана Мазепи')
# (None, '410000.0', 'Радченка')
# ('Печерський', '93000.0', 'Лабораторний')
# (None, '137634.0', 'Конєва')
# (None, '115000.0', 'Шаповала')
# ('Оболонський', '85000.0', 'Дніпровська')
# ('Дарницький', '130000.0', 'Клеманська')
# (None, '113000.0', 'Григоренка')
# (None, '39500.0', 'Туполєва')
# (None, '68000.0', 'Хмельницького')
# ('Печерський', '155000.0', 'Саперне Поле')
# ('Оболонський', '110000.0', 'Героїв Сталінграда')
# ('Оболонський', '75000.0', 'Дніпровська')
# ('Голосіївський', '142000.0', 'Тарасівська')
# ('Дніпровський', '80000.0', 'Краківська')
# ('Святошинський', '43000.0', 'Юнацька')
# ("Солом'янський", '43000.0', 'Юнацька')
# ('Дарницький', '248000.0', 'Клеманська')
# ('Оболонський', '280000.0', 'Героїв Сталінграда')
# (None, '209000.0', 'Драгомирова')
# (None, '58990.0', '*** not found')
# ('Дарницький', '111000.0', 'Драгоманова')
# (None, '97000.0', 'Українки')
# (None, '68000.0', 'Тимошенка')
# ('Деснянський', '184900.0', 'Маяковського')
# ('Подільський', '61500.0', 'Дмитрівська')
# ('Шевченківський', '61500.0', 'Дмитрівська')
# (None, '111000.0', 'Курбаса')
# (None, '190700.0', 'Комарова')
# ('Дарницький', '53000.0', 'Драгоманова')
# (None, '69000.0', 'Драгомирова')
# (None, '169000.0', 'Моторний')
# ('Деснянський', '95000.0', 'Милославська')
# (None, '110000.0', 'Бойчука')
# (None, '5880000.0', 'Закревського')
# (None, '99999.0', 'Івана Федорова')
# (None, '327000.0', 'Філатова')
# ('Святошинський', '85000.0', 'Перемоги')
# ('Шевченківський', '85000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '85000.0', 'Перемоги')
# ('Деснянський, Дніпровський', '790000.0', 'Миропільська')
# (None, '95000.0', 'Григоренка')
# ('Святошинський', '70000.0', 'Юнацька')
# ("Солом'янський", '70000.0', 'Юнацька')
# ('Подільський, Оболонський', '2352122.0', 'Вишгородська')
# ('Святошинський', '807000.0', 'Жолудєва')
# ('Шевченківський', '77000.0', 'Павлівська')
# ('Голосіївський', '75000.0', 'Голосіївський')
# ('Голосіївський', '75000.0', 'Голосіївський')
# ('Дарницький', '480000.0', 'Осокорська')
# ('Подільський, Оболонський', '70000.0', 'Вишгородська')
# (None, '205000.0', 'Драгомирова')
# (None, '499990.0', 'Тютюнника')
# (None, '52000.0', 'Маккейна')
# (None, '93000.0', 'Івана Мазепи')
# ('Оболонський', '117000.0', 'Героїв Сталінграда')
# (None, '53900.0', 'Липківського')
# (None, '58000.0', '*** not found')
# (None, '159000.0', 'Коновальця')
# ('Святошинський', '116000.0', 'Максимовича')
# ('Дарницький', '42000.0', 'Зарічна')
# ('Голосіївський', '55500.0', 'Голосіївська')
# ('Голосіївський', '55500.0', 'Голосіївська')
# ('Голосіївський', '370000.0', 'Ясинуватський')
# (None, '650000.0', '*** not found')
# (None, '355000.0', 'Колоса')
# ('Подільський', '145000.0', 'Правди')
# ('Голосіївський, Шевченківський, Печерський', '117000.0', 'Велика Васильківська')
# ('Голосіївський', '300000.0', 'Голосіївський')
# ('Голосіївський', '300000.0', 'Голосіївський')
# (None, '55000.0', '*** not found')
# (None, '41000.0', 'Бойчука')
# ('Дніпровський', '128000.0', 'Центральна')
# ('Оболонський', '128000.0', 'Центральна')
# ('Шевченківський', '128000.0', 'Центральна')
# ('Голосіївський', '175000.0', 'Ясинуватський')
# ('Дніпровський', '783000.0', 'Райдужна')
# ('Голосіївський', '90000.0', 'Ломоносова')
# (None, '98000.0', None)
# (None, '137000.0', '*** not found')
# ('Печерський', '45000.0', 'Гусовського')
# (None, '2015228.0', 'Окіпної')
# ('Шевченківський', '200000.0', 'Багговутівська')
# ('Печерський', '147000.0', 'Дружби Народів')
# (None, '78000.0', 'Маккейна')
# (None, '82000.0', 'Маланюка')
# (None, '75000.0', 'Михайла Котельникова')
# ("Солом'янський", '89000.0', 'Героїв Севастополя')
# (None, '710000.0', 'Маланюка')
# ('Печерський', '620000.0', 'Саперне Поле')
# ('Оболонський', '69500.0', 'Балтійський')
# ('Шевченківський', '85000.0', 'Кудрявська')
# ('Святошинський', '43000.0', 'Перемоги')
# ('Шевченківський', '43000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '43000.0', 'Перемоги')
# ('Печерський', '330000.0', 'Німанська')
# ('Дніпровський', '59000.0', 'Каховська')
# ('Шевченківський', '40000.0', 'Малопідвальна')
# (None, '1200000.0', 'Невська')
# (None, '405000.0', 'Златоустівська')
# (None, '100110.0', None)
# ('Святошинський', '400000.0', 'Берковецька')
# (None, '97500.0', 'Бажана')
# ('Голосіївський, Печерський', '83000.0', 'Антоновича')
# (None, '44000.0', '*** not found')
# (None, '66000.0', 'Гречка')
# ('Дніпровський', '350000.0', 'Микільсько-Слобідська')
# ('Подільський', '77000.0', 'Правди')
# (None, '122250.0', 'Тимошенка')
# (None, '65000.0', 'Павла Тичини')
# ('Святошинський', '170000.0', 'Олевська')
# ("Солом'янський", '95000.0', 'Освіти')
# (None, '85000.0', 'Іллєнка')
# ('Оболонський', '69500.0', 'Дніпровська')
# (None, '152000.0', 'Івана Мазепи')
# (None, '92000.0', 'Українки')
# (None, '375000.0', 'Данченка')
# (None, '449000.0', 'Драгомирова')
# (None, '75500.0', 'Тбіліський')
# ('Дніпровський', '140000.0', 'Каховська')
# ("Солом'янський", '45000.0', 'Ушинського')
# ("Солом'янський", '45000.0', 'Ушинського')
# ('Дарницький', '135000.0', 'Урлівська')
# ('Подільський', '125000.0', 'Світлицького')
# ('Оболонський', '140000.0', 'Дніпровська')
# (None, '120000.0', 'Липківського')
# ('Дніпровський', '42000.0', 'Микільсько-Слобідська')
# (None, '125000.0', 'Лобановського')
# ('Оболонський', '48000.0', 'Героїв Сталінграда')
# ('Оболонський', '300000.0', 'Дніпровська')
# ('Дарницький', '120000.0', 'Драгоманова')
# (None, '649000.0', 'Ахматової')
# ('Печерський', '64980.0', 'Саперне Поле')
# (None, '77000.0', 'Данченка')
# ('Голосіївський', '48000.0', 'Голосіївський')
# ('Голосіївський', '48000.0', 'Голосіївський')
# (None, '102000.0', '*** not found')
# ('Шевченківський', '185000.0', 'Глибочицька')
# ('Шевченківський', '42000.0', 'Багговутівська')
# ('Голосіївський, Печерський, Шевченківський', '115000.0', 'Саксаганського')
# (None, '175000.0', 'Моторний')
# ('Оболонський', '54000.0', 'Йорданська')
# ('Печерський', '10116000.0', 'Саперне Поле')
# (None, '137000.0', 'Вернадського')
# (None, '95000.0', 'Курбаса')
# ('Шевченківський', '360000.0', 'Багговутівська')
# ('Подільський', '135000.0', 'Набережно-Рибальська')
# ('Голосіївський, Печерський, Шевченківський', '105000.0', 'Саксаганського')
# (None, '58000.0', 'Малиновського')
# ("Солом'янський", '180000.0', 'Протасів Яр')
# ('Печерський', '153000.0', 'Німанська')
# (None, '159000.0', 'Підвисоцького')
# ('Святошинський', '98000.0', 'Зодчих')
# (None, '1200000.0', 'Рокосовського')
# ('Печерський', '42900.0', 'Шовковична')
# (None, '86000.0', 'Крушельницької')
# ("Солом'янський", '155000.0', 'Новопольова')
# ('Дніпровський', '450000.0', 'Визволителів')
# ('Дніпровський', '148000.0', 'Сонячна')
# ('Шевченківський', '148000.0', 'Сонячна')
# (None, '50000.0', 'Сікорського')
# (None, '81000.0', 'Радченка')
# ('Шевченківський', '161003.0', 'Бульварно-Кудрявська')
# ("Голосіївський,Солом'янський", '61500.0', 'Кайсарова')
# ('Оболонський', '78000.0', 'Дніпровська')
# ('Дніпровський', '259266.0', 'Перова')
# (None, '34500.0', 'Глушкова')
# (None, '122000.0', 'Рокосовського')
# ('Голосіївський', '147420.0', 'Саперно-Слобідська')
# (None, '73000.0', 'Миколи Кибальчича')
# (None, '44000.0', 'Миколи Ушакова')
# ('Голосіївський, Печерський', '128000.0', 'Антоновича')
# ("Солом'янський", '111000.0', 'Богданівська')
# (None, '73000.0', None)
# (None, '89000.0', 'Сверстюка')
# ('Дарницький', '64000.0', 'Ревуцького')
# (None, '375000.0', 'Ованеса Туманяна')
# ('Печерський', '98000.0', 'Саперне Поле')
# (None, '32000.0', 'Григоренка')
# (None, '125000.0', 'Гречка')
# ('Оболонський', '61500.0', 'Богатирська')
# ('Шевченківський', '105000.0', 'Білоруська')
# ('Дніпровський', '2425640.0', 'Регенераторна')
# ('Дарницький', '89000.0', 'Вишняківська')
# (None, '27500.0', 'Гонгадзе')
# ('Подільський', '47000.0', 'Правди')
# ('Святошинський', '329000.0', 'Кольцова')
# ('Дніпровський', '71000.0', 'Воскресенська')
# (None, '1885431.0', 'Руставелі')
# ('Голосіївський', '980000.0', 'Голосіївський')
# ('Голосіївський', '980000.0', 'Голосіївський')
# ('Дніпровський', '68000.0', 'Комбінатна')
# ('Шевченківський', '71000.0', 'Салютна')
# (None, '190000.0', 'Маланюка')
# (None, '3641884.0', 'Ромоданова')
# ('Печерський', '115000.0', 'Саперне Поле')
# (None, '45000.0', 'Сім’ї Кульженків')
# ('Голосіївський, Печерський', '57000.0', 'Лабораторна')
# ('Дарницький', '45500.0', 'Драгоманова')
# (None, '260000.0', None)
# ('Шевченківський', '80000.0', 'Кудрявська')
# ('Дніпровський', '2110252.0', 'Краківська')
# ('Святошинський', '138000.0', 'Кольцова')
# ('Голосіївський, Печерський', '105000.0', 'Антоновича')
# (None, '2363130.0', 'Лариси Руденко')
# (None, '89000.0', 'Івана Пулюя')
# (None, '400000.0', 'Українки')
# (None, '100000.0', 'Тютюнника')
# (None, '61500.0', 'Юрія Смолича')
# ('Оболонський', '48000.0', 'Оболонський')
# (None, '180000.0', 'Курбаса')
# (None, '108000.0', 'Верховинця')
# ('Дарницький', '43500.0', 'Зарічна')
# ('Оболонський', '100999.0', 'Дніпровська')
# ('Голосіївський', '52000.0', 'Коломийський')
# ('Подільський', '146000.0', 'Правди')
# ('Дніпровський', '110000.0', 'Каховська')
# (None, '148800.0', 'Бойчука')
# ('Подільський', '77000.0', 'Правди')
# (None, '38500.0', 'Маккейна')
# ('Святошинський', '100000.0', 'Перемоги')
# ('Шевченківський', '100000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '100000.0', 'Перемоги')
# (None, '78000.0', 'Грушевського')
# ('Дарницький', '75000.0', 'Срібнокільська')
# ('Святошинський', '45000.0', 'Перемоги')
# ('Шевченківський', '45000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '45000.0', 'Перемоги')
# ('Дарницький', '900000.0', 'Урлівська')
# (None, '85000.0', 'Заболотного')
# ('Святошинський', '65600.0', 'Максимовича')
# (None, '395000.0', 'Бажана')
# (None, '155000.0', 'Сікорського')
# (None, '84000.0', 'Курбаса')
# ('Оболонський', '73000.0', 'Дніпровська')
# (None, '83000.0', 'Драгомирова')
# (None, '250000.0', None)
# (None, '299000.0', 'Антонова')
# (None, '56000.0', 'Бучми')
# ('Деснянський', '4335178.0', 'Кубанської України')
# ('Оболонський', '270000.0', 'Дніпровська')
# (None, '58000.0', 'Панельна')
# (None, '62000.0', 'Коновальця')
# ('Оболонський', '80000.0', 'Богатирська')
# ('Оболонський', '195000.0', 'Оболонський')
# (None, '3180495.0', 'Українки')
# (None, '122000.0', 'Бориса Гмирі')
# ('Подільський', '3793500.0', 'Правди')
# ('Дніпровський', '65000.0', 'Центральна')
# ('Оболонський', '65000.0', 'Центральна')
# ('Шевченківський', '65000.0', 'Центральна')
# ("Солом'янський", '40500.0', 'Преображенська')
# (None, '1181731.0', 'Коновальця')
# ...
# ('Подільський', '67000.0', 'Електриків')
# ('Подільський', '67000.0', 'Електриків')
# ("Солом'янський", '88000.0', "Солом'янська")
# ("Солом'янський", '88000.0', "Солом'янська")
# ('Дарницький', '285000.0', 'Шевченка')
# ('Дарницький', '285000.0', 'Шевченка')
# ('Деснянський', '285000.0', 'Шевченка')
# ("Солом'янський", '285000.0', 'Шевченка')
# ("Солом'янський", '285000.0', 'Шевченка')
# ('Дарницький', '93000.0', 'Озерна')
# ('Оболонський', '93000.0', 'Озерна')
# ('Святошинський (СТ "Нивки")', '93000.0', 'Озерна')
# ("Солом'янський", '93000.0', 'Озерна')
# (None, '85000.0', 'Григоренка')
# (None, '230000.0', 'Антонова')
# ('Голосіївський', '155000.0', 'Голосіївський')
# ('Голосіївський', '155000.0', 'Голосіївський')
# (None, '180000.0', 'Комарова')
# ("Солом'янський, Шевченківський ", '95000.0', 'Борщагівська')
# ('Дарницький', '54934.0', 'Шевченка')
# ('Дарницький', '54934.0', 'Шевченка')
# ('Деснянський', '54934.0', 'Шевченка')
# ("Солом'янський", '54934.0', 'Шевченка')
# ("Солом'янський", '54934.0', 'Шевченка')
# ('Святошинський', '260000.0', 'Максимовича')
# ("Солом'янський", '145000.0', 'Ковальський')
# (None, '135000.0', 'Малевича')
# ('Деснянський', '50000.0', 'Мічуріна')
# ('Оболонський', '50000.0', 'Мічуріна')
# ('Печерський', '50000.0', 'Мічуріна')
# ('Печерський', '50000.0', 'Мічуріна')
# ("Солом'янський", '50000.0', 'Мічуріна')
# (None, '399000.0', '*** not found')
# ('Оболонський', '55000.0', 'Балтійський')
# ('Дніпровський', '270000.0', 'Азербайджанська')
# ('Дарницький', '337000.0', 'Зарічна')
# (None, '170000.0', 'Чавдар')
# ('Подільський', '85000.0', 'Правди')
# ('Дарницький', '279000.0', 'Урлівська')
# ('Дарницький', '44000.0', 'Бориспільська')
# (None, '170000.0', 'Поправки')
# ('Дарницький', '88000.0', 'Бориспільська')
# ('Дніпровський', '41500.0', 'Ентузіастів')
# ('Дарницький', '70000.0', 'Малоземельна')
# ('Голосіївський, Печерський, Шевченківський', '119900.0', 'Саксаганського')
# ('Оболонський', '86000.0', 'Героїв Сталінграда')
# ('Святошинський', '138000.0', 'Зодчих')
# (None, '240000.0', 'Калнишевського')
# (None, '149500.0', 'Філатова')
# ('Печерський', '1999600.0', 'Старонаводницька')
# (None, '67999.0', 'Заболотного')
# ('Подільський', '41500.0', 'Правди')
# (None, '99000.0', '*** not found')
# ('Голосіївський, Печерський', '580000.0', 'Антоновича')
# (None, '75000.0', 'Шаповала')
# (None, '299000.0', 'Івана Федорова')
# ('Шевченківський', '44000.0', 'Деревлянська')
# (None, '139000.0', 'Вільямса')
# ("Солом'янський", '150000.0', 'Васильченка')
# ('Печерський', '45690.0', 'Предславинська')
# ('Деснянський', '115000.0', 'Крайня')
# ('Деснянський', '63500.0', 'Милославська')
# ('Дніпровський', '42000.0', 'Воскресенська')
# (None, '56500.0', 'Маланюка')
# ('Оболонський', '66000.0', 'Дніпровська')
# ('Шевченківський', '103000.0', 'Пушкінська')
# ('Голосіївський', '63000.0', 'Набережно-Корчуватська')
# ('Дарницький', '228000.0', 'Зарічна')
# ('Шевченківський', '90000.0', 'Тургенєвська')
# (None, '87000.0', 'Радченка')
# ('Дарницький', '62000.0', 'Зарічна')
# ('Голосіївський', '77000.0', 'Метрологічна')
# ('Оболонський', '179900.0', 'Йорданська')
# ('Святошинський', '49000.0', 'Кольцова')
# ('Святошинський', '105900.0', 'Максимовича')
# ('Голосіївський', '500000.0', 'Науки')
# ('Голосіївський', '38000.0', 'Саперно-Слобідська')
# ('Печерський', '130000.0', 'Шовковична')
# ('Дарницький', '230000.0', 'Трускавецька')
# (None, '66800.0', 'Гавела')
# ("Шевченківський, Солом'янський", '125000.0', 'Повітрофлотський')
# (None, '113000.0', 'Запорожця')
# (None, '93000.0', 'Маккейна')
# ('Святошинський', '422000.0', 'Перемоги')
# ('Шевченківський', '422000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '422000.0', 'Перемоги')
# (None, '80500.0', 'Щербаківського')
# ('Дарницький', '123000.0', 'Зарічна')
# ('Деснянський', '200000.0', 'Будищанська')
# ('Печерський, Голосіївський, Шевченківський', '52000.0', 'Жилянська')
# ('Дніпровський', '360000.0', 'Комбінатна')
# ('Дарницький', '102000.0', 'Ревуцького')
# (None, '77000.0', 'Бородіна')
# (None, '125000.0', 'Руставелі')
# ('Дарницький', '84000.0', 'Драгоманова')
# ("Солом'янський", '185000.0', 'Преображенська')
# ('Святошинський', '888189.0', 'Депутатська')
# ('Шевченківський', '45142.0', 'Багговутівська')
# (None, '980000.0', '*** not found')
# (None, '180000.0', 'Сікорського')
# (None, '40000.0', 'Драгомирова')
# ('Шевченківський', '110000.0', 'Коперніка')
# ('Голосіївський', '3600804.0', 'Васильківська')
# ('Шевченківський', '165000.0', 'Глибочицька')
# (None, '92550.0', 'Чавдар')
# ('Печерський', '80000.0', 'Шовковична')
# ('Оболонський', '115000.0', 'Дніпровська')
# ('Голосіївський, Печерський', '4335178.0', 'Антоновича')
# (None, '155000.0', None)
# ('Дарницький', '220000.0', 'Славгородська')
# (None, '95000.0', 'Драгомирова')
# ('Дарницький', '115000.0', 'Срібнокільська')
# (None, '1750000.0', 'Харченка')
# (None, '240000.0', 'Окіпної')
# ('Печерський', '1158740.0', 'Саперне Поле')
# (None, '170000.0', 'Олени Теліги')
# (None, '93000.0', 'Кондратюка')
# ('Печерський', '145000.0', 'Мечнікова')
# ('Оболонський', '47211.0', 'Героїв Сталінграда')
# ('Печерський', '81000.0', 'Рибальська')
# ("Солом'янський", '750000.0', 'Березова')
# ('Печерський', '84950.0', 'Саперне Поле')
# ('Голосіївський, Печерський', '190000.0', 'Антоновича')
# (None, '85000.0', 'Маккейна')
# ('Печерський', '211000.0', 'Лейпцизька')
# ('Дарницький', '136279.0', 'Драгоманова')
# (None, '71000.0', 'Коновальця')
# (None, '95000.0', 'Василя Стуса')
# (None, '120000.0', 'Тютюнника')
# ('Шевченківський', '335000.0', 'Січових Стрільців')
# ('Дніпровський', '38500.0', 'Райдужна')
# (None, '47000.0', 'Закревського')
# ('Шевченківський', '105000.0', 'Тургенєвська')
# ('Голосіївський', '163000.0', 'Васильківська')
# (None, '1500000.0', "Зої Космодем'янської")
# (None, '49000.0', 'Радченка')
# (None, '100000.0', 'Сверстюка')
# ('Деснянський', '130000.0', 'Милославська')
# ('Голосіївський', '2688000.0', 'Метрологічна')
# ('Голосіївський', '52600.0', 'Деміївська')
# ('Голосіївський', '52600.0', 'Деміївська')
# ('Святошинський', '39000.0', 'Перемоги')
# ('Шевченківський', '39000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '39000.0', 'Перемоги')
# ('Подільський, Оболонський', '110000.0', 'Вишгородська')
# (None, '135000.0', 'Маккейна')
# (None, '139860.0', None)
# ('Святошинський', '70000.0', 'Перемоги')
# ('Шевченківський', '70000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '70000.0', 'Перемоги')
# ('Оболонський', '95000.0', 'Балтійський')
# ('Печерський', '155000.0', 'Звіринецька')
# ('Дарницький', '56850.0', 'Ревуцького')
# ('Подільський', '140000.0', 'Правди')
# ('Деснянський', '110000.0', 'Милославська')
# (None, '145000.0', 'Вербицького')
# ("Солом'янський", '280000.0', 'Новгородська')
# (None, '270000.0', 'Бажана')
# ('Подільський', '50500.0', 'Канівська')
# ('Святошинський', '39000.0', 'Максимовича')
# (None, '490000.0', 'Донця')
# (None, '34988.0', 'Драгомирова')
# ('Подільський', '311000.0', 'Тираспольська')
# ('Голосіївський, Печерський, Шевченківський', '65000.0', 'Саксаганського')
# ('Подільський', '169000.0', 'Тираспольська')
# ('Дарницький', '70000.0', 'Зарічна')
# (None, '103000.0', 'Гонгадзе')
# (None, '140000.0', 'Українки')
# ('Подільський', '116500.0', 'Світлицького')
# (None, '107000.0', 'Воробйова')
# ('Дніпровський', '77000.0', 'Каховська')
# ('Шевченківський', '165000.0', 'Глибочицька')
# (None, '450000.0', 'Білокур')
# ('Оболонський', '195000.0', 'Балтійський')
# ('Голосіївський, Печерський', '480000.0', 'Антоновича')
# (None, '120000.0', 'Кондратюка')
# (None, '58000.0', 'Гончара')
# ('Дарницький', '1500000.0', 'Ревуцького')
# (None, '345700.0', '*** not found')
# ('Дарницький', '126000.0', 'Драгоманова')
# (None, '158000.0', 'Сім’ї Кульженків')
# (None, '206315.0', 'Панельна')
# (None, '33000.0', 'Вільямса')
# ('Голосіївський', '250000.0', 'Голосіївська')
# ('Голосіївський', '250000.0', 'Голосіївська')
# ('Оболонський', '63500.0', 'Оболонський')
# ("Солом'янський", '2100000.0', 'Миколи Голего')
# ('Оболонський', '1180000.0', 'Дніпровська')
# (None, '42000.0', 'Малиновського')
# ('Шевченківський', '146000.0', 'Назарівська')
# ('Шевченківський', '299000.0', 'Гоголівська')
# ('Шевченківський', '141000.0', 'Дорогожицька')
# ('Оболонський', '41000.0', 'Петропавлівська')
# ('Подільський', '41000.0', 'Петропавлівська')
# (None, '115000.0', 'Грушевського')
# (None, '81000.0', 'Іллєнка')
# (None, '103950.0', 'Липківського')
# ("Солом'янський", '1468067.0', 'Ушинського')
# ("Солом'янський", '1468067.0', 'Ушинського')
# ('Дарницький', '68000.0', 'Польова')
# ('Деснянський', '68000.0', 'Польова')
# ("Солом'янський", '68000.0', 'Польова')
# ('Печерський', '80000.0', 'Саперне Поле')
# (None, '112000.0', 'Панельна')
# (None, '319000.0', 'Коновальця')
# (None, '98000.0', 'Хмельницького')
# (None, '50000.0', 'Маккейна')
# ('Голосіївський, Печерський', '49990.0', 'Антоновича')
# ('Дарницький', '89500.0', 'Толстого')
# ('Печерський', '350000.0', 'Дружби Народів')
# ('Оболонський', '210000.0', 'Оболонський')
# ('Шевченківський', '345000.0', 'Багговутівська')
# (None, '90000.0', 'Антонова')
# ('Голосіївський, Шевченківський', '170000.0', 'Володимирська')
# (None, '110000.0', 'Українки')
# (None, '59000.0', 'Сім’ї Кульженків')
# (None, '145000.0', 'Коновальця')
# (None, '79000.0', 'Мирного')
# ('Печерський', '375000.0', 'Московська')
# ("Солом'янський", '375000.0', 'Московська')
# ('Святошинський', '122000.0', 'Жмеринська')
# (None, '255000.0', 'Бойчука')
# (None, '85000.0', 'Липківського')
# ('Печерський', '240800.0', 'Лабораторний')
# ('Печерський', '455000.0', 'Інститутська')
# (None, '165000.0', 'Українки')
# ('Печерський, Шевченківський', '100000.0', 'Хрещатик')
# ('Оболонський', '195000.0', 'Дніпровська')
# ('Дарницький', '41000.0', 'Осокорська')
# ('Печерський', '70000.0', 'Саперне Поле')
# (None, '71400.0', 'Комарова')
# (None, '3711865.0', 'Драгомирова')
# ('Дарницький', '60000.0', 'Срібнокільська')
# ("Солом'янський", '240000.0', 'Чоколівський')
# ('Печерський', '260000.0', 'Звіринецька')
# ('Подільський, Оболонський', '127000.0', 'Вишгородська')
# (None, '40000.0', 'Драгомирова')
# ('Оболонський', '1796439.0', 'Героїв Сталінграда')
# ('Деснянський', '3400000.0', 'Будівельників')
# ('Дніпровський', '3400000.0', 'Будівельників')
# ('Дніпровський', '3400000.0', 'Будівельників')
# ('Святошинський', '3400000.0', 'Будівельників')
# (None, '44500.0', 'Іллєнка')
# ('Дарницький', '125000.0', 'Урлівська')
# ('Дарницький', '51000.0', 'Сормовська')
# ('Подільський', '1707790.0', 'Правди')
# ('Святошинський', '65000.0', 'Верховинна')
# (None, '55000.0', 'Вербицького')
# (None, '94500.0', '*** not found')
# ('Голосіївський, Шевченківський, Печерський', '115000.0', 'Велика Васильківська')
# (None, '45000.0', 'Бойчука')
# (None, '85000.0', 'Лобановського')
# (None, '5204750.0', 'Миколи Шепелєва')
# ('Печерський', '84500.0', 'Кропивницького')
# ('Дарницький', '350000.0', 'Трускавецька')
# ('Голосіївський', '182000.0', 'Голосіївська')
# ('Голосіївський', '182000.0', 'Голосіївська')
# (None, '188999.0', 'Маланюка')
# (None, '147000.0', 'Драгомирова')
# ('Святошинський', '89900.0', 'Юнацька')
# ("Солом'янський", '89900.0', 'Юнацька')
# ('Святошинський', '66900.0', 'Максимовича')
# (None, '75000.0', 'Комарова')
# ('Шевченківський', '58000.0', 'Багговутівська')
# (None, '140000.0', None)
# ('Голосіївський', '82000.0', 'Костанайська')
# ('Дарницький', '215000.0', 'Срібнокільська')
# (None, '33400.0', 'Курчатова')
# ('Печерський', '100000.0', 'Гусовського')
# (None, '240000.0', 'Українки')
# ('Дарницький', '62000.0', 'Драгоманова')
# ('Оболонський', '115000.0', 'Дніпровська')
# (None, '143560.0', 'Заболотного')
# (None, '130000.0', 'Заболотного')
# ('Святошинський', '152000.0', 'Перемоги')
# ('Шевченківський', '152000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '152000.0', 'Перемоги')
# (None, '33800.0', 'Сверстюка')
# (None, '55000.0', 'Липківського')
# (None, '110000.0', 'Маккейна')
# ('Оболонський', '200000.0', 'Дніпровська')
# ('Деснянський', '70000.0', 'Волгоградська')
# ("Солом'янський", '70000.0', 'Волгоградська')
# ("Солом'янський", '160888.0', 'Новопольова')
# ('Дарницький', '189000.0', 'Драгоманова')
# (None, '135000.0', 'Лебедєва')
# (None, '215000.0', '*** not found')
# (None, '102000.0', 'Драгомирова')
# ('Печерський', '193750.0', 'Лейпцизька')
# ('Шевченківський', '54000.0', 'Глибочицька')
# ('Шевченківський', '70000.0', 'Салютна')
# ('Голосіївський', '3180495.0', 'Метрологічна')
# ('Подільський', '50500.0', 'Північно-Сирецька')
# ('Подільський', '57000.0', 'Правди')
# (None, '130000.0', 'Вернадського')
# (None, '262000.0', 'Пчілки')
# ('Печерський', '66000.0', 'Лейпцизька')
# ('Печерський, Шевченківський', '3249056.0', 'Басейна')
# (None, '2000000.0', 'Шаповала')
# ('Оболонський', '78000.0', 'Бережанська')
# (None, '90500.0', 'Бойчука')
# ('Святошинський', '80000.0', 'Перемоги')
# ('Шевченківський', '80000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '80000.0', 'Перемоги')
# (None, '906080.0', 'Івана Федорова')
# ('Голосіївський, Печерський', '4500000.0', 'Антоновича')
# (None, '32000.0', 'Вільямса')
# (None, '190000.0', 'Бойчука')
# ('Святошинський', '220000.0', 'Перемоги')
# ('Шевченківський', '220000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '220000.0', 'Перемоги')
# ('Голосіївський, Печерський', '110000.0', 'Ковпака')
# ('Дніпровський', '43000.0', 'Русанівський')
# (None, '983253.0', 'Українки')
# ('Дніпровський', '65000.0', 'Празька')
# (None, '110000.0', 'Гончара')
# (None, '150000.0', 'Маккейна')
# ('Оболонський', '125500.0', 'Балтійський')
# ('Шевченківський', '200000.0', 'Білоруська')
# ('Дарницький', '480000.0', 'Драгоманова')
# (None, '235000.0', 'Липківського')
# ('Печерський', '82000.0', 'Новогоспітальна')
# (None, '121975.0', 'Радченка')
# (None, '200000.0', 'Богомольця')
# (None, '250000.0', 'Донця')
# ('Оболонський', '205000.0', 'Оболонський')
# ('Подільський', '76466.0', 'Щекавицька')
# ('Подільський', '76466.0', 'Щекавицька')
# ('Деснянський', '240000.0', 'Пожарського')
# ('Дніпровський', '240000.0', 'Пожарського')
# ('Подільський', '150000.0', 'Полкова')
# (None, '69000.0', 'Донця')
# (None, '74900.0', 'Палладіна')
# (None, '1350000.0', 'Бойчука')
# (None, '386000.0', 'Липківського')
# ('Шевченківський', '31500.0', 'Павлівська')
# (None, '58000.0', 'Івашкевича')
# ("Солом'янський", '115000.0', 'Іскрівська')
# ('Святошинський', '64999.0', 'Максимовича')
# (None, '69900.0', '*** not found')
# (None, '220000.0', 'Драгомирова')
# ('Голосіївський', '2873080.0', 'Теремківська')
# ('Дарницький', '186000.0', 'Осокорська')
# ('Подільський', '43000.0', 'Дмитрівська')
# ('Шевченківський', '43000.0', 'Дмитрівська')
# (None, '55000.0', 'Кондратюка')
# ('Дніпровський', '193750.0', 'Регенераторна')
# (None, '100999.0', None)
# ('Шевченківський', '11017941.0', 'Глибочицька')
# ('Оболонський', '149000.0', 'Героїв Сталінграда')
# ("Солом'янський, Шевченківський ", '3600804.0', 'Борщагівська')
# ('Дарницький', '45000.0', 'Ревуцького')
# ('Святошинський', '92000.0', 'Юнацька')
# ("Солом'янський", '92000.0', 'Юнацька')
# (None, '295000.0', 'Заболотного')
# ('Оболонський', '39900.0', 'Автозаводська')
# (None, '215000.0', 'Заболотного')
# ('Голосіївський, Печерський, Шевченківський', '2458347.0', 'Саксаганського')
# ('Дарницький', '138000.0', 'Зарічна')
# (None, '50000.0', '*** not found')
# (None, '92284.0', 'Невська')
# ('Оболонський', '140000.0', 'Героїв Сталінграда')
# ('Дарницький', '3707378.0', 'Вишняківська')
# (None, '94000.0', 'Драгомирова')
# (None, '45000.0', 'Драгомирова')
# (None, '56000.0', 'Гавела')
# ('Дарницький', '140000.0', 'Здолбунівська')
# (None, '90000.0', 'Драгомирова')
# ('Печерський', '159000.0', 'Мечнікова')
# (None, '1848450.0', '*** not found')
# ('Святошинський', '106000.0', 'Максимовича')
# ('Шевченківський', '170000.0', 'Багговутівська')
# ('Шевченківський', '91000.0', 'Шолуденка')
# ('Подільський', '110000.0', 'Щекавицька')
# ('Подільський', '110000.0', 'Щекавицька')
# (None, '65000.0', 'Коласа')
# (None, '260000.0', '*** not found')
# (None, '125000.0', '*** not found')
# ('Святошинський', '65000.0', 'Перемоги')
# ('Шевченківський', '65000.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '65000.0', 'Перемоги')
# (None, '158000.0', '*** not found')
# (None, '80000.0', 'Наумова')
# ('Святошинський', '68900.0', 'Перемоги')
# ('Шевченківський', '68900.0', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '68900.0', 'Перемоги')
# ('Голосіївський, Шевченківський, Печерський', '168000.0', 'Велика Васильківська')
# (None, '41000.0', 'Червоноткацька')
# ('Подільський, Оболонський', '134900.0', 'Вишгородська')

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = np.delete(result_list, [0,2], 1)

result_arr[result_arr == None] = 0
result_arr = [float(el[0]) for el in result_arr]

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : len(result_arr)  ,
    "середнє значення"         : round(np.mean(result_arr),1) ,
    "максимальне значення"     : np.max(result_arr) ,
    "мінімальне значення"      : np.min(result_arr) ,
    "стандартне відхилення"    : round(np.std(result_arr),1) ,
    "розмах вариації"          : np.max(result_arr) - np.min(result_arr)
    }
#  [np.nonzero(result_arr)]
print(result_dict)
# Out:
# {'кількість спостережень': 1622, 'середнє значення': 356496.8, 'максимальне значення': 14883863.0, 'мінімальне значення': 27500.0, 'стандартне відхилення': 1009040.0, 'розмах вариації': 14856363.0}

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# ================================================
# №  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ
# ================================================
#
# 1   кількість спостережень     1622
# 2   середнє значення           356496.8
# 3   максимальне значення       14883863.0
# 4   мінімальне значення        27500.0
# 5   стандартне відхилення      1009040.0
# 6   розмах вариації            14856363.0
